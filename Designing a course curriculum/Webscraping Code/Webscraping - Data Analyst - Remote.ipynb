# %% [markdown]
# # Web Scraping - Indeed.com
# General steps for Web Scraping
# 1. Check whether the website allows web scraping
# 2. Obtain the source code (HTML File) by using the website URL
# 3. Download the website content
# 4. Parse the content using keywords tags for elements of interest
# 5. Extract relevant data/features
# 6. Organize raw data in structured format (e.g., CSV)

# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from datetime import datetime
from arsenic import get_session
from arsenic.browsers import Firefox
from arsenic.services import Geckodriver
import asyncio
import time

# disable arsenic logging to stdout
import structlog
import logging

logger = logging.getLogger()
logger.setLevel(logging.WARN)
structlog.configure(logger_factory=lambda: logger)

# %% [markdown]
# ### Path to webdriver (Firefox, Chrome)

# %%
# Ensure that the driver path is correct before running this script.
# Microsoft Windows
# driver_path = "./drivers/windows/geckodriver.exe"
#driver_path = "./programs/geckodriver.exe"
driver_path = r"C:\Users\ranga\Downloads\geckodriver-v0.32.1-win64\geckodriver.exe"
# Linux
# driver_path = "./drivers/linux/geckodriver"
# driver_path = "/usr/bin/geckodriver"

options = {
  'moz:firefoxOptions': {
    # if you want it to be headless
    'args': ['-headless'],
    'log': {'level': 'warn'},
    # Needed for windows / non-default firefox install
    'binary': 'C:\\Program Files\\Mozilla Firefox\\firefox.exe'
  }
}

# %% [markdown]
# ### Define position and location

# %%
## Enter a job position
position = "data analyst"
## Enter a location (City, State or Zip or remote)
locations = "remote"

def get_url(position, location):
    url_template = "https://www.indeed.com/jobs?q={}&l={}"
    url = url_template.format(position, location)
    return url

url = get_url(position, locations)
dataframe = pd.DataFrame(columns=["Title", "Company", "Location", "Rating", "Date", "Salary", "Description", "Links"])

# %% [markdown]
# ### Scrape job postings

# %%
## Number of postings to scrape
postings = 1600

## Number of browser instances to use
n = 3

pages = list(range(0, postings, 7))

state = {
  'lock': asyncio.Lock(),
  'ids': set(),
  'n': 0
}
             
async def get_jobs(url, pages, state):
  data = []
  async with get_session(Geckodriver(binary=driver_path, log_file=asyncio.subprocess.PIPE), Firefox(**options)) as session:
    for i in pages:
      await session.get(url + "&start=" + str(i))
      jobs = await session.get_elements("[class='job_seen_beacon']")

      for job in jobs:
        result_html = await job.get_property('innerHTML')
        soup = BeautifulSoup(result_html, 'html.parser')

        liens = await job.get_elements("a")
        link = await liens[0].get_attribute("href")

        title = soup.select('.jobTitle')[0].get_text().strip()
        try:
          company = soup.select('.companyName')[0].get_text().strip()
        except:
          continue
        location = soup.select('.companyLocation')[0].get_text().strip()
        try:
            salary = soup.select('.salary-snippet-container')[0].get_text().strip()
        except:
            salary = 'NaN'
        try:
            rating = soup.select('.ratingNumber')[0].get_text().strip()
        except:
            rating = 'NaN'
        try:
            date = soup.select('.date')[0].get_text().strip()
        except:
            date = 'NaN'
        try:
            description = soup.select('.job-snippet')[0].get_text().strip()
        except:
            description = ''
            
        Id = f"{title}{company}{location}{rating}{date}{salary}{description}"
        dupe = False
        async with state['lock']:
          if Id in state['ids']:
            dupe = True
          else:
            state['ids'].add(Id)
            state['n'] = state['n'] + 1
            print("Job number {0:4d} added - {1:s}".format(state['n'],title))
        if dupe:
          continue

        data.append({
          'Title': title,
          "Company": company,
          'Location': location,
          'Rating': rating,
          'Date': date,
          "Salary": salary,
          "Description": description,
          "Links": link
        })

        # print("Job number {0:4d} added - {1:s}".format(jn,title))
      i = i + 10
  return data

tasks = [asyncio.create_task(get_jobs(url, p, state)) for p in np.array_split(pages, n)]
dataframe = pd.DataFrame([j for task in tasks for j in await task])
# Out:
# Job number    1 added - Sr. Data Analyst
# Job number    2 added - Data Reporting and Analytics Consultant II, Cost and Managerial Accounting *REMOTE*
# Job number    3 added - Sr. Business Intelligence Analyst
# Job number    4 added - IT BUSINESS SYSTEMS ANALYST SENIOR
# Job number    5 added - Analyst, Value-Based Care
# Job number    6 added - Product Analyst
# Job number    7 added - IT Project Business Analyst - Remote
# Job number    8 added - Agile Business Analyst (Hybrid)
# Job number    9 added - Senior Associate, Digital Data Analyst/Architect
# Job number   10 added - Sr. Business Intelligence Analyst
# Job number   11 added - Data Analyst Level 2 (W2 ONLY)(REMOTE)
# Job number   12 added - Data Analyst/Business Intelligence Developer
# Job number   13 added - Business Analyst - Remote
# Job number   14 added - Sr Risk Score Data Analyst, remote
# Job number   15 added - Functional Analyst, Senior
# Job number   16 added - AWS Data & Reporting Analyst
# Job number   17 added - Security Analyst II
# Job number   18 added - Senior Data Analyst
# Job number   19 added - Data Analyst, Advanced Excel
# Job number   20 added - Business Analyst – Gift Management System (work from home)
# Job number   21 added - Business Analyst
# Job number   22 added - Senior Analyst
# Job number   23 added - Business Information Analyst II
# Job number   24 added - Operations Business Analyst III
# Job number   25 added - Data Analyst
# Job number   26 added - JC-356882 - Telework Option - Contract Analyst
# Job number   27 added - Data Analyst
# Job number   28 added - Sr. Data Analyst-Cloud
# Job number   29 added - Senior AWS Data Engineer / Analyst
# Job number   30 added - Lead Business Analyst
# Job number   31 added - Data Analyst (Training and Placement)
# Job number   32 added - Data and Integration Analyst
# Job number   33 added - Data Analyst I
# Job number   34 added - JC-343578 - Telework Option - Administrative Analyst
# Job number   35 added - Junior Data Analyst
# Job number   36 added - Pharmaceutical Business / Product Analyst
# Job number   37 added - Data Analyst - RWD
# Job number   38 added - Lead Data Analyst (P2172)
# Job number   39 added - Data Analyst
# Job number   40 added - Public Comment Data Processing Analyst
# Job number   41 added - Data Analyst
# Job number   42 added - Benefits Data Compliance and Projects Analyst
# Job number   43 added - Data Analyst
# Job number   44 added - Business Analyst
# Job number   45 added - Senior Data Analyst
# Job number   46 added - Senior Analyst, Business Intelligence
# Job number   47 added - Data Services - Analyst
# Job number   48 added - Healthcare Data Analyst
# Job number   49 added - Senior Data Analyst
# Job number   50 added - Data Analyst Specialist
# Job number   51 added - Enterprise Business Analyst 1 or 2 (Remote Eligible)
# Job number   52 added - Data Operations Analyst
# Job number   53 added - Data Governance Technical Analyst
# Job number   54 added - Data Analyst
# Job number   55 added - Senior Health Data Analyst
# Job number   56 added - Senior Data Analyst II (Remote)
# Job number   57 added - Data Systems Analyst - Fully Remote
# Job number   58 added - Sr Risk Score Data Analyst, remote
# Job number   59 added - Business Data Quality Analyst Co-op (Summer/Fall 2023) (Remote)
# Job number   60 added - Business Analytics - Senior Analyst (Work from home)
# Job number   61 added - Data Analyst
# Job number   62 added - Senior Business Data Analyst
# Job number   63 added - Data Analyst (Remote)
# Job number   64 added - Business Analyst III
# Job number   65 added - Data Analyst
# Job number   66 added - Reimbursement Analyst III - Work From Home
# Job number   67 added - Data Analyst- Supply Chain Operations Intelligence(Remote Or Hybrid)
# Job number   68 added - HR Reporting and Data Analyst (REMOTE)
# Job number   69 added - Data Analyst
# Job number   70 added - Data Analyst
# Job number   71 added - Senior Data Analyst
# Job number   72 added - Learning Data Analyst
# Job number   73 added - Data Analyst(PowerBI,Analytics,Dashboard,Patient Service)
# Job number   74 added - Data Analyst (Remote)
# Job number   75 added - Data Analyst, Remote, Only W2
# Job number   76 added - Business Analytics Lead Analyst - eMOS Implementation - Remote
# Job number   77 added - Senior Business Analyst - Remote
# Job number   78 added - Genesys Business Analyst with AI and CX Experience
# Job number   79 added - Data Analyst (Data Management)
# Job number   80 added - Data Analyst
# Job number   81 added - Payment Operations Analyst
# Job number   82 added - Roofing and Building Business Analyst
# Job number   83 added - Business Analyst
# Job number   84 added - Data Analyst, Product
# Job number   85 added - Data Analyst
# Job number   86 added - DMARC/ Business Analyst
# Job number   87 added - Business Analyst
# Job number   88 added - Business Analyst
# Job number   89 added - Lead Business Analyst
# Job number   90 added - Senior Business Analyst (Remote)
# Job number   91 added - Business Intelligence Analyst
# Job number   92 added - Data Analyst
# Job number   93 added - Data Analyst - Level II #1857
# Job number   94 added - Senior Marketing Data Analyst
# Job number   95 added - Associate Business Analyst
# Job number   96 added - Data Analyst - Payments Fraud
# Job number   97 added - Business Analyst
# Job number   98 added - Business Intelligence Analyst (Virtual Opportunity)
# Job number   99 added - Data Analyst Consultant
# Job number  100 added - Data Analyst
# Job number  101 added - Data Analyst/Engineer
# Job number  102 added - Data Analyst - Machine Learning
# Job number  103 added - Data Analyst
# Job number  104 added - Data Analyst
# Job number  105 added - Data Analyst
# Job number  106 added - Senior Data Analyst
# Job number  107 added - Data Analyst
# Job number  108 added - Data Analyst
# Job number  109 added - Donor Data Analyst
# Job number  110 added - Senior Data Analyst
# Job number  111 added - Data Analyst
# Job number  112 added - Data Analyst, eCommerce
# Job number  113 added - Metaverse Data Analyst
# Job number  114 added - Data Analyst
# Job number  115 added - Data Analyst
# Job number  116 added - Senior Data Analyst
# Job number  117 added - Data Analyst
# Job number  118 added - Research Data Analyst II
# Job number  119 added - Senior Data Analyst (Product Analytics)
# Job number  120 added - Senior Data Analyst
# Job number  121 added - Data Analyst
# Job number  122 added - Sr. Data Analyst
# Job number  123 added - Hydrographic Data Analyst
# Job number  124 added - Data Analyst/Engineer
# Job number  125 added - Business Analyst
# Job number  126 added - Remote - Reporting Analytics Risk Analyst *Must Reside in GA, SC, TN, FL or AL*
# Job number  127 added - Senior Business Analyst
# Job number  128 added - Business Intelligence Analyst
# Job number  129 added - Business Intelligence Analyst
# Job number  130 added - Business Analyst
# Job number  131 added - Business Analyst
# Job number  132 added - Business Analyst III
# Job number  133 added - Data Analyst/Engineer (Remote)
# Job number  134 added - HRIS Analyst III
# Job number  135 added - HR Analyst II
# Job number  136 added - Analyst
# Job number  137 added - Senior Data Analyst
# Job number  138 added - Data Analyst
# Job number  139 added - Senior Data Analyst (Product Analytics)
# Job number  140 added - Sr. Data Analyst
# Job number  141 added - Sr. Business Analyst
# Job number  142 added - Capital Markets Analyst
# Job number  143 added - CRM Business Analyst
# Job number  144 added - Senior Analyst, Portfolio Analytics
# Job number  145 added - Business Analyst
# Job number  146 added - Data Analyst (ORS/CQCT)
# Job number  147 added - IT Data Visualization Specialist (VA41)
# Job number  148 added - Business Analyst - Managed Care
# Job number  149 added - HEOR Sr. Data Analyst
# Job number  150 added - Business Analyst
# Job number  151 added - Advanced Analytics Analyst
# Job number  152 added - Business Analyst, Remote (NY,NJ and CT only)
# Job number  153 added - Senior Data Analyst
# Job number  154 added - Business Intelligence Analyst
# Job number  155 added - Business Analyst III
# Job number  156 added - Business Data Analyst
# Job number  157 added - DATA ANALYST
# Job number  158 added - Data Analyst
# Job number  159 added - SQL Data and Operations Analyst - Fully Remote
# Job number  160 added - Data Analyst
# Job number  161 added - Data Quality Analyst
# Job number  162 added - Junior Data Analyst
# Job number  163 added - Data Analyst
# Job number  164 added - Data Analyst
# Job number  165 added - Data Support Analyst
# Job number  166 added - DATA ANALYST
# Job number  167 added - Business Data Analyst I- ADS Auxiliary Services
# Job number  168 added - Data Analyst
# Job number  169 added - DTC Data Analyst
# Job number  170 added - Sr. Data Analyst
# Job number  171 added - Quality Assurance Business Analyst
# Job number  172 added - Technical Risk Analyst
# Job number  173 added - Technical Business Analyst (contract)
# Job number  174 added - IT Business Analyst
# Job number  175 added - Data Analyst-Remote!
# Job number  176 added - BI Analyst
# Job number  177 added - Data Analyst/Engineer/Scientist
# Job number  178 added - Healthcare Industry Data Analyst (100% Remote)
# Job number  179 added - Data Analyst II
# Job number  180 added - Data Analyst
# Job number  181 added - Business Intelligence Analyst
# Job number  182 added - Data Health Analyst
# Job number  183 added - Data Analyst (Intermediate Level)
# Job number  184 added - Jr. Business Analyst
# Job number  185 added - Business Analyst (Must live within Sacramento California)
# Job number  186 added - Data Analyst (Warehouse Operations)
# Job number  187 added - Sr. Data Analyst
# Job number  188 added - Technical Data Analyst
# Job number  189 added - Associate Data Analyst
# Job number  190 added - Data Analyst
# Job number  191 added - Sr. BI Analyst
# Job number  192 added - Analyst II, Data
# Job number  193 added - Senior Data Analyst, Central Analytics
# Job number  194 added - IT Operations Data Analyst
# Job number  195 added - Data Analyst
# Job number  196 added - Healthcare Data Analyst
# Job number  197 added - Data Analyst (Remote)
# Job number  198 added - Data Analyst
# Job number  199 added - Senior Data Analyst
# Job number  200 added - Marketing Data Analyst (Remote)
# Job number  201 added - Business Analyst
# Job number  202 added - Data Specialist
# Job number  203 added - Business Systems/Data Analyst (Telework Available)
# Job number  204 added - Junior Technology Analyst - Integration and Analytics Track
# Job number  205 added - Data & Reporting Senior Analyst
# Job number  206 added - Senior IT Analyst
# Job number  207 added - Staff Business Data Analyst (Remote U.S. OK)
# Job number  208 added - Senior Business Analyst
# Job number  209 added - HIM Sr Analyst Coding Data Qual-Facil Based - Remote Opportunity
# Job number  210 added - Operations Data Analyst (Remote) (SAS Required)
# Job number  211 added - Data Governance & Security Analyst
# Job number  212 added - HR Data Analyst - Remote
# Job number  213 added - Sales and Marketing Analytics Analyst
# Job number  214 added - Business Analyst
# Job number  215 added - Sr Tech Analyst – Data
# Job number  216 added - Associate Cybersecurity & Data Privacy Analyst
# Job number  217 added - Data Analyst
# Job number  218 added - Data Analyst REMOTE
# Job number  219 added - Sr Provider Data Analyst - Remote
# Job number  220 added - Senior Data Analyst, Risk Adjustment
# Job number  221 added - Data Analyst
# Job number  222 added - HL7 Data Analyst
# Job number  223 added - Data Analyst
# Job number  224 added - Data Analyst - Contractor only
# Job number  225 added - Senior Data Analyst
# Job number  226 added - Data Analyst
# Job number  227 added - Data Analyst
# Job number  228 added - Senior Data Analyst
# Job number  229 added - Data Analyst
# Job number  230 added - Data Analyst
# Job number  231 added - Business Analyst, IT (Fully Remote or Hybrid)
# Job number  232 added - Financial and Customer Data Analyst
# Job number  233 added - Senior Business Analyst
# Job number  234 added - Data Analyst
# Job number  235 added - Sr. Programmer/Analyst (Data)
# Job number  236 added - Business Analyst - Remote
# Job number  237 added - Sr Business Analyst
# Job number  238 added - Financial Analyst
# Job number  239 added - Advanced Data Analyst
# Job number  240 added - Master Scheduler-Business Analyst -MS Project
# Job number  241 added - Senior Data Analyst
# Job number  242 added - Marketing Analyst - Contract
# Job number  243 added - Data Visualization Analyst
# Job number  244 added - Senior Business Intelligence Analyst
# Job number  245 added - Data Engineer / Data Analyst
# Job number  246 added - Data Analyst
# Job number  247 added - Data Analyst
# Job number  248 added - Sr. Data Analyst I
# Job number  249 added - Data Analyst
# Job number  250 added - Data Analyst (Looker)
# Job number  251 added - Data Analyst (Hybrid)
# Job number  252 added - Systems Business & Data Analyst
# Job number  253 added - Data Analyst, Integrations
# Job number  254 added - Data Reporting Analyst - Healthcare
# Job number  255 added - FROSCH - Senior Data and Reporting Analyst (FULLY REMOTE)
# Job number  256 added - Business Intelligence Analyst
# Job number  257 added - Senior Business Analyst (C)
# Job number  258 added - Senior Reporting Analyst, Government Programs
# Job number  259 added - Business Analyst
# Job number  260 added - (5) Data Analyst / Data Scientist
# Job number  261 added - Data Analyst
# Job number  262 added - Sales Operations Analyst
# Job number  263 added - Data Security Analyst
# Job number  264 added - Implementation Business Analyst
# Job number  265 added - Data Analytics Specialist [REMOTE]
# Job number  266 added - Lead IT Business Analyst
# Job number  267 added - Business Intelligence Analyst
# Job number  268 added - Enterprise Fraud Strategy Data Analyst
# Job number  269 added - Healthcare Business Analyst
# Job number  270 added - Sales Operations Analyst (remote role)
# Job number  271 added - SAP Data Analyst
# Job number  272 added - Senior Business Analyst - Credit Cards
# Job number  273 added - Business Intelligence Analyst
# Job number  274 added - PMO Business Analyst
# Job number  275 added - (REMOTE) Sr. Business Analyst - Engineering, Maintenance Safety Health and Environment
# Job number  276 added - Operations Controlling Data Analyst
# Job number  277 added - Data Analyst, E-commerce and DTC
# Job number  278 added - SQL Data Analyst
# Job number  279 added - Data Analyst
# Job number  280 added - Business Data Analyst (Remote)
# Job number  281 added - Business Analyst (Data Analytics) (Remote, Des Moines, IA)
# Job number  282 added - Data Analyst
# Job number  283 added - Data Analyst
# Job number  284 added - Data Analyst (Seattle or US Remote)
# Job number  285 added - Data Exchange Analyst
# Job number  286 added - Entry Level Business Analyst
# Job number  287 added - Senior Data Analyst (Remote Options Available for Preferred Candidate)
# Job number  288 added - 1099 Pharma Commercial Data Analyst
# Job number  289 added - Data Governance Analyst
# Job number  290 added - Senior Data Analyst
# Job number  291 added - Data Operations Analyst II
# Job number  292 added - Business Intelligence Analyst - LATAM
# Job number  293 added - Data Analyst
# Job number  294 added - Business Analyst (W2 Only)
# Job number  295 added - Business Analyst (Remote)
# Job number  296 added - Sr. Contract Analyst
# Job number  297 added - Business Analyst Sr. - Digital Experience
# Job number  298 added - Senior Marketing Data Analyst
# Job number  299 added - Data Analyst
# Job number  300 added - Senior Data Analyst
# Job number  301 added - Data Analyst
# Job number  302 added - Data Analyst
# Job number  303 added - Data Analyst
# Job number  304 added - Senior Data Analyst
# Job number  305 added - 10101 - Data Equity Analyst
# Job number  306 added - Senior Healthcare Data Analyst
# Job number  307 added - Data Analyst - Yardi
# Job number  308 added - Business Analyst
# Job number  309 added - Senior Data Analyst
# Job number  310 added - Business Analyst (CRM Analytics)
# Job number  311 added - Business Intelligence Analyst
# Job number  312 added - Business Analyst
# Job number  313 added - Business Analyst
# Job number  314 added - Business Analyst
# Job number  315 added - Associate Data Center Operations Analyst
# Job number  316 added - Business Analyst/Junior Solution Architect
# Job number  317 added - IT Business Analyst
# Job number  318 added - BI Data Administrator
# Job number  319 added - Data Analyst
# Job number  320 added - Data Analyst
# Job number  321 added - Senior Data Analyst - Finance
# Job number  322 added - Business Data Analyst (Remote)
# Job number  323 added - Business Systems Analyst
# Job number  324 added - Business Data Analyst
# Job number  325 added - Predictive Data Analyst - Remote Opportunity - SimioCloud
# Job number  326 added - Data Analyst - Senior Data Analyst
# Job number  327 added - Sr. Data Analyst, Cardiology Program
# Job number  328 added - Business Intelligence Analyst
# Job number  329 added - Data Analyst - Marketing
# Job number  330 added - Risk Analyst
# Job number  331 added - Business Analyst - EDI
# Job number  332 added - Sr. Business Analyst
# Job number  333 added - GRC Business Analyst
# Job number  334 added - Operations Analyst – Evernorth Care Group – Remote
# Job number  335 added - Business Analyst - EDI
# Job number  336 added - Senior Marketing Data Analyst – Channel Optimization - Remote
# Job number  337 added - Data Governance Analyst---Remote (GC and Citizens)
# Job number  338 added - BA/QA
# Job number  339 added - Data Analyst
# Job number  340 added - Business Analyst II
# Job number  341 added - Data Analyst- IT (Fully Remote)
# Job number  342 added - Sr. Product Data Analyst
# Job number  343 added - Data Acquisition and Optimization Analyst
# Job number  344 added - Business Analyst
# Job number  345 added - Data Analyst - REQ 617
# Job number  346 added - Sr. Data Analyst
# Job number  347 added - Junior Business Analyst
# Job number  348 added - CRM Data Analyst
# Job number  349 added - Senior Data Analyst
# Job number  350 added - Lead Data Analyst
# Job number  351 added - Sr. Data Analyst (Partner Analytics)
# Job number  352 added - Data Visualization Specialist
# Job number  353 added - Data/Project Analyst
# Job number  354 added - Data Analyst
# Job number  355 added - Financial Data Analyst
# Job number  356 added - Business Analyst - Fully Remote
# Job number  357 added - Data Analyst - Local Remote
# Job number  358 added - Associate Data Analyst
# Job number  359 added - Business Analyst
# Job number  360 added - Data Analyst
# Job number  361 added - Data Analyst Contract Exclusions
# Job number  362 added - Sr. Data Analyst (Product)
# Job number  363 added - Senior Data Analyst (HEDIS & Performance Specialist)
# Job number  364 added - Pharma Master Data Business Analyst
# Job number  365 added - Data Analyst-Assessment Developer
# Job number  366 added - Data Analyst
# Job number  367 added - Senior Data Analyst (Remote)
# Job number  368 added - Senior Data Analyst
# Job number  369 added - Senior Business Analyst
# Job number  370 added - Senior Data Analyst
# Job number  371 added - Data Analyst
# Job number  372 added - Revenue Cycle Data Analyst (100% Remote)
# Job number  373 added - Sr. Data Analyst
# Job number  374 added - Business Analyst (LIMS)
# Job number  375 added - Embedded Senior Data Analyst SIBU510
# Job number  376 added - Senior Data Analyst
# Job number  377 added - Research Data Analyst 1 (Remote)
# Job number  378 added - Data Analyst
# Job number  379 added - Business Analyst
# Job number  380 added - Scientific Data Analyst
# Job number  381 added - Data Visualization specialist REMOTE
# Job number  382 added - Senior Data Analyst, Product Analytics
# Job number  383 added - JC-348370 - Telework Option - Data Analyst
# Job number  384 added - Data Analyst, Performance Marketing
# Job number  385 added - Business Systems Analyst
# Job number  386 added - EDI Analyst
# Job number  387 added - Senior Analyst, Airbnb for Real Estate
# Job number  388 added - Data Conversion Analyst
# Job number  389 added - EHR Data Analyst
# Job number  390 added - Sr. Data Analyst, Electric Vehicles
# Job number  391 added - Campaign Analyst
# Job number  392 added - Data Analyst
# Job number  393 added - Data Analyst
# Job number  394 added - Senior Data Analyst
# Job number  395 added - IT Data Analyst II
# Job number  396 added - Marketing Insights Data Analyst
# Job number  397 added - Data Analyst II
# Job number  398 added - Business Analyst - Cloud Migration
# Job number  399 added - Senior Risk Adjustment Data Analyst 8332 REMOTE
# Job number  400 added - Data Analyst (Remote)
# Job number  401 added - Senior Data Analyst
# Job number  402 added - Sr Business Analyst
# Job number  403 added - Senior Data Analyst
# Job number  404 added - Business Intelligence Analyst
# Job number  405 added - Sr. Contract Analyst
# Job number  406 added - Business Analyst
# Job number  407 added - IT Business Analyst
# Job number  408 added - BI Data Administrator
# Job number  409 added - Data Analyst/Engineer/Scientist
# Job number  410 added - Data Business Intelligence Analyst II
# Job number  411 added - Sr. Business Data Analyst
# Job number  412 added - Data Analyst (Dealer Development)
# Job number  413 added - Clinical Data Analyst II
# Job number  414 added - Business Analyst
# Job number  415 added - Data Analyst, Marketing
# Job number  416 added - Research Data Analyst
# Job number  417 added - Sr. Data Analyst, Collections (REMOTE)
# Job number  418 added - Marketing Data Analyst
# Job number  419 added - Data Analyst, Valuation
# Job number  420 added - Business Analyst
# Job number  421 added - Senior Business Analyst
# Job number  422 added - Healthcare Analyst - Operations Data Analyst
# Job number  423 added - Senior Business Analyst
# Job number  424 added - Business Intelligence Analyst
# Job number  425 added - Sr. Contract Analyst
# Job number  426 added - Business Analyst
# Job number  427 added - Business Analyst
# Job number  428 added - Business Analyst
# Job number  429 added - Associate Data Center Operations Analyst
# Job number  430 added - Business Analyst/Junior Solution Architect
# Job number  431 added - IT Business Analyst
# Job number  432 added - BI Data Administrator
# Job number  433 added - Data Analyst/Engineer/Scientist
# Job number  434 added - Sales Operations Analyst (remote role)
# Job number  435 added - HIM Sr Analyst Coding Data Qual-Facil Based - Remote Opportunity
# Job number  436 added - Risk Analyst
# Job number  437 added - Business Analyst - EDI
# Job number  438 added - Associate Analyst, Customer Data (REMOTE)
# Job number  439 added - Senior Marketplace Insights Data Analyst
# Job number  440 added - Data Analyst - Health Plan Member Analytics - 100% Remote
# Job number  441 added - Clinical Data Analyst
# Job number  442 added - Business Analyst
# Job number  443 added - Enterprise Data Warehouse Analyst
# Job number  444 added - Sr Business Analyst
# Job number  445 added - Business Analyst
# Job number  446 added - Data Analyst
# Job number  447 added - Data Modeler/Data Analyst
# Job number  448 added - Data Analyst III - Healthcare - Remote
# Job number  449 added - Recruitment and Retention Data Analyst - SFPD (1823)
# Job number  450 added - Technical Analyst - EDW and Data Lake
# Job number  451 added - Data Analyst
# Job number  452 added - Policy Implementation and Data Analyst - HL7/FHIR- Remote
# Job number  453 added - Business Analyst
# Job number  454 added - REMOTE | Provider Network Data Oversight Analyst Network Pricing
# Job number  455 added - M&E Business Intelligence Research Analyst II and III
# Job number  456 added - SEO Analyst
# Job number  457 added - Sr Analyst - Automation Business Intelligence
# Job number  458 added - Data Measurement & Reporting Senior Analyst - Evernorth Health Services - Remote
# Job number  459 added - IT Business Analyst
# Job number  460 added - Health Data Visualization Analyst (Remote position)
# Job number  461 added - Insurance Data Analyst
# Job number  462 added - Data Analyst, High School Study Abroad
# Job number  463 added - Healthcare Data Analyst
# Job number  464 added - Data Analyst
# Job number  465 added - Data Analyst
# Job number  466 added - QNXT Business Analyst
# Job number  467 added - Health Plan Data Analyst
# Job number  468 added - Client-Facing Marketing Data Analyst (Remote)
# Job number  469 added - REMOTE | Provider Network Data Oversight Analyst Network Pricing
# Job number  470 added - Data Analyst
# Job number  471 added - Compliance Analyst
# Job number  472 added - Marketing Data Analyst (remote)
# Job number  473 added - Business Analyst
# Job number  474 added - Lead Data Analyst
# Job number  475 added - Reimbursement Analyst III - Work From Home
# Job number  476 added - Clinical Data Analyst
# Job number  477 added - Data Analyst
# Job number  478 added - Data and Business Analyst, Customer Operations (Remote)
# Job number  479 added - Data Systems Analyst 3 - Enterprise Data and Analytics - FT Days (Remote)
# Job number  480 added - Data Analyst
# Job number  481 added - Sr. Data Analyst
# Job number  482 added - EDI Analyst
# Job number  483 added - Data/Business Analyst
# Job number  484 added - Medical Data Analyst (Medical Coder)
# Job number  485 added - Senior Healthcare Data Analyst
# Job number  486 added - Senior Healthcare Data Analyst Remote
# Job number  487 added - Senior Data Analyst
# Job number  488 added - Data Viz Analyst (241)
# Job number  489 added - Health Information Technology Data Analytics Analyst I, II, or III
# Job number  490 added - Jr. Business/Data Systems Analyst - BDSA1601
# Job number  491 added - Senior Data Analyst
# Job number  492 added - Business Analyst
# Job number  493 added - Social Media Data Analyst
# Job number  494 added - Data Analyst Remote
# Job number  495 added - Data Analyst (Case Management Experience)
# Job number  496 added - Data Analyst
# Job number  497 added - Data Analyst
# Job number  498 added - ECOSYSTEM DATA ANALYST
# Job number  499 added - Data & Compliance Analyst
# Job number  500 added - IT Business Analyst
# Job number  501 added - Data Analyst
# Job number  502 added - Lead IT Data Analyst
# Job number  503 added - Data Systems Analyst -100% remote in Texas
# Job number  504 added - Healthcare Data Analyst
# Job number  505 added - Data Analyst
# Job number  506 added - Data & Compliance Analyst
# Job number  507 added - IT Business Analyst
# Job number  508 added - Clinical Data Analyst II
# Job number  509 added - Data Analyst
# Job number  510 added - SQL Developer/Data Analyst
# Job number  511 added - Material Data Analyst
# Job number  512 added - Data Quality Analyst (REMOTE)
# Job number  513 added - Teamcenter BA
# Job number  514 added - Data Analyst I/II
# Job number  515 added - Data Analyst
# Job number  516 added - Privacy Data Analyst
# Job number  517 added - Data Conversion Analyst
# Job number  518 added - IT Operations Data Analyst
# Job number  519 added - Data Governance Analyst (Remote)
# Job number  520 added - Business Analyst
# Job number  521 added - Business Intelligence Analyst
# Job number  522 added - Associate Data Analyst
# Job number  523 added - Business Analyst
# Job number  524 added - Data Analyst (Remote)
# Job number  525 added - Business Analyst- Contact Center
# Job number  526 added - Data Analyst - Data Operations
# Job number  527 added - IT Business/ Data Analyst :: 100% Remote
# Job number  528 added - Data Analyst - eCommerce
# Job number  529 added - SAS Analyst
# Job number  530 added - Business Analyst
# Job number  531 added - Data Governance Analyst
# Job number  532 added - Curriculum Developer- Business/Data Analytics:
# Job number  533 added - Business Analyst
# Job number  534 added - Business Intelligence Analyst
# Job number  535 added - REMOTE | Provider Network Data Oversight Analyst Network Pricing
# Job number  536 added - M&E Business Intelligence Research Analyst II and III
# Job number  537 added - SEO Analyst
# Job number  538 added - Sr Analyst - Automation Business Intelligence
# Job number  539 added - Data Specialist
# Job number  540 added - Data Analyst (ORS/CQCT)
# Job number  541 added - Sr Risk Score Data Analyst, remote
# Job number  542 added - Data Measurement & Reporting Senior Analyst - Evernorth Health Services - Remote
# Job number  543 added - Business Analyst
# Job number  544 added - Data and Reporting Analyst
# Job number  545 added - Data Analyst - Ad Tech - Remote
# Job number  546 added - Blockchain Data Analyst
# Job number  547 added - Analyst 2 - Clinical Data (contract)
# Job number  548 added - PMO Business Analyst
# Job number  549 added - EMDM Senior Data Quality Analyst
# Job number  550 added - Senior Data Analytics Analyst - Remote
# Job number  551 added - Data Analyst
# Job number  552 added - Business Analyst
# Job number  553 added - GIDP - Business Analyst
# Job number  554 added - Healthcare Analyst
# Job number  555 added - Business Analyst - Remote (WFH)
# Job number  556 added - Data Analyst
# Job number  557 added - Data Analyst
# Job number  558 added - IT Business Analyst
# Job number  559 added - Reimbursement Analyst III - Work From Home
# Job number  560 added - Data Analyst II World Trade Center Health Program
# Job number  561 added - Data Analyst
# Job number  562 added - Data Analyst (Case Management Experience)
# Job number  563 added - Implementation Business Analyst
# Job number  564 added - Data Analyst (Intermediate Level)
# Job number  565 added - Business Analyst
# Job number  566 added - Data Analyst/Purchasing Coordinator
# Job number  567 added - Remote Junior Data Analyst
# Job number  568 added - Enterprise Data Warehouse Data Analyst/Quality Analyst
# Job number  569 added - Data Business Intelligence Analyst II
# Job number  570 added - BI Data Analyst IV
# Job number  571 added - Reporting Analyst
# Job number  572 added - Senior Data Analyst
# Job number  573 added - HR Data Analyst
# Job number  574 added - Healthcare Data Analyst
# Job number  575 added - Senior Data Analyst - Remote Eligible
# Job number  576 added - Business Analyst
# Job number  577 added - Sr. Business Analyst
# Job number  578 added - Sr Biomarker Data Analyst
# Job number  579 added - Data Analyst
# Job number  580 added - Implementation Business Analyst
# Job number  581 added - Data Analyst
# Job number  582 added - Market Data Analyst
# Job number  583 added - Provider Data Analyst - Remote
# Job number  584 added - Data Analyst
# Job number  585 added - Healthcare Data Analyst: Government Revenue (Remote)
# Job number  586 added - Business Analyst
# Job number  587 added - Senior Data Analyst
# Job number  588 added - Sr Data Quality Analyst (Remote)
# Job number  589 added - Lead Business Intelligence Analyst
# Job number  590 added - Data Analyst, Privacy
# Job number  591 added - Senior Data Analyst
# Job number  592 added - Senior Data Analyst (Virtual Opportunity)
# Job number  593 added - Data Analyst
# Job number  594 added - Healthcare Economics Data Analyst
# Job number  595 added - Hydrologic Data Analyst (0478) (Hybrid-Remote Eligible)
# Job number  596 added - ProServices Program Analyst-Remote
# Job number  597 added - BI Developer / Analyst
# Job number  598 added - Business Systems Analyst IV
# Job number  599 added - Remote - IT Senior Business Analyst
# Job number  600 added - Analytics Implemented Solutions Analyst, Loan Servicing
# Job number  601 added - Business Analyst
# Job number  602 added - Lead Medicare Stars Data Analyst
# Job number  603 added - Philanthropy Data Analyst
# Job number  604 added - Business Analyst (Tableau)
# Job number  605 added - IT Business Analyst - REMOTE
# Job number  606 added - Commodity Risk Analyst
# Job number  607 added - Resource Management Analyst III: Business Services (Austin District)
# Job number  608 added - Business Analyst- Behavioral Healthcare Systems- Clinical
# Job number  609 added - Business Analyst
# Job number  610 added - I.T. Data Analyst
# Job number  611 added - Sr. Data Visualization Analyst (305)
# Job number  612 added - SAFETY & RISK DATA ANALYST (REMOTE)
# Job number  613 added - Senior Data Analyst
# Job number  614 added - Agile Business Analyst
# Job number  615 added - Quality Measurement Analyst (Analytics and Data Science, Remote)
# Job number  616 added - Associate Business Data Support Analyst
# Job number  617 added - Remote - Data Analysis and Visualization Specialist
# Job number  618 added - Senior Business Analyst
# Job number  619 added - HR Data Analyst I - 1.0 FTE - Human Resources
# Job number  620 added - Business Analyst
# Job number  621 added - Sr. Data Analyst, Pricing & Packaging
# Job number  622 added - Remote MES BA/Technical Writer 707648
# Job number  623 added - Lead Data Analyst
# Job number  624 added - P2P Analyst - Data Management
# Job number  625 added - Ecommerce Business Analyst
# Job number  626 added - SEM Data Analyst
# Job number  627 added - Business Analyst
# Job number  628 added - Sr. Data Analyst, Pricing & Packaging
# Job number  629 added - Lead Data Analyst
# Job number  630 added - Ecommerce Business Analyst
# Job number  631 added - Data Analyst
# Job number  632 added - Senior Data Analyst
# Job number  633 added - Senior Data Analyst
# Job number  634 added - Data Analyst
# Job number  635 added - Business Analyst - Remote (WFH)
# Job number  636 added - Product Analyst
# Job number  637 added - Big Data Analyst
# Job number  638 added - Data Analyst/Contract with Defense Health Agency
# Job number  639 added - Business Analyst, Senior - Data Analytics: 100% Remote US
# Job number  640 added - Payor Data Analyst - Remote
# Job number  641 added - Data Analyst (Remote)
# Job number  642 added - Trade & Syndicated Data Analyst
# Job number  643 added - Agile Business Analyst
# Job number  644 added - Provider Roster Data Analyst
# Job number  645 added - Data Analyst
# Job number  646 added - Business Analyst - Remote
# Job number  647 added - Senior Data Analyst
# Job number  648 added - Remote - IT Senior Business Analyst
# Job number  649 added - Analytics Implemented Solutions Analyst, Loan Servicing
# Job number  650 added - Lead Medicare Stars Data Analyst
# Job number  651 added - Business Analyst - Managed Care
# Job number  652 added - Data Analyst Specialist
# Job number  653 added - Philanthropy Data Analyst
# Job number  654 added - Business Analyst (Tableau)
# Job number  655 added - IT Business Analyst - REMOTE
# Job number  656 added - Business Analyst- Behavioral Healthcare Systems- Clinical
# Job number  657 added - Commodity Risk Analyst
# Job number  658 added - Resource Management Analyst III: Business Services (Austin District)
# Job number  659 added - Business Analyst
# Job number  660 added - Business Analyst - Remote
# Job number  661 added - Remote MES BA/Technical Writer 707648
# Job number  662 added - Business Analyst
# Job number  663 added - Senior Data Analyst, Research Success
# Job number  664 added - Research/Data Analyst
# Job number  665 added - Business System Data Analyst
# Job number  666 added - Senior Financial Data Analyst
# Job number  667 added - Data Analyst
# Job number  668 added - Senior Data Analyst
# Job number  669 added - Senior Data Science Analyst
# Job number  670 added - Procurement Data Analyst - Remote AZ
# Job number  671 added - Benefit Marketing Analyst - Remote
# Job number  672 added - Business Analyst - Managed Care
# Job number  673 added - Business Analyst- Behavioral Healthcare Systems- Clinical
# Job number  674 added - Senior Data Analyst
# Job number  675 added - Business System Data Analyst
# Job number  676 added - Benefit Marketing Analyst - Remote
# Job number  677 added - Senior Data Analyst (Customer Experience) - Remote
# Job number  678 added - Business Intelligence (BI) /Data Analyst (DeFi) - Digital Assets
# Job number  679 added - Business Intelligence (BI) /Data Analyst (DeFi) - Digital Assets
# Job number  680 added - Senior Data Analyst (Customer Experience) - Remote
# Job number  681 added - Business Analyst
# Job number  682 added - Analyst - People Analytics
# Job number  683 added - Business Analyst - Smartsheet - Remote
# Job number  684 added - Business Analyst
# Job number  685 added - Data Analyst
# Job number  686 added - Music Royalty Analyst
# Job number  687 added - HMIS Data Analyst
# Job number  688 added - Lead Data Analyst
# Job number  689 added - Sr. Data Analyst
# Job number  690 added - Business Analyst
# Job number  691 added - Junior Business Analyst
# Job number  692 added - Management and Program Analyst
# Job number  693 added - Data Governance Analyst
# Job number  694 added - Business Analyst
# Job number  695 added - Data Transformation Analyst II/Customer Support Associate
# Job number  696 added - Business Data Analyst II
# Job number  697 added - AI Machine Learning Data Analyst
# Job number  698 added - Data Analyst
# Job number  699 added - SAP Finance Data Analyst
# Job number  700 added - Data Informatics Analyst(ServiceNow)
# Job number  701 added - Data Hacker / Analyst
# Job number  702 added - Associate Analyst, Data Intelligence
# Job number  703 added - Information Technology Business Analyst
# Job number  704 added - Analyst, Business Intelligence
# Job number  705 added - Data Analyst
# Job number  706 added - IT BUSINESS SYSTEMS ANALYST SENIOR
# Job number  707 added - IT Mobility Support Technician (IT Support) - REMOTE US
# Job number  708 added - Quality Data Analyst
# Job number  709 added - Data Analyst ll, Ecommerce Product Analytics - Remote
# Job number  710 added - Data Analyst (Mobile UA & Growth)
# Job number  711 added - Data Analyst- Capital market domain
# Job number  712 added - Utility Billing Analyst
# Job number  713 added - Senior Data Analyst
# Job number  714 added - Insurance Technology Analyst- Data Operations
# Job number  715 added - Business Analyst | REMOTE
# Job number  716 added - Junior Data Analyst
# Job number  717 added - Data Analyst
# Job number  718 added - Sr. Fraud Data Analyst
# Job number  719 added - Business Analyst
# Job number  720 added - Sr. Business Analyst - Aspen Enterprise IP.21
# Job number  721 added - Business Analyst
# Job number  722 added - Bilingual Enrollment Data Analyst II (contract)
# Job number  723 added - Data Analyst - CropSights, a Precision Ag Platform (Remote - Must Be Located In Cascades Area - Washington State)
# Job number  724 added - Sr. Data Analyst
# Job number  725 added - Senior Business Data Analyst (REMOTE)
# Job number  726 added - IT Business Analyst
# Job number  727 added - Directory Services Data Analyst (REMOTE)
# Job number  728 added - Business Analyst (Remote)
# Job number  729 added - AAPI Data Senior Research Analyst
# Job number  730 added - Data Analyst (Remote-Philippines Only-Contractor)
# Job number  731 added - Senior Data Analyst
# Job number  732 added - Healthcare Data Analyst
# Job number  733 added - Data Analyst - Consumer/Small Business
# Job number  734 added - Business Analyst/PM
# Job number  735 added - Business Analyst
# Job number  736 added - Ombudsman Data Analyst / Management Analyst 4
# Job number  737 added - Intelligence Analyst
# Job number  738 added - Data & Reporting Analyst Sr
# Job number  739 added - TECHNICAL BUSINESS ANALYST - MOBILE ORDERING & MENU CONFIGURATION
# Job number  740 added - IT BI/ Data Reporting Analyst (VA81)
# Job number  741 added - IT Data Analyst (Remote Possible)
# Job number  742 added - BUSINESS SYSTEMS DATA ANALYST
# Job number  743 added - Apptio Expert Data Analyst
# Job number  744 added - Senior Data Health Analyst
# Job number  745 added - Data Analyst -128361
# Job number  746 added - Senior Data Analyst (Remote)
# Job number  747 added - Senior Market Data Analyst
# Job number  748 added - Sr. Data Analyst (Remote Possible)
# Job number  749 added - Competitive Intelligence Analyst, Data Protection (Remote)
# Job number  750 added - Business Analyst
# Job number  751 added - Data Analytics Business Analyst
# Job number  752 added - Business Analyst I- REMOTE
# Job number  753 added - Data/Marketing Analyst - AIU (Data Analysis/Data Science, Tableau, Excel, Google Analytics, BigQuery, SQL, Visual Basic, R & Python
# Job number  754 added - Claims, Business Analyst - Work from Home
# Job number  755 added - Business Analyst
# Job number  756 added - Criminal Data Entry Analyst (REMOTE)
# Job number  757 added - Brand Protection Analyst
# Job number  758 added - Senior Data Science Analyst
# Job number  759 added - Sr. Data Analyst, Clinical and Quality Analytics
# Job number  760 added - Business Analyst
# Job number  761 added - Product Data Analyst (Remote)
# Job number  762 added - Sr. Analyst
# Job number  763 added - Web Marketing Data Analyst
# Job number  764 added - Senior Data Analyst
# Job number  765 added - Banking Operations Data Analyst
# Job number  766 added - Business Analyst
# Job number  767 added - Data Modeling Analyst
# Job number  768 added - Staff Business Systems Analyst - Data Science
# Job number  769 added - Senior Marketing Data Analyst
# Job number  770 added - Data and Sales Operations Analyst
# Job number  771 added - Senior IT Data Analyst
# Job number  772 added - Master Data Management Analyst
# Job number  773 added - Analyst (Shopify Landing Page Optimization)
# Job number  774 added - Analyst Data-Cancer Registry Remote
# Job number  775 added - Data Analyst- IT (Fully Remote)
# Job number  776 added - Business Intelligence Analyst II (Work From Home)
# Job number  777 added - Lead Business Data Analyst
# Job number  778 added - Senior Systems Analyst with SAP data warehouse background
# Job number  779 added - Sr. Business Analyst
# Job number  780 added - Business Analyst
# Job number  781 added - Data Scientist / Data Analyst
# Job number  782 added - Information Protection Data Analyst - Remote
# Job number  783 added - Senior Reporting Analyst (Remote)
# Job number  784 added - Senior Healthcare Data Analyst
# Job number  785 added - Data Analyst, Solutions Measurement
# Job number  786 added - Business Analyst 4
# Job number  787 added - Operations Data Analyst - AZ Remote
# Job number  788 added - Business Analyst (Remote - U.S. only)
# Job number  789 added - Capture Data Analyst
# Job number  790 added - Data Modeling Analyst II-Experian Clarity Services (Remote Position)
# Job number  791 added - HR Systems & Data Senior Analyst
# Job number  792 added - Senior Data Analyst
# Job number  793 added - Data Warehouse Analyst
# Job number  794 added - Sr. Data Analyst I
# Job number  795 added - HCM Business Analyst
# Job number  796 added - Senior Data Analyst
# Job number  797 added - Data Analyst - Business Development (Full Time/Part Time)
# Job number  798 added - Business Analyst - Specialty Pharmacy
# Job number  799 added - Business Analyst
# Job number  800 added - Lead Data and Reporting Analyst Call Center
# Job number  801 added - Senior Product Data Analyst - Fully Remote
# Job number  802 added - Database Analyst/Administrator - IM-Data Services
# Job number  803 added - Marketing Data Analyst
# Job number  804 added - Analytics & Insights Analyst
# Job number  805 added - Senior Financial Data Analyst - Health Care Industry
# Job number  806 added - Contract Activation Analyst (Remote)
# Job number  807 added - Customer Data Integration Analyst
# Job number  808 added - Analyst, Business Intelligence
# Job number  809 added - Procurement Data Analyst
# Job number  810 added - Senior Labor Market Data Analyst
# Job number  811 added - Marketing Data Analyst
# Job number  812 added - Senior Business Intelligence Analyst
# Job number  813 added - Data Analyst with Mainframe Data
# Job number  814 added - Senior Data Analyst
# Job number  815 added - Senior Data Analyst - Remote
# Job number  816 added - Health Informatics Data Analyst (NC30)
# Job number  817 added - Clinical Research Data Analyst-Engineer
# Job number  818 added - Business Analyst Consultant - Remote
# Job number  819 added - Senior Data Analyst - Yardi
# Job number  820 added - Sr. Data Analyst, Web Experimentation
# Job number  821 added - Data Privacy Compliance Analyst
# Job number  822 added - Data Analyst
# Job number  823 added - Associate Data Analyst - Marketing - Remote
# Job number  824 added - Data Analyst
# Job number  825 added - Digital Data Analyst (Google Analytics)- Remote
# Job number  826 added - Advocacy Data Analyst
# Job number  827 added - Business Analyst – West Coast
# Job number  828 added - Operations Data Analyst
# Job number  829 added - Senior People Analyst
# Job number  830 added - Business Analyst
# Job number  831 added - Analyst, Finance & Analytics (SQL Programming) - REMOTE
# Job number  832 added - Remote Senior Technical Business Analyst
# Job number  833 added - Business Analyst
# Job number  834 added - PMO Support Analyst
# Job number  835 added - Senior Analyst Risk Analytics & Strategy
# Job number  836 added - Business Analyst*
# Job number  837 added - Marketing Campaign Analyst, Advisors Plus
# Job number  838 added - Finance Data Analyst
# Job number  839 added - Associate IT Analyst - Manufacturing
# Job number  840 added - Sr. Business Analyst
# Job number  841 added - Business Analyst
# Job number  842 added - Sr Health Info and Data Analyst (remote)
# Job number  843 added - Senior Data Analyst, Travel Insights
# Job number  844 added - Business Analyst (Contract)
# Job number  845 added - Web and Mobile App - Business Analyst (20-25 hrs/wk)
# Job number  846 added - Business Analyst, Data and Process Insights
# Job number  847 added - Medical Claim Automation & System Enhancement Analyst
# Job number  848 added - Financial Analyst - Finance
# Job number  849 added - Analytics Consultant
# Job number  850 added - Data Analyst - Level II #1857
# Job number  851 added - Digital Analyst
# Job number  852 added - Senior Data Analyst - Brand Solutions
# Job number  853 added - Senior Business Analyst
# Job number  854 added - Medicare-Business Support Analyst II
# Job number  855 added - Business Systems Analyst
# Job number  856 added - Business Analyst
# Job number  857 added - Senior Data Governance Analyst
# Job number  858 added - Business Analyst - Remote
# Job number  859 added - Data Analyst/Report Writer (Only For TX)
# Job number  860 added - Sr. IT Business Analyst
# Job number  861 added - Business Intelligence Analyst (Virtual Opportunity)
# Job number  862 added - Business Analyst
# Job number  863 added - Business Analyst
# Job number  864 added - Sr. Data Analyst
# Job number  865 added - Clinical Data Analyst, Registry (Part-Time, Remote)
# Job number  866 added - Senior Business Analyst
# Job number  867 added - Senior Business Intelligence Analyst
# Job number  868 added - Data Quality Analyst
# Job number  869 added - EDI Analyst
# Job number  870 added - Senior Business Data Analyst
# Job number  871 added - Business Analyst
# Job number  872 added - Clinical Data Analyst
# Job number  873 added - Senior Business Analyst
# Job number  874 added - Sr. Market Research Analyst
# Job number  875 added - Data Analyst III
# Job number  876 added - Business/Data Analyst Senior | Remote
# Job number  877 added - Jr-Mid Level Data Engineer/Analyst with Front-end experience
# Job number  878 added - Business Analyst
# Job number  879 added - Senior Technical Data Quality Analyst
# Job number  880 added - Senior Business Analyst
# Job number  881 added - Senior Business Intelligence Analyst
# Job number  882 added - EDI Analyst
# Job number  883 added - Business Analyst Sr. - Digital Experience
# Job number  884 added - Business Intelligence Analyst - Remote
# Job number  885 added - Quality Measures Data Analyst (Remote)
# Job number  886 added - eCommerce Business Analyst - Remote Eligible
# Job number  887 added - Business Intelligence Analyst
# Job number  888 added - Business Analyst
# Job number  889 added - Business Analyst
# Job number  890 added - HR/Payroll Senior Data Analyst - Report Writer
# Job number  891 added - Sr. IT Business Analyst (remote)
# Job number  892 added - Sr. Data Analyst
# Job number  893 added - CLAIMS ANALYST - NATIONWIDE (REMOTE)
# Job number  894 added - Lead Data Analyst - Remote
# Job number  895 added - Data Governance Analyst III
# Job number  896 added - IT Analyst - Remote
# Job number  897 added - Jr. Business Analyst
# Job number  898 added - Sr Principal Analyst - Master Data Management Expert, Flexible Work Remote Location
# Job number  899 added - Business Analyst
# Job number  900 added - Capability Analyst - Remote in US
# Job number  901 added - Business Intelligence Analyst
# Job number  902 added - Senior Compliance Data Analyst
# Job number  903 added - Business Analysis - Healthcare
# Job number  904 added - BI Analyst
# Job number  905 added - Data Governance Analyst I - (REMOTE)
# Job number  906 added - Data Analyst
# Job number  907 added - Healthcare Business Analyst 1 (REMOTE)
# Job number  908 added - Outreach Data Analyst (HQ) U.S. Remote/Location Flexible
# Job number  909 added - Healthcare Business Analyst 1 (REMOTE)
# Job number  910 added - Capability Analyst - Remote in US
# Job number  911 added - Outreach Data Analyst (HQ) U.S. Remote/Location Flexible
# Job number  912 added - Scrum Master/Business Analyst
# Job number  913 added - Data Specialist
# Job number  914 added - BA/ Data Analyst - Data Architecture - SQL, Salesforce, PowerBI
# Job number  915 added - Senior Business Analyst (311)
# Job number  916 added - Looking for Senior Data Privacy Business Analyst
# Job number  917 added - Sr. Business Intelligence Analyst
# Job number  918 added - Data Specialist
# Job number  919 added - Senior Analyst, Online Business Analytics (Remote)
# Job number  920 added - Software Quality Assurance Analyst III
# Job number  921 added - Business Data Analyst II
# Job number  922 added - Sales Operations, Senior Analyst
# Job number  923 added - Healthcare Quality Data Analyst REMOTE
# Job number  924 added - Data / Systems Analyst (full-time)
# Job number  925 added - Business Analyst

# %% [markdown]
# ### Scrape full job descriptions

# %%
Links_list = dataframe['Links'].tolist()

import random

async def get_description(urls):
  descriptions = []
  async with get_session(Geckodriver(binary=driver_path, log_file=asyncio.subprocess.PIPE), Firefox(**options)) as session:
    for url in urls:
      await session.get("https://www.indeed.com"+url)
      time.sleep(1) #adding a one-second delay
      jd = await session.get_element('#jobDescriptionText')
      descriptions.append(await jd.get_text())
      await asyncio.sleep(random.random() * 1.5)
  return descriptions

## Number of browser instances to use
n = 3

tasks = [asyncio.create_task(get_description(urls)) for urls in np.array_split(Links_list, n)]
dataframe['Descriptions'] = [desc for task in tasks for desc in await task]

# %% [markdown]
# ### Save results

# %%
# Convert the dataframe to a csv file
date = datetime.today().strftime('%Y-%m-%d')
dataframe.to_csv(date + "_" + position + "_" + locations + ".csv", index=False)

# %%
dataframe
# Out:
#                                          Title  \
# 0                 AWS Data & Reporting Analyst
# 1                 Data Analyst, Advanced Excel
# 2                             Business Analyst
# 3              Business Information Analyst II
# 4                                 Data Analyst
# ..                                         ...
# 920  Data Analyst (Case Management Experience)
# 921            Implementation Business Analyst
# 922          Data Analyst (Intermediate Level)
# 923            Implementation Business Analyst
# 924         IT BUSINESS SYSTEMS ANALYST SENIOR
#
#                                  Company                     Location Rating  \
# 0                      Stand Up Wireless                       Remote    3.9
# 1    ATL International (formerly DeNuke)                       Remote    NaN
# 2                         Aceolution Inc                       Remote    NaN
# 3                        Elevance Health  Remote in Chicago, IL 60610    3.6
# 4                   Phoenix Loss Control                       Remote    4.2
# ..                                   ...                          ...    ...
# 920                    Devcare Solutions                       Remote    3.6
# 921                               Viz.ai  Remote in San Francisco, CA    NaN
# 922                        Topline Group                       Remote    NaN
# 923                               Viz.ai  Remote in San Francisco, CA    NaN
# 924                   First Horizon Bank  Remote in Memphis, TN 38118    3.5
#
#                            Date                     Salary  \
# 0     EmployerActive 3 days ago   $75,000 - $80,000 a year
# 1     EmployerActive 2 days ago          $30 - $45 an hour
# 2     PostedPosted 30+ days ago                $80 an hour
# 3      PostedPosted 24 days ago                        NaN
# 4     EmployerActive 6 days ago  $60,000 - $120,000 a year
# ..                          ...                        ...
# 920  EmployerActive 18 days ago          $50 - $60 an hour
# 921   PostedPosted 30+ days ago  $89,000 - $115,000 a year
# 922   PostedPosted 30+ days ago   $50,000 - $60,000 a year
# 923   PostedPosted 30+ days ago  $89,000 - $115,000 a year
# 924   PostedPosted 30+ days ago                        NaN
#
#                                            Description  \
# 0    Implement best practices in data visualization...
# 1    I. Connecting to data from multiple sources.\n...
# 2    Experience working as a Retail e-commerce data...
# 3    This position is responsible for serving as an...
# 4    Help analyze KPI report data and deduce busine...
# ..                                                 ...
# 920  *Job Title:* Data Analyst *Location:* Jackson,...
# 921  About Viz.ai Viz.ai is the pioneer in the use ...
# 922  Topline Group is looking for a strong intermed...
# 923  Increased data integrity and data gathering wi...
# 924  **This position has the opportunity to sit rem...
#
#                                                  Links  \
# 0    /pagead/clk?mo=r&ad=-6NYlbfkN0BjCBRdhP65IZiSCQ...
# 1    /company/ATL-International-(formerly-DeNuke)/j...
# 2    /pagead/clk?mo=r&ad=-6NYlbfkN0BT75f5_1uiyebGPe...
# 3    /pagead/clk?mo=r&ad=-6NYlbfkN0CYKz7WkjjIBo9g-U...
# 4    /company/Phoenix-Loss-Control/jobs/Data-Analys...
# ..                                                 ...
# 920  /company/Devcare-Solutions/jobs/Data-Analyst-3...
# 921  /rc/clk?jk=7e479f5a759b425a&fccid=309afdc18f5b...
# 922  /rc/clk?jk=da284515bf36a61f&fccid=010548e0d754...
# 923  /rc/clk?jk=7e479f5a759b425a&fccid=309afdc18f5b...
# 924  /pagead/clk?mo=r&ad=-6NYlbfkN0CsITP4rdDTTMAA12...
#
#                                           Descriptions
# 0    AWS Data & Reporting Analyst\n1. As an AWS Dat...
# 1    Seeking a Data Analyst with advanced Excel and...
# 2    Job Description\nRole Description:\n● Business...
# 3    Business Information Analyst II\nThis position...
# 4    Phoenix Loss Control\n` 382 NE 191st St. PMB 9...
# ..                                                 ...
# 920  Job Title: Data Analyst\nLocation: Jackson, MS...
# 921  About Viz.ai\nViz.ai is the pioneer in the use...
# 922  Topline Group is looking for a strong intermed...
# 923  About Viz.ai\nViz.ai is the pioneer in the use...
# 924  **This position has the opportunity to sit rem...
#
# [925 rows x 9 columns]
