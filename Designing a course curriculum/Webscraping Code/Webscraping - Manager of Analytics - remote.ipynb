# %% [markdown]
# # Web Scraping - Indeed.com
# General steps for Web Scraping
# 1. Check whether the website allows web scraping
# 2. Obtain the source code (HTML File) by using the website URL
# 3. Download the website content
# 4. Parse the content using keywords tags for elements of interest
# 5. Extract relevant data/features
# 6. Organize raw data in structured format (e.g., CSV)

# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from datetime import datetime
from arsenic import get_session
from arsenic.browsers import Firefox
from arsenic.services import Geckodriver
import asyncio
import time

# disable arsenic logging to stdout
import structlog
import logging

logger = logging.getLogger()
logger.setLevel(logging.WARN)
structlog.configure(logger_factory=lambda: logger)

# %% [markdown]
# ### Path to webdriver (Firefox, Chrome)

# %%
# Ensure that the driver path is correct before running this script.
# Microsoft Windows
# driver_path = "./drivers/windows/geckodriver.exe"
#driver_path = "./programs/geckodriver.exe"
driver_path = r"C:\Users\ranga\Downloads\geckodriver-v0.32.1-win64\geckodriver.exe"
# Linux
# driver_path = "./drivers/linux/geckodriver"
# driver_path = "/usr/bin/geckodriver"

options = {
  'moz:firefoxOptions': {
    # if you want it to be headless
    'args': ['-headless'],
    'log': {'level': 'warn'},
    # Needed for windows / non-default firefox install
    'binary': 'C:\\Program Files\\Mozilla Firefox\\firefox.exe'
  }
}

# %% [markdown]
# ### Define position and location

# %%
## Enter a job position
position = "manager of analytics"
## Enter a location (City, State or Zip or remote)
locations = "california"

def get_url(position, location):
    url_template = "https://www.indeed.com/jobs?q={}&l={}"
    url = url_template.format(position, location)
    return url

url = get_url(position, locations)
dataframe = pd.DataFrame(columns=["Title", "Company", "Location", "Rating", "Date", "Salary", "Description", "Links"])

# %% [markdown]
# ### Scrape job postings

# %%
## Number of postings to scrape
postings = 1000

## Number of browser instances to use
n = 3

pages = list(range(0, postings, 10))

state = {
  'lock': asyncio.Lock(),
  'ids': set(),
  'n': 0
}
             
async def get_jobs(url, pages, state):
  data = []
  async with get_session(Geckodriver(binary=driver_path, log_file=asyncio.subprocess.PIPE), Firefox(**options)) as session:
    for i in pages:
      await session.get(url + "&start=" + str(i))
      jobs = await session.get_elements("[class='job_seen_beacon']")

      for job in jobs:
        result_html = await job.get_property('innerHTML')
        soup = BeautifulSoup(result_html, 'html.parser')

        liens = await job.get_elements("a")
        link = await liens[0].get_attribute("href")

        title = soup.select('.jobTitle')[0].get_text().strip()
        try:
          company = soup.select('.companyName')[0].get_text().strip()
        except:
          continue
        location = soup.select('.companyLocation')[0].get_text().strip()
        try:
            salary = soup.select('.salary-snippet-container')[0].get_text().strip()
        except:
            salary = 'NaN'
        try:
            rating = soup.select('.ratingNumber')[0].get_text().strip()
        except:
            rating = 'NaN'
        try:
            date = soup.select('.date')[0].get_text().strip()
        except:
            date = 'NaN'
        try:
            description = soup.select('.job-snippet')[0].get_text().strip()
        except:
            description = ''
            
        Id = f"{title}{company}{location}{rating}{date}{salary}{description}"
        dupe = False
        async with state['lock']:
          if Id in state['ids']:
            dupe = True
          else:
            state['ids'].add(Id)
            state['n'] = state['n'] + 1
            print("Job number {0:4d} added - {1:s}".format(state['n'],title))
        if dupe:
          continue

        data.append({
          'Title': title,
          "Company": company,
          'Location': location,
          'Rating': rating,
          'Date': date,
          "Salary": salary,
          "Description": description,
          "Links": link
        })

        # print("Job number {0:4d} added - {1:s}".format(jn,title))
      i = i + 10
  return data

tasks = [asyncio.create_task(get_jobs(url, p, state)) for p in np.array_split(pages, n)]
dataframe = pd.DataFrame([j for task in tasks for j in await task])
# Out:
# Job number    1 added - Program Manager, Analytics
# Job number    2 added - Information Technology Product/ Project Manager [HYBRID]
# Job number    3 added - Manager of Operations
# Job number    4 added - User Support Manager
# Job number    5 added - Pre-Award Manager
# Job number    6 added - Manager, CRM Data Science Analytics
# Job number    7 added - Growth Analytics Manager
# Job number    8 added - Manager of Planning & Analysis
# Job number    9 added - Product Manager - Feed Foundations
# Job number   10 added - Senior Manager of Strategy & Analytics
# Job number   11 added - Manager, Insights and Analytics
# Job number   12 added - AR/VR Media Tech Lead/ Engineering Manager
# Job number   13 added - Associate Manager, Digital Analytics
# Job number   14 added - Sr Manager, Financial Planning and Analysis
# Job number   15 added - Enterprise Account Manager - Analytics
# Job number   16 added - Accounting Manager
# Job number   17 added - Sr. Manager, Business Analytics
# Job number   18 added - Internal Audit Manager
# Job number   19 added - Senior Manager, Programming - Gaming
# Job number   20 added - Manager, Business Analytics - Valent U.S.A LLC
# Job number   21 added - Research Biostatistician Manager
# Job number   22 added - Enterprise Architecture Manager
# Job number   23 added - IT Specialist - Desktop Support and CISCO Call Manager Experience
# Job number   24 added - Sr. Product Manager, Seller Experience
# Job number   25 added - Senior Product Manager - Banking
# Job number   26 added - Manager, Analytics
# Job number   27 added - IT Service Desk Manager
# Job number   28 added - Program Manager, Medication Abortion Access
# Job number   29 added - Transmission Business Manager / Sr. Transmission Business Analyst
# Job number   30 added - Sr. Manager, Product Management, Podcasts
# Job number   31 added - Senior Marketing Manager
# Job number   32 added - Principal Project Manager
# Job number   33 added - Principal Product Manager- Customer Insights & Strategy
# Job number   34 added - Seller Advocacy Lead
# Job number   35 added - Senior Product Manager - TCAD
# Job number   36 added - Manager, People & Culture Strategy, Analytics & Equity
# Job number   37 added - Manager - Technology Risk Consulting
# Job number   38 added - IT Manager - InterContinental Los Angeles Downtown
# Job number   39 added - IT Audit Manager
# Job number   40 added - Strategy and Transactions - EYP-Transaction Strategy and Execution - IT - Manager - Mult Pos-1402605
# Job number   41 added - Project Manager II-Event Planning
# Job number   42 added - Faculty Compensation Lead Analyst - Radiology
# Job number   43 added - Manager, NGS Lab Services
# Job number   44 added - Healthcare Analytics Manager/Senior Analyst
# Job number   45 added - Flight Test Manager
# Job number   46 added - Associate Product Manager
# Job number   47 added - Insights & Analytics Manager, Node Capabilities
# Job number   48 added - Product Manager
# Job number   49 added - Sr Manager, Decision Science - Vans
# Job number   50 added - Technical Program Manager
# Job number   51 added - Analytics Strategy and Operations Manager
# Job number   52 added - Manager, Analytics
# Job number   53 added - Customer Experience Program Manager, GNE
# Job number   54 added - Manager, Business Analytics
# Job number   55 added - FSQA Division Manager (Fresh)
# Job number   56 added - Manager, Data Analytics
# Job number   57 added - Sr Manager Marketing Strategy & Analytics
# Job number   58 added - Game Analytics Manager
# Job number   59 added - Manager Logistics
# Job number   60 added - Manager of Manufacturing Analytics/ Data Science (Remote)
# Job number   61 added - Principal Product Manager - Savings
# Job number   62 added - Manager, Data Science - Streamlit
# Job number   63 added - Data Engineering Manager (San Diego)
# Job number   64 added - Market Research Manager (Hybrid)
# Job number   65 added - Long Term Care Data & Operations Senior Manager San Diego
# Job number   66 added - Manager Database Engineering Security Compliance
# Job number   67 added - Senior Product Manager
# Job number   68 added - Sr. Manager, Manufacturing Engineering
# Job number   69 added - Senior Manager, Competitive Intelligence
# Job number   70 added - Senior Product Manager
# Job number   71 added - Manager, Payments Product, Apple Media Products
# Job number   72 added - Product Manager
# Job number   73 added - Customer Success Manager - Remote
# Job number   74 added - Manager/Analyst(Body Contouring,Business Strategy & Analytics)
# Job number   75 added - Principal Product Manager, Emerging Markets
# Job number   76 added - North America Technical Support Manager
# Job number   77 added - Test Leader / QA Manager
# Job number   78 added - Manager, Data Analytics
# Job number   79 added - Software QA Manager
# Job number   80 added - Sr Manager, Sales Analytics & Insights - TV Distribution
# Job number   81 added - Sr. Manager, People Analytics
# Job number   82 added - 2023-32978/Customer Solutions Analytics Manager
# Job number   83 added - Manager, Adaptive Data Operations
# Job number   84 added - Manager, Pricing Strategy & Analytics - Remote
# Job number   85 added - Product Manager, Customer Insights & Activation
# Job number   86 added - Senior Analytics Manager, Logistics
# Job number   87 added - Product Manager - Engagement
# Job number   88 added - Merchandising Analytics Manager
# Job number   89 added - Senior, Content Strategy Manager
# Job number   90 added - IT PROJECT MANAGER
# Job number   91 added - Manager, Strategic Planning & Business Operations
# Job number   92 added - IT Asset Lead
# Job number   93 added - Special Investigation Unit Manager
# Job number   94 added - Sr. Product Manager Tech, Growth, Wondery
# Job number   95 added - Lead Product Manager, Mobile Games
# Job number   96 added - Project Manager
# Job number   97 added - Reverse Logistics Program Manager
# Job number   98 added - Global Product Manager, Orthodontics
# Job number   99 added - Laboratory Information Systems (LIS) Manager
# Job number  100 added - Sr Incident Manager
# Job number  101 added - Accelerator Operations Maintenance Manager
# Job number  102 added - Corporate Compliance Manager
# Job number  103 added - Senior Product Manager (Remote, US-based)
# Job number  104 added - Manager, Engineering, Core Data
# Job number  105 added - Senior Payment Analytics & Operations Manager
# Job number  106 added - Associate Product Manager
# Job number  107 added - Education Campus Manager
# Job number  108 added - Manager, Energy Storage Development & Analytics
# Job number  109 added - Supervising Health Information Specialist
# Job number  110 added - AI product manager
# Job number  111 added - Technical Training, Program Manager
# Job number  112 added - Patient Success Call Quality Analyst/Manager
# Job number  113 added - Business Intelligence Analytics Manager, Full Time, Days (Hybrid)
# Job number  114 added - Business Analytics Manager
# Job number  115 added - Product Manager - Growth PM Data Analytics
# Job number  116 added - Senior Product Manager - Remote
# Job number  117 added - Platform Product Manager, Graphics
# Job number  118 added - Associate Product Manager
# Job number  119 added - Sr. BI Manager
# Job number  120 added - Legal Technology Manager
# Job number  121 added - Decision Science Manager, Controls
# Job number  122 added - IT Manager
# Job number  123 added - Team Leader Global Markets Trading Risk & Research
# Job number  124 added - CDnA - Data Platform Operations Manager
# Job number  125 added - Manager, Data Integrity & Reporting – Santa Monica, California
# Job number  126 added - Senior Project Manager - One Person One Record
# Job number  127 added - (USA) Operations Manager I - Supply Chain - Field Operations Manager - Imports
# Job number  128 added - Business Applications Manager-Contract
# Job number  129 added - Product Marketing Manager, Competitive Intelligence
# Job number  130 added - Analytics Manager
# Job number  131 added - Sr. Product Manager - Customer Analytics (Customer360)
# Job number  132 added - Program Manager Legal Department- Google Cloud
# Job number  133 added - Sr Manager Data and Analytics
# Job number  134 added - Logistic Product Manager, TikTok US E-commerce
# Job number  135 added - Product Manager (Experienced)
# Job number  136 added - Customer Support Manager
# Job number  137 added - Manager, Intelligence and Analytics Insights - Remote/Hybrid
# Job number  138 added - Partner Operations Manager(Executive marketing,data report & analysis)
# Job number  139 added - Portfolio Manager – Junior Systematic Quantitative Researcher
# Job number  140 added - Compensation Program Manager
# Job number  141 added - Senior Manager/Associate Director, Trade Operations, Analytics, and Reporting
# Job number  142 added - (USA) Manager I, Advanced Analytics - Business Intelligence
# Job number  143 added - Manager, Metadata & Taxonomy
# Job number  144 added - Lead Application Admin
# Job number  145 added - Manager, VIC & Client Development- West Coast
# Job number  146 added - IT Manager
# Job number  147 added - Business Operations Manager Senior-IO/IT
# Job number  148 added - Senior Manager ITSM
# Job number  149 added - Manager, Digital Data & Analytics (Data Analysis)
# Job number  150 added - Lead IT Auditor (Remote)
# Job number  151 added - Senior Project Manager
# Job number  152 added - Sr. Manager, HRIS Technology and Strategy
# Job number  153 added - Group Product Manager - Virtual Expert Platform - Collaboration Capabilities
# Job number  154 added - Data Engineering Manager (San Diego)
# Job number  155 added - Manager, Database Administration
# Job number  156 added - Project Manager Sr-IT
# Job number  157 added - Evaluation Lead (RSCH DATA ANL 4)-SOM: MED: Equity Diversity Inclusion-Sacramento Campus
# Job number  158 added - Product Manager, Upsell Experience
# Job number  159 added - Sr Manager, Diversity, Equity and Inclusion Intelligence and Analytics Insights - Remote/Hybrid
# Job number  160 added - Manager, CEO office
# Job number  161 added - Manager, Procurement Operations & Analytics
# Job number  162 added - Manager, Data Science & Analytics (Inventory & Supply Chain) - Remote
# Job number  163 added - Senior Quality Assurance Manager (QA Manager), TikTok E-commerce
# Job number  164 added - Sr Manager, Real Estate Data Strategy & Analytics
# Job number  165 added - Senior Manager, Global Insights and Analytics
# Job number  166 added - Product Manager - B2C, Chatbot
# Job number  167 added - Manager/Senior Manager, Business Analytics
# Job number  168 added - Product Manager, Core Product
# Job number  169 added - Investor Analytics Manager
# Job number  170 added - Compliance Manager
# Job number  171 added - Manager, Clinical Analytics
# Job number  172 added - Content Marketing Manager
# Job number  173 added - Data Governance & Privacy, Senior Technical Program Manager
# Job number  174 added - Manager, Clinical Documentation Improvement
# Job number  175 added - Sales Strategy & Operations Analytics Manager - SF/NY
# Job number  176 added - Sr. HRIS Manager
# Job number  177 added - Technical Product Manager - New Media
# Job number  178 added - Sr. Manager, Ecommerce Planning & Analysis
# Job number  179 added - Quality Project Manager
# Job number  180 added - Land Title and GIS Program Manager
# Job number  181 added - Senior Manager, Systems Engineer IV - Senior Network Engineer
# Job number  182 added - Senior Manager, Marketing Analytics
# Job number  183 added - Strategy Product Manager Lead, TikTok Commerce Anti-fraud Solutions
# Job number  184 added - Senior Manager, Flight Sciences
# Job number  185 added - Manager, Clinical Enrollment (Remote)
# Job number  186 added - Manager, Consumer Research
# Job number  187 added - Manager, Content Strategy & Analysis
# Job number  188 added - Program Manager
# Job number  189 added - Engineering Manager, Data Analytics
# Job number  190 added - Global Real Estate Strategy Manager
# Job number  191 added - Manager, Strategy Analytics
# Job number  192 added - IT Manager
# Job number  193 added - Senior Manager, Finance
# Job number  194 added - Global Service Readiness Manager
# Job number  195 added - Analytics Manager
# Job number  196 added - Planning & Buying Analytics Manager
# Job number  197 added - Project Manager, Distribution Services
# Job number  198 added - Customer Success Manager
# Job number  199 added - Senior Manager, Competitive Intelligence
# Job number  200 added - ERP Systems Project Manager (Analyst/Programmer, Career)
# Job number  201 added - Manager, Machine Learning Infrastructure
# Job number  202 added - Digital Product Manager (Remote)
# Job number  203 added - Competitive Intelligence Engineer or Manager, Observability (Remote)
# Job number  204 added - Analytics Manager
# Job number  205 added - Lead Data Analyst
# Job number  206 added - Data Integration Manager/Job Req 537195376
# Job number  207 added - Artificial Intelligence Leader, Healthcare - SFL Scientific
# Job number  208 added - Sr. Manager, Data Science
# Job number  209 added - Senior Product Manager (Remote)
# Job number  210 added - Tech Lead Machine Learning Engineer, TikTok Branding Ads
# Job number  211 added - Manager / Sr. Manager, Upstream Manufacturing
# Job number  212 added - Compensation Manager, Equity
# Job number  213 added - Manager, Stars Analytics
# Job number  214 added - Project Manager
# Job number  215 added - Data Analytics Manager
# Job number  216 added - Product Manager, TV App Sports
# Job number  217 added - Sr. Product Manager, Watch Experience
# Job number  218 added - Case Designer / Analytics Manager
# Job number  219 added - Information Technology Manager
# Job number  220 added - Data Engineering Manager
# Job number  221 added - Senior Product Manager, Data and Analytics
# Job number  222 added - SENIOR MANAGER, INSIGHTS AND ANALYTICS
# Job number  223 added - Technical Program Manager, Machine Learning
# Job number  224 added - Men's Social Media & Content Manager (REVOLVE + FWRD)
# Job number  225 added - Digital Media Manager
# Job number  226 added - Principal Project Manager
# Job number  227 added - CDnA – Patient Support Analytics Manager
# Job number  228 added - Product Manager
# Job number  229 added - Technical Project Manager
# Job number  230 added - Senior Engineering Manager, Data & Analytics
# Job number  231 added - National Sales Manager-CPN
# Job number  232 added - Pricing Strategy Analytics - Manager
# Job number  233 added - Regional Supply Chain Manager
# Job number  234 added - Customer Experience Manager - Rider Operations
# Job number  235 added - Senior Events Manager
# Job number  236 added - Senior Technical Program Manager
# Job number  237 added - Data Engineering Manager
# Job number  238 added - Product Manager
# Job number  239 added - Research and Business Intelligence Manager
# Job number  240 added - Program Manager
# Job number  241 added - HRIS Manager (San Diego, Dallas or DC)
# Job number  242 added - Systems Test Manager
# Job number  243 added - M&A Integration Program Manager
# Job number  244 added - Distribution Center Operations Manager
# Job number  245 added - Business Intelligence Manager IS
# Job number  246 added - Manager, Financial Planning & Analysis
# Job number  247 added - Senior Client Program Manager
# Job number  248 added - Manager of Business Intelligence and Data Analytics
# Job number  249 added - Assembly Manager
# Job number  250 added - IT Vendor Manager (Remote)
# Job number  251 added - Senior Product Manager
# Job number  252 added - Associate Manager, Ecommerce Sales Analytics
# Job number  253 added - Sr. Data & Analytics Manager
# Job number  254 added - Manager, Contract & Access Analytics
# Job number  255 added - Revenue Cycle Program Manager (Remote)
# Job number  256 added - Senior Product Manager
# Job number  257 added - Manager, Manufacturing Engineering
# Job number  258 added - Accounting Manager
# Job number  259 added - Commodity Manager, Indirect Procurement
# Job number  260 added - Senior Product Manager - Data & AI
# Job number  261 added - Manager - IT ERP Applications - Finance
# Job number  262 added - Mid-Level Technical Program Manager (hybrid)
# Job number  263 added - Institutional Program Business Manager IV, Performance Assessment and Analysis Office
# Job number  264 added - People Operations Manager
# Job number  265 added - Technical Program Manager, Go To Market
# Job number  266 added - IT Education Service Lead
# Job number  267 added - Senior Clinical Programming Manager
# Job number  268 added - Manager, Service Desk
# Job number  269 added - Senior Product Manager
# Job number  270 added - Product Manager - SaaS
# Job number  271 added - Product Manager, Privacy
# Job number  272 added - Manager, Content Analytics & Insights
# Job number  273 added - Manager, IT Support Services
# Job number  274 added - Manager, Financial Analysis - (M5)
# Job number  275 added - Senior Manager Risk Program Mgmt, Data & Analytics - Los Angeles/hybrid
# Job number  276 added - Sr. Manager Risk, Capital Markets
# Job number  277 added - Shopper Insights Manager
# Job number  278 added - Retail Operations Project Manager (Remote)
# Job number  279 added - Senior Product Manager, Reporting & Analytics
# Job number  280 added - Manager, Financial Planning and Analysis
# Job number  281 added - Manager, Analytics
# Job number  282 added - Product Manager, Creator Experience
# Job number  283 added - Project Manager/Financial Analyst
# Job number  284 added - Product Manager
# Job number  285 added - Employee Experience Manager
# Job number  286 added - Senior Product Manager
# Job number  287 added - Senior Manager, CRM Lifecycle
# Job number  288 added - Lead Research Data Analyst
# Job number  289 added - Product Manager, Web
# Job number  290 added - Manager, Quality Engineering
# Job number  291 added - Sr. Product Manager
# Job number  292 added - Program Manager, Learning and Talent Management
# Job number  293 added - Manager, Financial Planning and Analysis - Supply Chain
# Job number  294 added - Research Manager Ad Solutions
# Job number  295 added - AIML - Sr Manager, Speech Technologies Product & Program Management
# Job number  296 added - Business Solutions Manager (Remote)
# Job number  297 added - Manager, Competitive Intelligence (US Strategy) | Businesses, Global and Strategic Services (BGS)
# Job number  298 added - Account Manager-Ohio
# Job number  299 added - NPI Readiness Program Manager
# Job number  300 added - Sr. Data & Analytics Manager
# Job number  301 added - Market Intelligence Manager
# Job number  302 added - Power & Performance - Analytics Infrastructure Engineering Manager
# Job number  303 added - Consumer Insights Manager
# Job number  304 added - Commercial Data & Analytics Manager
# Job number  305 added - Manager, Revenue Management & Business Analytics
# Job number  306 added - Senior Manager Data Science
# Job number  307 added - Manager of Product Management, Protein Analysis
# Job number  308 added - Assistant Manager, Safety Data Analytics
# Job number  309 added - Sr. Manager, Commercial Planning and Analytics
# Job number  310 added - Product Manager - Ezmeral Data Fabric
# Job number  311 added - Senior Product Manager, Mobile
# Job number  312 added - Data & Analytics Manager
# Job number  313 added - Program Manager, Product (0854)
# Job number  314 added - Technical Program Manager - Product Security
# Job number  315 added - Staff Product Manager - Platform
# Job number  316 added - Data Manager
# Job number  317 added - IT Audit Manager - Consultant
# Job number  318 added - Lead Product Manager, Reporting
# Job number  319 added - As a Service Program Manager for Storage
# Job number  320 added - Product Manager – Business Intelligence & Analytics (Hybrid)
# Job number  321 added - Associate Product Manager
# Job number  322 added - Data Analytics Manager - Pomona [HYBRID]
# Job number  323 added - Business Analysis Manager - Marketing
# Job number  324 added - Design Program Manager
# Job number  325 added - Database Operations Manager (San Diego)
# Job number  326 added - Technical Product Manager - Core Database (Remote)
# Job number  327 added - Senior Product Manager, Fraud
# Job number  328 added - Manager, Enterprise Architecture - 23-29
# Job number  329 added - Senior Manager - Data Engineering and Analytics
# Job number  330 added - Manager, Financial Analyst – Santa Ana, CA
# Job number  331 added - Associate Product Manager
# Job number  332 added - Operations Senior Manager, 1st shift
# Job number  333 added - Senior Manager, Data and Analytics
# Job number  334 added - Manager, Business Intelligence Analytics
# Job number  335 added - Future of Work Product Manager, 3P Experiences
# Job number  336 added - Manager, Growth Marketing (Paid Search) - REMOTE
# Job number  337 added - Platform Manager, UCAN Social (Twitter & Facebook)
# Job number  338 added - Display Technologies Engineering Program Manager
# Job number  339 added - Quality Assurance Manager
# Job number  340 added - Senior Manager, Merchandising Analytics - Remote
# Job number  341 added - Ads Interface Project Manager
# Job number  342 added - Senior Maintenance Manager
# Job number  343 added - Project Manager
# Job number  344 added - Information Technology Product/ Project Manager [HYBRID]
# Job number  345 added - Technical Program Manager - Sensors and Compute
# Job number  346 added - Product Manager, User Growth
# Job number  347 added - Product Manager - Feed Foundations
# Job number  348 added - Program Manager, Quote-to-Invoice (Q2I)
# Job number  349 added - Test Development Manager - (Principal Human Resources Analyst)
# Job number  350 added - AR/VR Media Tech Lead/ Engineering Manager
# Job number  351 added - Sr. Manager, Infra QA, Testing Automation and SRE
# Job number  352 added - Sr Manager, Financial Planning and Analysis
# Job number  353 added - Outside Sales Account Manager (Multi-Family) - San Jose, CA
# Job number  354 added - Accounting Manager
# Job number  355 added - Senior Manager, Programming - Gaming
# Job number  356 added - Research Biostatistician Manager
# Job number  357 added - Lead IT Risk – Analytics & Reporting
# Job number  358 added - Sr. Product Manager, Seller Experience
# Job number  359 added - Data Science Manager - TikTok Ads
# Job number  360 added - IT Service Desk Manager
# Job number  361 added - IT Data and Analytics Leader
# Job number  362 added - Transmission Business Manager / Sr. Transmission Business Analyst
# Job number  363 added - IT Project Manager - Department of Technology (5502)
# Job number  364 added - Senior Marketing Manager
# Job number  365 added - Sr. Manager, Logistics Digital Transformation
# Job number  366 added - Principal Product Manager- Customer Insights & Strategy
# Job number  367 added - Product Manager, Mobile
# Job number  368 added - Senior Product Manager - TCAD
# Job number  369 added - Program/Project Manager 5
# Job number  370 added - Senior Product Manager, Data & Analytics
# Job number  371 added - Manager - Technology Risk Consulting
# Job number  372 added - Senior Product Manager, Personalization & Search
# Job number  373 added - Sr. Customer Success Manager
# Job number  374 added - IT Audit Manager
# Job number  375 added - Regional Project Manager
# Job number  376 added - Sr. Operations Manager - (Remote)
# Job number  377 added - Quantitative Portfolio Manager
# Job number  378 added - Associate Supply Chain Manager
# Job number  379 added - People Operations Manager (Contract, Part-Time)
# Job number  380 added - Document Control Manager
# Job number  381 added - SENIOR MANAGER, DIGITAL ANALYTICS
# Job number  382 added - Senior Product Manager, Employee Benefits
# Job number  383 added - Senior Manager of Renewable Energy Project Development
# Job number  384 added - Sr. Product Manager
# Job number  385 added - Production Manager
# Job number  386 added - Manager, Ecommerce & Digital Marketing Analytics
# Job number  387 added - Principal Product Manager - Application
# Job number  388 added - Senior Program Manager
# Job number  389 added - Strategic Sourcing Category Manager
# Job number  390 added - Engineering Manager
# Job number  391 added - Analytics Program Manager II
# Job number  392 added - Program Manager
# Job number  393 added - Product Manager (Remote USA)
# Job number  394 added - Senior Product Manager
# Job number  395 added - Senior Reliability Engineering Manager
# Job number  396 added - Information Systems Manager
# Job number  397 added - Developer Marketing Manager
# Job number  398 added - Principal Product Manager, Identity
# Job number  399 added - Manager, Compliance, Medical Coding Information Technology
# Job number  400 added - Senior Project Manager (Hybrid)
# Job number  401 added - Senior Manager, Billings, Collections & Revenue
# Job number  402 added - Principal Product Manager, Enterprise
# Job number  403 added - Salesforce Product Manager
# Job number  404 added - Senior Product Manager, Fulfillment Solutions (Remote Positions Available)
# Job number  405 added - Product Manager
# Job number  406 added - Technical Program Manager
# Job number  407 added - Product Manager, Data Platform - Online Data Stores
# Job number  408 added - Engineering Manager
# Job number  409 added - IT Infrastructure Manager (Supervising Technology Analyst) - Remote
# Job number  410 added - Compliance Manager
# Job number  411 added - Bus Analyst - Str and Tran - SaT - Parth - Tran Str and Exe- DealStr andMagmnt-Mgr-Mul Pos - 1409541
# Job number  412 added - Senior Product Manager - Services & Protection
# Job number  413 added - Project Manager
# Job number  414 added - Senior Technical Project Manager
# Job number  415 added - Product Manager, Core Product
# Job number  416 added - Product Manager, Data Foundations
# Job number  417 added - Assistant Manager, Safety Data Analytics
# Job number  418 added - Manager, NGS Lab Services
# Job number  419 added - Manager, Business Intelligence & Analysis
# Job number  420 added - Production Manager
# Job number  421 added - Manager, Data & Analytics - Apple Retail Online
# Job number  422 added - Principal Vehicle Product Manager
# Job number  423 added - Data Manager
# Job number  424 added - Senior Product Manager - TikTok Effect
# Job number  425 added - Senior Product Manager
# Job number  426 added - Senior Product Manager - Healthy Light Software Applications
# Job number  427 added - Digital Data Technical Project Manager
# Job number  428 added - Sr HIPAA Compliance Program Manager - REMOTE
# Job number  429 added - Product Manager, Silicon SoC
# Job number  430 added - New NaaS Introduction Program Manager
# Job number  431 added - Principal Product Manager, UI and Application Platforms
# Job number  432 added - Sr. Program Manager - Talent
# Job number  433 added - Product Manager
# Job number  434 added - Senior Product Manager I
# Job number  435 added - Strategic Planning Manager
# Job number  436 added - Associate Companion Diagnostics Project Leader
# Job number  437 added - Remote - Sr. Product Manager, Healthcare Innovation & Digital Strategy
# Job number  438 added - Manager, Manufacturing Financial Planning and Analysis (FP&A)
# Job number  439 added - Technology Support Manager
# Job number  440 added - Program Manager, Innovative Technology - Allergan Aesthetics
# Job number  441 added - Project Manager - Product
# Job number  442 added - (USA) Senior Manager II, Design (US) - Services
# Job number  443 added - Sr. Technical Product Manager Cloud
# Job number  444 added - Senior Packaging Engineer/Packaging Center of Excellence Lead
# Job number  445 added - Senior Product Manager, Gaming
# Job number  446 added - Project Manager with pharmacy industry
# Job number  447 added - Community College Program Manager
# Job number  448 added - Senior Product Manager, Alliances/Partnerships
# Job number  449 added - Senior Product Manager, Growth and Subscription
# Job number  450 added - Securities Analyst - TAS - Value and Bus Model Complex Sec - Senior Manager - Mult Pos - 1395525
# Job number  451 added - Lead Engineer, Data Platform
# Job number  452 added - QA Leader
# Job number  453 added - Manager, Data Analytics (Finance)
# Job number  454 added - Manager, Media Information and Data Analysis – Woodland Hills, California
# Job number  455 added - Environmental Sustainability Manager
# Job number  456 added - Senior Manager, Product Management, Track and Measure Products
# Job number  457 added - Implementation Project Manager
# Job number  458 added - Business Manager, Private Label
# Job number  459 added - Manager, Claims
# Job number  460 added - Lead Product Manager App, Loyalty, Data, & Insights
# Job number  461 added - Information Security Lead - Fraud
# Job number  462 added - System Architecture Engineering Manager
# Job number  463 added - Service Delivery Manager - California/ Remote
# Job number  464 added - Senior Manager II, Advanced Analytics - Category Marketing
# Job number  465 added - HR Business Partner Leader - Trust & Safety - AMS - San Jose
# Job number  466 added - Senior Manager, Consumer Insights
# Job number  467 added - Product Manager
# Job number  468 added - Lead Product Manager, Onboarding & Identity Verification
# Job number  469 added - Lead, Advanced Analytics, Payments
# Job number  470 added - Senior Product Manager, Patient Experience
# Job number  471 added - Financial Planning & Analysis Manager
# Job number  472 added - ALM Analytics Manager
# Job number  473 added - Lead Data Management Analyst
# Job number  474 added - Manager, Model Validation
# Job number  475 added - Onsite Display Senior Analyst - Optimization Manager, Marketing Operations - eComm (Ad Performance & Optimizations) Walmart Connect
# Job number  476 added - Quality Manager: Cosmetic Ingredients and Products
# Job number  477 added - Senior Product Manager
# Job number  478 added - Platform+ Insights and Analytics Manager
# Job number  479 added - Technical Project Manager
# Job number  480 added - Supervisor, Starlink Customer Operations
# Job number  481 added - Quality Assurance Manager
# Job number  482 added - Big Data Manager- Hybrid
# Job number  483 added - Artificial Intelligence Business Development Leader - SFL Scientific
# Job number  484 added - Enterprise Architecture Manager
# Job number  485 added - Construction Purchasing Manager
# Job number  486 added - Staff/Principal Program Manager
# Job number  487 added - PRODUCT MANAGER
# Job number  488 added - Manager, Financial Planning & Analysis (Remote)
# Job number  489 added - CRM Manager, Engagement
# Job number  490 added - Platform User Operation Leader - USDS
# Job number  491 added - Sr Data Services Manager
# Job number  492 added - Senior Marketing Analytics Manager
# Job number  493 added - Automation Design & Activation, Supply Chain Manager
# Job number  494 added - Product Manager - Core Property Management Platform
# Job number  495 added - Business Manager, Private Label
# Job number  496 added - Clinical Navigation & Research Svsc. Data Manager
# Job number  497 added - Operations Senior Manager, 1st shift
# Job number  498 added - Senior / Staff Technical Program Manager - Engineering
# Job number  499 added - Associate Manager, Integration and Test Engineer
# Job number  500 added - Technical Program Manager - Infrastructure Energy Strategy
# Job number  501 added - Sr. Product Manager, Seller Experience
# Job number  502 added - Product Manager - Technical II
# Job number  503 added - Product Manager
# Job number  504 added - Data Platform Engineering Manager
# Job number  505 added - Custodial and Facilities Operations Program Manager
# Job number  506 added - Service Delivery Manager
# Job number  507 added - Product Manager
# Job number  508 added - Principal Manager of Insights & Analytics [HYBRID]
# Job number  509 added - Senior Product Manager, AI/Teachers
# Job number  510 added - Senior Product Manager, Music Tools
# Job number  511 added - Principal Product Manager
# Job number  512 added - Reporting and Analytics Manager
# Job number  513 added - Senior Staff Technical Program Manager, SoFi Product (Contract)
# Job number  514 added - Manager, Solution Engineering
# Job number  515 added - Global Market Development Manager, Pharma Analytics
# Job number  516 added - Technical Project Manager - Data Warehouse and Analytics
# Job number  517 added - Information Technology Product/ Project Manager [HYBRID]
# Job number  518 added - Sr. Manager, MSAT
# Job number  519 added - Chip Architecture Manager, GPU
# Job number  520 added - Manager, Project Management Organization
# Job number  521 added - Senior Product Manager (Web & Mobile Apps) - Remote
# Job number  522 added - Utility Energy Analyst (Utility Program Manager)
# Job number  523 added - Artificial Intelligence Leader, Life Sciences - SFL Scientific
# Job number  524 added - Quantitative Portfolio Manager
# Job number  525 added - REMOTE: Senior IT Project Manager
# Job number  526 added - CCTO Regulatory Lead of IIT Services
# Job number  527 added - Technical Project Manager - Hardware
# Job number  528 added - LN Concerts, Pricing Manager
# Job number  529 added - Manager II, Revenue Growth Manager SGWS (CA)
# Job number  530 added - Manager, Site & Merchandising Experience – Santa Monica, California
# Job number  531 added - Product Manager
# Job number  532 added - IT Manager - Remote
# Job number  533 added - Product Manager, Client Experience
# Job number  534 added - Technical Program Manager- Mac
# Job number  535 added - Business Analytics Lead
# Job number  536 added - Senior Product Manager, Data
# Job number  537 added - COMPENSATION ANALYTICS MANAGER
# Job number  538 added - Technical Program Manager of Mechanical Systems
# Job number  539 added - Consumer Lending Non-Real Estate Secured Product Manager
# Job number  540 added - Academic Data & Analytics Manager
# Job number  541 added - Senior Growth Product Manager
# Job number  542 added - IT Manager II (Business Continuity)
# Job number  543 added - Sr. IT Manager
# Job number  544 added - Sr. Program Manager
# Job number  545 added - Lead Business Analyst, Restaurant Labor Technology
# Job number  546 added - Sr. Supply Chain Manager, 3PL Operations and Analysis
# Job number  547 added - Email Marketing Manager (Remote)
# Job number  548 added - Rec Sports Associate Director and Workforce Analysis & Strategic Projects Manager (7398U), Recreational Sports - 51162
# Job number  549 added - Lead Product Manager - Commerce Platform
# Job number  550 added - Database Operations Manager (San Diego)
# Job number  551 added - Senior Manager, Residuals and Data Management
# Job number  552 added - DEI Transformation Manager
# Job number  553 added - Analytic Lab Manager
# Job number  554 added - Senior Technical Product Manager - Family Tree Intelligence
# Job number  555 added - Senior Commercial Business Systems Manager
# Job number  556 added - Manager, Business Planning & Financial Analysis
# Job number  557 added - Data Manager Analyst
# Job number  558 added - Senior Associate/Manager, Quality Control
# Job number  559 added - Manager - Financial Planning & Analytics (1.0 FTE, Days)
# Job number  560 added - Senior Product Manager, Lingo Biowearables
# Job number  561 added - Technical Project Manager-USDS
# Job number  562 added - Technical Product Manager - Development Infrastructure Product Team
# Job number  563 added - Voice of the Customer, Insights Lead, Remote
# Job number  564 added - Tech Lead Manager, Data Platform - USDS
# Job number  565 added - New Product Technology Project Manager
# Job number  566 added - Manager of Marketing Analytics and Strategy
# Job number  567 added - Senior Game Product Manager - Unpublished R&D Product
# Job number  568 added - Manager, Workforce Planning and Performance Analytics
# Job number  569 added - Business Intelligence Manager
# Job number  570 added - Project Manager
# Job number  571 added - Product Manager
# Job number  572 added - CRM Sr Manager
# Job number  573 added - Manager, Business Analytics (Applebee's)
# Job number  574 added - Project Manager - Frontier Climate Project
# Job number  575 added - Product Manager
# Job number  576 added - Staff Analyst, Coordination Manager
# Job number  577 added - User Experience (UX) Research Manager
# Job number  578 added - Business Operations Manager - Product (Insurance)
# Job number  579 added - Technology Audit Manager
# Job number  580 added - IT Portfolio Manager (San Diego)
# Job number  581 added - Senior Manager II, User Experience - Walmart+
# Job number  582 added - Tech Program Manager
# Job number  583 added - Product Manager - Data
# Job number  584 added - HRIS Manager - Hybrid/Remote
# Job number  585 added - Proposal Manager
# Job number  586 added - Product Manager / Product Owner - Translational Research Informatics
# Job number  587 added - Data Governance Manager
# Job number  588 added - Engineering Manager, Mobile Release
# Job number  589 added - Senior Product Manager
# Job number  590 added - Cainiao Import Operation Analyst/Manager Los Angeles
# Job number  591 added - Associate Manager, Ecommerce Sales Analytics
# Job number  592 added - Program Manager, Learning and Talent Management
# Job number  593 added - Sr Technical Product Manager-Enterprise Integrations
# Job number  594 added - Senior Product Manager
# Job number  595 added - Sr. Manager, Revenue FP&A and Analytics
# Job number  596 added - Manager Business Systems Analysis
# Job number  597 added - Product Manager Lead, Content Classification - Trust & Safety
# Job number  598 added - Program Manager, Payment Integrity
# Job number  599 added - Product Manager
# Job number  600 added - Senior Marketing Operations & Business Analytics Manager
# Job number  601 added - Sr. Manager, Media Data Solutions and Engineering
# Job number  602 added - Senior Product Manager - Feed Quality
# Job number  603 added - Sr Technical Program Manager
# Job number  604 added - Senior Technical Product Manager
# Job number  605 added - Senior Product Manager - Verticals- Remote United States
# Job number  606 added - Senior Product Manager, Data and Analytics
# Job number  607 added - Senior Machine Learning Manager
# Job number  608 added - Senior Product Manager - Dremio Sonar
# Job number  609 added - Data Management & Analytics Manager - Customer Data Platform (CDP)
# Job number  610 added - Sr. Manager, Splunk Threat Research Team (STRT) - Remote
# Job number  611 added - Sr Program Manager - Portfolio Analytics #2850
# Job number  612 added - Program Manager, Supply Chain
# Job number  613 added - Project Manager
# Job number  614 added - Technical Program Manager / Sr Technical Business Analyst
# Job number  615 added - Data Analysis Sr Manager
# Job number  616 added - Program Manager, Growth & Monetization
# Job number  617 added - Senior Sourcing Manager
# Job number  618 added - Cybersecurity Program Manager
# Job number  619 added - Senior Operations Manager, DashMart
# Job number  620 added - Senior Project Manager - Information Services - Full Time 8Hr - Days
# Job number  621 added - Program Manager III, GHG and Net Zero Standards
# Job number  622 added - Sr. Product Manager, Ancestry
# Job number  623 added - Manager, Supply Intelligence & Analysis
# Job number  624 added - IT Application Manager
# Job number  625 added - Product Manager - Clinical Database (CDB)
# Job number  626 added - Project Manager
# Job number  627 added - Product Manager - European Contractor
# Job number  628 added - People Operations Manager
# Job number  629 added - Operations Manager
# Job number  630 added - Staff Analyst - Skid Row Action Plan Technical Assistance Program Manager
# Job number  631 added - Product Manager - Fishing Mobile App
# Job number  632 added - Program Manager
# Job number  633 added - Product Owner/Manager
# Job number  634 added - Principal Product Manager
# Job number  635 added - Neonatology Education Program Manager
# Job number  636 added - Manager Engineering Technical Support 2
# Job number  637 added - Consumer Insights Manager- REMOTE
# Job number  638 added - Cybersecurity Project Manager
# Job number  639 added - Senior Product Manager - Ads (Remote)
# Job number  640 added - Marketing Communications Manager
# Job number  641 added - Sr. Product Manager, XDR (Remote)
# Job number  642 added - Senior User Research Manager
# Job number  643 added - Consumer Lending Unsecured Product Manager
# Job number  644 added - Manager, Information Systems (IS) III
# Job number  645 added - Manager of Data & Analytics
# Job number  646 added - Services Reliability Program Manager
# Job number  647 added - Senior Product Manager
# Job number  648 added - Manager, Marketing Insights and Analysis
# Job number  649 added - Manager II, Product Management (Tech) - Walmart Fulfillment Services - Remote
# Job number  650 added - Data Science Senior Manager, Measurements
# Job number  651 added - Engineering Manager II, Search Platform
# Job number  652 added - Senior Manager, IT Process Improvement Specialist
# Job number  653 added - Senior Product Manager
# Job number  654 added - Principal Product Manager (Remote)
# Job number  655 added - Senior Product Manager (Remote)
# Job number  656 added - Manager Insights & Analytics
# Job number  657 added - Internal Audit Manager
# Job number  658 added - Laboratory Administrative Manager
# Job number  659 added - Senior Product Manager - Healthy Light Software Applications
# Job number  660 added - Senior Product Manager
# Job number  661 added - Healthcare Data Quality Manager
# Job number  662 added - Manager Reporting & Data Analysis - CA Commercial Capitated Delivery Systems
# Job number  663 added - Sr. Program Manager - Talent
# Job number  664 added - Senior Manager, Medical Affairs Operations – Business Analytics and Systems
# Job number  665 added - Remote - Sr. Product Manager, Healthcare Innovation & Digital Strategy
# Job number  666 added - Non-Technical Program/Project Manager
# Job number  667 added - Manager, Manufacturing Financial Planning and Analysis (FP&A)
# Job number  668 added - Technology Support Manager
# Job number  669 added - Data Science Manager, Crypto
# Job number  670 added - Program Manager, Innovative Technology - Allergan Aesthetics
# Job number  671 added - Valuation & Analytics - Sr. Manager, Energy Commodity
# Job number  672 added - Project Manager - Product
# Job number  673 added - Senior Technical Program Manager
# Job number  674 added - (USA) Senior Manager II, Design (US) - Services
# Job number  675 added - Product Manager, Web
# Job number  676 added - Sr. Technical Product Manager Cloud
# Job number  677 added - CapEx Requirements Program Manager - iPhone
# Job number  678 added - Senior Packaging Engineer/Packaging Center of Excellence Lead
# Job number  679 added - Senior Product Manager, Gaming
# Job number  680 added - Project Manager with pharmacy industry
# Job number  681 added - Clinical Project Manager
# Job number  682 added - Senior Technical Product Manager
# Job number  683 added - Sr. Business Coach / Regional Manager - Las Vegas
# Job number  684 added - Consumer Insights, Senior Manager Advertising Effectiveness
# Job number  685 added - Senior Product Manager, International
# Job number  686 added - Senior Manager, Data Science - Inventory Forecasting (San Bruno)
# Job number  687 added - Sr Manager, Trust Strategic Insights
# Job number  688 added - Lead Product Manager, Mobile Games
# Job number  689 added - Project Manager, REVOLVE Owned Brands
# Job number  690 added - Ads Data Science Manager
# Job number  691 added - Product Manager
# Job number  692 added - Manager, Data & Analytics – Santa Monica, California
# Job number  693 added - Project Manager - Structural Analysis
# Job number  694 added - Sales Product Manager - Server
# Job number  695 added - Manager, IT Business Engagement Analyst
# Job number  696 added - Tech Lead Manager, Architect and New Technology Research
# Job number  697 added - Program Manager
# Job number  698 added - Lead Data Engineer
# Job number  699 added - Technical Program Manager - Sensors and Compute
# Job number  700 added - Sr. Software Engineering Manager, Data
# Job number  701 added - District Sales Manager, Diabetes- Northern California
# Job number  702 added - Technical Project Manager for BI&DW Implementation Project
# Job number  703 added - Sr. IT Project Manager - Enterprise Applications
# Job number  704 added - Customer Success Manager
# Job number  705 added - Manager IS Analytics and Business Intelligence - FT - Days - IS Business Systems
# Job number  706 added - Senior Manager, Analysis, Environmental Markets
# Job number  707 added - Product Manager Palo Alto, CA
# Job number  708 added - Senior Control Account Manager
# Job number  709 added - Digital Platform Services - Data Analytics and Insights - Senior Manager
# Job number  710 added - Treasury Manager
# Job number  711 added - Strategic Account Manager - iGaming/Sports Betting - Remote
# Job number  712 added - Product Line Manager - Hyperscalers - Opportunity for Working Remotely Palo Alto, CA
# Job number  713 added - Clinical Informatics Supervisor II
# Job number  714 added - Senior Product Manager – Next Gen ADAS/AD
# Job number  715 added - Product Ideation Manager
# Job number  716 added - Platinion Risk Management Manager
# Job number  717 added - Email Marketing / CRM Manager
# Job number  718 added - Mgr, Finance & Analytics
# Job number  719 added - Manager, Structural Analysis
# Job number  720 added - Brand Manager
# Job number  721 added - Service Desk Manager
# Job number  722 added - IT Manager - InterContinental Los Angeles Downtown
# Job number  723 added - Operations Manager -LAX Los Angeles International Airport - Full-time
# Job number  724 added - Technical Program Manager- Test & Reliability
# Job number  725 added - Manager Data Architecture & BI
# Job number  726 added - UX Research Manager
# Job number  727 added - Senior Manager, Closed-End Portfolio Analytics, Risk and Reporting
# Job number  728 added - Senior Manager Data Science
# Job number  729 added - Digital Solutions Leader
# Job number  730 added - Product Manager - Technical II
# Job number  731 added - Trading Analytics Manager (Data Scientist)
# Job number  732 added - IT Project Manager (Hybrid)
# Job number  733 added - Sr. Business Analysis Manager
# Job number  734 added - Information Technology Project Manager
# Job number  735 added - Senior Technical Product Manager (Remote)
# Job number  736 added - Lead Analyst, Digital Sales
# Job number  737 added - District Service Manager
# Job number  738 added - Billing Analytics Supervisor
# Job number  739 added - Special Districts Project Manager (Sr. Administrative Analyst)
# Job number  740 added - SPS Financial Planning & Analysis Manager (Remote)
# Job number  741 added - Manager, Data & Analytics Technology Platform Administrator
# Job number  742 added - IT Project Manager - Infrastructure
# Job number  743 added - Technical Program Manager
# Job number  744 added - Social Media Insights & Analytics Manager
# Job number  745 added - Business Applications Manager-Contract
# Job number  746 added - FSQA Division Manager (Fresh)
# Job number  747 added - Marketing Technology Manager
# Job number  748 added - Senior Product Manager
# Job number  749 added - IT Infrastructure Manager (San Diego, CA)
# Job number  750 added - Manager of Audit II- Banking
# Job number  751 added - Quality Assurance Manager
# Job number  752 added - Fraud Risk Manager - Risk Policy and Solutions
# Job number  753 added - Benefits Program Manager, Americas
# Job number  754 added - Staff Product Manager, Staff Experience
# Job number  755 added - Senior Product Manager
# Job number  756 added - Global Program Manager, Customer Success
# Job number  757 added - Senior Manager SDN Networking, Kuiper Networking and ISP Services
# Job number  758 added - QA/QC Manager
# Job number  759 added - Product Manager - LC/QTOF
# Job number  760 added - Digital Transformation Business Development Manager
# Job number  761 added - Senior Business Systems Manager
# Job number  762 added - ATE Test Engineering - Manager/Director
# Job number  763 added - Manager, Product Management - New Products, Apple Store Online
# Job number  764 added - Associate Product Manager - Cloud Data Services
# Job number  765 added - Manager, Media Analytics (Remote)
# Job number  766 added - Ad Partnerships Lead
# Job number  767 added - Technical Program Manager (remote)
# Job number  768 added - Manager - Digital Analytics and Architecture
# Job number  769 added - EverHealth - Clinical Product Manager (Remote, US)
# Job number  770 added - Global Supply Manager
# Job number  771 added - Senior Manager, Financial Planning & Analysis
# Job number  772 added - Information Technology Specialist I - Manager I
# Job number  773 added - Senior Scientific Manager, Phenotypic Screening and Chemical Biology
# Job number  774 added - Project Manager, Health Care Information
# Job number  775 added - Senior Technical Program Manager, Global Labeling
# Job number  776 added - Senior Program Manager - Riverside, CA
# Job number  777 added - Senior Project Manager
# Job number  778 added - Senior Manager, Business and Data Analyst
# Job number  779 added - Finance Process Manager - USDS
# Job number  780 added - Product Manager
# Job number  781 added - Manager of Payment Management
# Job number  782 added - IT System Manager - Global Functions - 1117
# Job number  783 added - Senior Program Manager
# Job number  784 added - User Insights Program Manager
# Job number  785 added - Product Manager, Product Privacy
# Job number  786 added - Senior Product Manager, Data & Analytics
# Job number  787 added - Sr. Cyber Security Manager
# Job number  788 added - Analytics Manager
# Job number  789 added - IT Project Manager
# Job number  790 added - Manager - Digital Transformation
# Job number  791 added - Lead Legal Analyst
# Job number  792 added - Sr Manager Data Engineering
# Job number  793 added - TPMG Care Experience Practice Leader - East Bay.
# Job number  794 added - Senior Manager, Pharmacometrician (PK Data Scientist)
# Job number  795 added - Senior Product Manager, Personalization & Search
# Job number  796 added - General Manager
# Job number  797 added - Product Manager
# Job number  798 added - Data Science Team Lead (AI/ML) for BCI at Arctop
# Job number  799 added - Sr. Product Manager, Applications
# Job number  800 added - Senior Data Product Manager
# Job number  801 added - Senior Account Manager
# Job number  802 added - AVP, Special Assets Group Risk Manager
# Job number  803 added - IT CRM Manager
# Job number  804 added - Product Manager
# Job number  805 added - Senior Product Manager - B2B Product Led Growth
# Job number  806 added - Buying Assistant Manager
# Job number  807 added - Senior Manager, Internal Audit - Risk and Analytics
# Job number  808 added - Manager, Data Science
# Job number  809 added - Senior Product Manager
# Job number  810 added - SENIOR DATA GOVERNANCE MANAGER for (CDI2) CENTER FOR DATA-DRIVEN INSIGHTS AND INNOVATION (Remote position within California)
# Job number  811 added - R&D Engineering Manager
# Job number  812 added - Manager of Financial Planning and Analysis
# Job number  813 added - Enterprise Governance Project Manager V
# Job number  814 added - Finance Transformation Senior Manager
# Job number  815 added - Employee Listening Program Manager
# Job number  816 added - MANAGER, FINANCIAL PLANNING & ANALYSIS
# Job number  817 added - Engineering Manager- Product Development
# Job number  818 added - Product Manager
# Job number  819 added - Manager - Applications Software Engineering - Federal
# Job number  820 added - Principal Program Manager
# Job number  821 added - Senior Product Manager - Banking
# Job number  822 added - Product Manager, Charging (Digital Experience)
# Job number  823 added - Healthcare Analytics Manager/Senior Analyst
# Job number  824 added - Product Manager
# Job number  825 added - Senior Engineering Manager, Data & Analytics
# Job number  826 added - Space Systems Program Manager
# Job number  827 added - Senior Product Manager, Fulfillment Solutions (Remote Positions Available)
# Job number  828 added - Lead Experimentation Scientist
# Job number  829 added - Patient Experience Project Manager - FT - Days - Patient Experience
# Job number  830 added - Manager, Operations
# Job number  831 added - Manager, Service Desk
# Job number  832 added - Manager, Data Integrity & Reporting – Santa Monica, California
# Job number  833 added - Consumer Insights Manager- REMOTE
# Job number  834 added - IT Specialist - Desktop Support and CISCO Call Manager Experience
# Job number  835 added - Service Delivery Manager
# Job number  836 added - Sr Engineering Manager, Product ML Systems Evaluation Engineering
# Job number  837 added - Senior Product Manager - Marketer Persona
# Job number  838 added - Business Solutions Manager
# Job number  839 added - Sr. Product Manager
# Job number  840 added - Field Services Manager
# Job number  841 added - Project Manager (Pega / Appeals & Grievances) - REMOTE
# Job number  842 added - (Senior) Campaign Marketing Manager, Firewalls/CDSS
# Job number  843 added - Sr. Program Manager - Talent
# Job number  844 added - Accounting Manager
# Job number  845 added - Remote - Sr. Product Manager, Healthcare Innovation & Digital Strategy
# Job number  846 added - Technology Support Manager
# Job number  847 added - Project Manager - Product
# Job number  848 added - Senior Product Manager, Gaming
# Job number  849 added - SENIOR DATA GOVERNANCE MANAGER for (CDI2) CENTER FOR DATA-DRIVEN INSIGHTS AND INNOVATION (Remote position within California)

# %% [markdown]
# ### Scrape full job descriptions

# %%
Links_list = dataframe['Links'].tolist()

import random

async def get_description(urls):
  descriptions = []
  async with get_session(Geckodriver(binary=driver_path, log_file=asyncio.subprocess.PIPE), Firefox(**options)) as session:
    for url in urls:
      await session.get("https://www.indeed.com"+url)
      time.sleep(1) #adding a one-second delay
      jd = await session.get_element('#jobDescriptionText')
      descriptions.append(await jd.get_text())
      await asyncio.sleep(random.random() * 1.5)
  return descriptions

## Number of browser instances to use
n = 3

tasks = [asyncio.create_task(get_description(urls)) for urls in np.array_split(Links_list, n)]
dataframe['Descriptions'] = [desc for task in tasks for desc in await task]

# %% [markdown]
# ### Save results

# %%
# Convert the dataframe to a csv file
date = datetime.today().strftime('%Y-%m-%d')
dataframe.to_csv(date + "_" + position + "_" + locations + ".csv", index=False)

# %%
dataframe
# Out:
#                                                  Title  \
# 0                           Program Manager, Analytics
# 1                                Manager of Operations
# 2                                 User Support Manager
# 3                                    Pre-Award Manager
# 4                  Manager, CRM Data Science Analytics
# ..                                                 ...
# 844  Remote - Sr. Product Manager, Healthcare Innov...
# 845                         Technology Support Manager
# 846                          Project Manager - Product
# 847                     Senior Product Manager, Gaming
# 848  SENIOR DATA GOVERNANCE MANAGER for (CDI2) CENT...
#
#                                               Company  \
# 0                                              PayPal
# 1                                              SpaceX
# 2                                              TikTok
# 3                                         UCLA Health
# 4                                         Sephora USA
# ..                                                ...
# 844                                      City of Hope
# 845                       Pyramid Technology Services
# 846                              Alignment Healthcare
# 847                                              Yoom
# 848  University of California Office of the President
#
#                                        Location Rating  \
# 0               Remote in California+1 location    3.9
# 1    Hawthorne, CA 90250 (North Hawthorne area)    3.6
# 2                               Los Angeles, CA    3.4
# 3                         Los Angeles, CA 90095    4.0
# 4             Remote in San Francisco, CA 94105    3.8
# ..                                          ...    ...
# 844                  Remote in Duarte, CA 91009    3.7
# 845                               Riverside, CA    NaN
# 846                                  California    2.8
# 847                             Los Angeles, CA    NaN
# 848                 Remote in Oakland, CA 94607    4.1
#
#                           Date                      Salary  \
# 0    PostedPosted 30+ days ago   $84,500 - $204,600 a year
# 1    PostedPosted 30+ days ago  $130,000 - $180,000 a year
# 2    PostedPosted 30+ days ago  $101,333 - $188,522 a year
# 3    PostedPosted 30+ days ago   $61,400 - $121,400 a year
# 4     PostedPosted 13 days ago  $179,878 - $180,878 a year
# ..                         ...                         ...
# 844   PostedPosted 22 days ago     $59.44 - $99.27 an hour
# 845   PostedPosted 22 days ago    $86,000 - $90,000 a year
# 846  PostedPosted 30+ days ago                         NaN
# 847  PostedPosted 30+ days ago             $150,000 a year
# 848  PostedPosted 30+ days ago                 $28 an hour
#
#                                            Description  \
# 0    You will have exposure and visibility to PayPa...
# 1    SpaceX was founded under the belief that a fut...
# 2    TikTok is the leading destination for short-fo...
# 3    Minimum 3-years pre-award experience with NIH ...
# 4    Define marketing analytics requirements for ML...
# ..                                                 ...
# 844  City of Hope's mission is to deliver the cures...
# 845  Riverside, California - 2023-04-05 Technology ...
# 846  Alignment Health was founded with a mission to...
# 847  We are seeking an experienced Senior Product M...
# 848  Advanced written, verbal, and analytic skills,...
#
#                                                  Links  \
# 0    /rc/clk?jk=d80c44b2b2ed76a1&fccid=978d9fd9799d...
# 1    /rc/clk?jk=e713533258f4bd4f&fccid=8bc01be85b97...
# 2    /rc/clk?jk=af2cfc39b44a3fb8&fccid=caed318a9335...
# 3    /rc/clk?jk=c8d09b99bad832d6&fccid=74540dcd08f5...
# 4    /rc/clk?jk=8dbca01bb3417326&fccid=afda98bfc822...
# ..                                                 ...
# 844  /rc/clk?jk=5e27837917748aeb&fccid=e4c4ad85ebf2...
# 845  /rc/clk?jk=a0078795d802b6c4&fccid=07954fd3e787...
# 846  /rc/clk?jk=c875ad0748f6ed34&fccid=b671a434bbdb...
# 847  /rc/clk?jk=c2ecfa7ea5877354&fccid=95ab4146c159...
# 848  /rc/clk?jk=42371929edb0e61f&fccid=26da5e76f463...
#
#                                           Descriptions
# 0    At PayPal (NASDAQ: PYPL), we believe that ever...
# 1    SpaceX was founded under the belief that a fut...
# 2    Responsibilities\nTikTok is the leading destin...
# 3    Description\nThe Semel Institute for Neuroscie...
# 4    Position\nManager, CRM Data Science Analytics\...
# ..                                                 ...
# 844  About City of Hope\nCity of Hope's mission is ...
# 845  Riverside, California - 2023-04-05 Technology ...
# 846  Job Number 4903\nRemote - CA , California\nAli...
# 847  We are seeking an experienced Senior Product M...
# 848  For UCOP internal applicants, please login to ...
#
# [849 rows x 9 columns]
