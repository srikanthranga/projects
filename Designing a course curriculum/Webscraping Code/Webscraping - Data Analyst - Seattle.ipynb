# %% [markdown]
# # Web Scraping - Indeed.com
# General steps for Web Scraping
# 1. Check whether the website allows web scraping
# 2. Obtain the source code (HTML File) by using the website URL
# 3. Download the website content
# 4. Parse the content using keywords tags for elements of interest
# 5. Extract relevant data/features
# 6. Organize raw data in structured format (e.g., CSV)

# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from datetime import datetime
from arsenic import get_session
from arsenic.browsers import Firefox
from arsenic.services import Geckodriver
import asyncio
import time

# disable arsenic logging to stdout
import structlog
import logging

logger = logging.getLogger()
logger.setLevel(logging.WARN)
structlog.configure(logger_factory=lambda: logger)

# %% [markdown]
# ### Path to webdriver (Firefox, Chrome)

# %%
# Ensure that the driver path is correct before running this script.
# Microsoft Windows
# driver_path = "./drivers/windows/geckodriver.exe"
#driver_path = "./programs/geckodriver.exe"
driver_path = r"C:\Users\ranga\Downloads\geckodriver-v0.32.1-win64\geckodriver.exe"
# Linux
# driver_path = "./drivers/linux/geckodriver"
# driver_path = "/usr/bin/geckodriver"

options = {
  'moz:firefoxOptions': {
    # if you want it to be headless
    'args': ['-headless'],
    'log': {'level': 'warn'},
    # Needed for windows / non-default firefox install
    'binary': 'C:\\Program Files\\Mozilla Firefox\\firefox.exe'
  }
}

# %% [markdown]
# ### Define position and location

# %%
## Enter a job position
position = "data analyst"
## Enter a location (City, State or Zip or remote)
locations = "seattle"

def get_url(position, location):
    url_template = "https://www.indeed.com/jobs?q={}&l={}"
    url = url_template.format(position, location)
    return url

url = get_url(position, locations)
dataframe = pd.DataFrame(columns=["Title", "Company", "Location", "Rating", "Date", "Salary", "Description", "Links"])

# %% [markdown]
# ### Scrape job postings

# %%
## Number of postings to scrape
postings = 1600

## Number of browser instances to use
n = 3

pages = list(range(0, postings, 7))

state = {
  'lock': asyncio.Lock(),
  'ids': set(),
  'n': 0
}
             
async def get_jobs(url, pages, state):
  data = []
  async with get_session(Geckodriver(binary=driver_path, log_file=asyncio.subprocess.PIPE), Firefox(**options)) as session:
    for i in pages:
      await session.get(url + "&start=" + str(i))
      jobs = await session.get_elements("[class='job_seen_beacon']")

      for job in jobs:
        result_html = await job.get_property('innerHTML')
        soup = BeautifulSoup(result_html, 'html.parser')

        liens = await job.get_elements("a")
        link = await liens[0].get_attribute("href")

        title = soup.select('.jobTitle')[0].get_text().strip()
        try:
          company = soup.select('.companyName')[0].get_text().strip()
        except:
          continue
        location = soup.select('.companyLocation')[0].get_text().strip()
        try:
            salary = soup.select('.salary-snippet-container')[0].get_text().strip()
        except:
            salary = 'NaN'
        try:
            rating = soup.select('.ratingNumber')[0].get_text().strip()
        except:
            rating = 'NaN'
        try:
            date = soup.select('.date')[0].get_text().strip()
        except:
            date = 'NaN'
        try:
            description = soup.select('.job-snippet')[0].get_text().strip()
        except:
            description = ''
            
        Id = f"{title}{company}{location}{rating}{date}{salary}{description}"
        dupe = False
        async with state['lock']:
          if Id in state['ids']:
            dupe = True
          else:
            state['ids'].add(Id)
            state['n'] = state['n'] + 1
            print("Job number {0:4d} added - {1:s}".format(state['n'],title))
        if dupe:
          continue

        data.append({
          'Title': title,
          "Company": company,
          'Location': location,
          'Rating': rating,
          'Date': date,
          "Salary": salary,
          "Description": description,
          "Links": link
        })

        # print("Job number {0:4d} added - {1:s}".format(jn,title))
      i = i + 10
  return data

tasks = [asyncio.create_task(get_jobs(url, p, state)) for p in np.array_split(pages, n)]
dataframe = pd.DataFrame([j for task in tasks for j in await task])
# Out:
# Job number    1 added - DATA ANALYST
# Job number    2 added - Data Analyst - Tiktok Ads
# Job number    3 added - Senior Financial Analyst - Customer Service
# Job number    4 added - Sr. Business Intelligence Analyst (Remote Eligible)
# Job number    5 added - Data Analyst
# Job number    6 added - Business Analyst Consultant
# Job number    7 added - Data Analyst (Remote)
# Job number    8 added - Senior Compensation Analyst - PSE
# Job number    9 added - Data Operations Analyst
# Job number   10 added - Tax - Business Analyst - Lead
# Job number   11 added - Data Analyst
# Job number   12 added - Business Analyst, Revenue Accounting
# Job number   13 added - Data Analyst I - Human Cell Types
# Job number   14 added - digital asset management business analyst - hybrid
# Job number   15 added - Data Analyst (Seattle or US Remote)
# Job number   16 added - Salesforce Business Analyst - Remote
# Job number   17 added - DATA ANALYST, EVALUATIONS
# Job number   18 added - Data Analytics Lead, Cell Therapy
# Job number   19 added - Data Privacy Analyst III
# Job number   20 added - Compensation Analyst
# Job number   21 added - Data Analyst
# Job number   22 added - Product Strategy & Operations Analyst (USA)
# Job number   23 added - Data Analyst
# Job number   24 added - Senior Business Analyst ERP - Sourcing
# Job number   25 added - Data Analyst - Tiktok Ads and Monetization Products
# Job number   26 added - Sr. Product Strategy & Operations Analyst (USA)
# Job number   27 added - Privacy Data Analyst
# Job number   28 added - Staff Analyst
# Job number   29 added - Clinical Data Analyst
# Job number   30 added - Operations Systems Analyst
# Job number   31 added - Board Certified Behavior Analyst (BCBA)
# Job number   32 added - Data Analyst- Healthcare Consulting
# Job number   33 added - Data Analyst - Marketing
# Job number   34 added - Senior Data Analyst
# Job number   35 added - Senior Data Analyst (Hybrid)
# Job number   36 added - Growth Data Analyst
# Job number   37 added - RESEARCH SCIENTIST, STATISTICAL ANALYST
# Job number   38 added - Health Care Data Analyst
# Job number   39 added - Business Analyst
# Job number   40 added - BUSINESS INTELLIGENCE ANALYST
# Job number   41 added - BUSINESS ANALYST
# Job number   42 added - Data Analyst
# Job number   43 added - Sales Operation Data Analyst
# Job number   44 added - ITSM Analyst II
# Job number   45 added - Business Data Analyst
# Job number   46 added - Senior Data Analyst, Research Success
# Job number   47 added - Senior Logistics Analyst (Hybrid)
# Job number   48 added - SR. DATA ANALYST (REMOTE NATIONWIDE)
# Job number   49 added - Senior Financial Analyst - Customer Service
# Job number   50 added - Sr. Business Intelligence Analyst (Remote Eligible)
# Job number   51 added - Business Analyst Consultant
# Job number   52 added - Senior Data Analyst
# Job number   53 added - Sr. Data Analyst (Product)
# Job number   54 added - Sr. Data Analyst - Greenhouse Gas Compliance
# Job number   55 added - Senior Compensation Analyst - PSE
# Job number   56 added - Financial Data and Reporting Analyst
# Job number   57 added - Tax - Business Analyst - Lead
# Job number   58 added - Part-Time Data Entry Analyst - Solvas Financial Technology
# Job number   59 added - Business Analyst, Revenue Accounting
# Job number   60 added - Equity and Inclusion Data Analyst
# Job number   61 added - digital asset management business analyst - hybrid
# Job number   62 added - Senior Clinical Data Analyst
# Job number   63 added - Senior Quality Improvement Data Analyst - Remote
# Job number   64 added - Salesforce Business Analyst - Remote
# Job number   65 added - Data Analyst, Senior ~ Enterprise Data Management
# Job number   66 added - Data Analytics Lead, Cell Therapy
# Job number   67 added - Data Visualization Analyst (264)
# Job number   68 added - Compensation Analyst
# Job number   69 added - Benefits and Financial Data Analyst
# Job number   70 added - Product Strategy & Operations Analyst (USA)
# Job number   71 added - Business Systems Analyst I
# Job number   72 added - Senior Business Analyst ERP - Sourcing
# Job number   73 added - Business Intelligence Analyst
# Job number   74 added - Board Certified Behavior Analyst (BCBA)
# Job number   75 added - Operations Systems Analyst
# Job number   76 added - Sr. Product Strategy & Operations Analyst (USA)
# Job number   77 added - Data Analyst
# Job number   78 added - Data Reporting and Financial Analyst
# Job number   79 added - PCI Compliance Analyst
# Job number   80 added - Senior Data Analyst
# Job number   81 added - Lead Data Analyst
# Job number   82 added - Business Analyst - Sales and Investments
# Job number   83 added - Sr. Sales Business Intelligence Analyst
# Job number   84 added - Sr. IT Business Analyst (remote)
# Job number   85 added - Systems Data Analyst
# Job number   86 added - Business Analyst, Sponsorship & Ticketing
# Job number   87 added - Power BI Business Analyst - Data Focused
# Job number   88 added - Sr Data & Insights Analyst (Bilingual Japanese)
# Job number   89 added - Senior Policy Analyst
# Job number   90 added - Business Analyst
# Job number   91 added - Credit Risk Analyst (Data Analyst)
# Job number   92 added - Business Analyst
# Job number   93 added - BUSINESS ANALYST
# Job number   94 added - Senior Analyst, Data Strategy and Insights
# Job number   95 added - Project Consulting & Data Analyst
# Job number   96 added - Business Intelligence Analyst (Remote Eligible)
# Job number   97 added - Senior Utility Analyst, Principal Utility Analyst or Data Scientist
# Job number   98 added - Underwriting Analyst-Employee Benefits
# Job number   99 added - Clinical Trial Business Analyst
# Job number  100 added - Business Analyst I, II, III, Senior
# Job number  101 added - Senior Business Analyst
# Job number  102 added - Business Analyst Consultant
# Job number  103 added - Data Analyst/Report Developer
# Job number  104 added - Data Analyst Consultant
# Job number  105 added - Business Intelligence Analyst (Remote)
# Job number  106 added - Product Data Analyst
# Job number  107 added - IT Functional Analyst
# Job number  108 added - Business Analyst, Revenue Accounting
# Job number  109 added - digital asset management business analyst - hybrid
# Job number  110 added - Business Analyst
# Job number  111 added - Business Intelligence Analyst
# Job number  112 added - DENIALS MANAGEMENT ANALYST
# Job number  113 added - Content Analyst
# Job number  114 added - Business Analyst II - Product Analytics
# Job number  115 added - Business Analyst - Diligence
# Job number  116 added - Medicaid Data Advisory Services Analyst
# Job number  117 added - SHARED ENVIRONMENT ACCOUNTING ANALYST
# Job number  118 added - Senior Systems Analyst Development & Lab Data
# Job number  119 added - Call and Referral Data Analyst
# Job number  120 added - Business Analyst
# Job number  121 added - Content Analyst
# Job number  122 added - Operations Systems Analyst
# Job number  123 added - Business Analyst, eCommerce
# Job number  124 added - HEDIS/CMS Stars Data Quality Analyst
# Job number  125 added - Facilities Planning Analyst
# Job number  126 added - Aftersales Business Analyst
# Job number  127 added - Senior Data Visualization Specialist
# Job number  128 added - Analyst, Social
# Job number  129 added - Business Data Analyst - Auburn, WA
# Job number  130 added - Business Intelligence Analyst III (Digital Marketing + Email)
# Job number  131 added - Business Analyst
# Job number  132 added - Business Analyst - Remote
# Job number  133 added - SENIOR SAP MASTER DATA ANALYST - HYBRID
# Job number  134 added - Ecommerce Business Analyst - International
# Job number  135 added - IT Data and Security Support Analyst
# Job number  136 added - Healthcare Data Analyst
# Job number  137 added - Business Analyst (Retail Planning)
# Job number  138 added - Enabling Tech & Analytics Reporting and Functional Analyst - National_Office
# Job number  139 added - Business Analyst II
# Job number  140 added - Financial Data Analyst
# Job number  141 added - Business Analyst - Bellevue
# Job number  142 added - Demand Analyst I
# Job number  143 added - Configuration & Data Management Analyst II (Fixed-Term)
# Job number  144 added - Configuration & Data Management Analyst
# Job number  145 added - Health Solutions Financial Management Consultant/Analyst
# Job number  146 added - Senior Business Data Analyst, Revenue Cycle, Remote
# Job number  147 added - Senior Financial Analyst
# Job number  148 added - Planning and Inventory Analyst
# Job number  149 added - Senior Business Analyst
# Job number  150 added - Senior Business Analyst, Sort Tech
# Job number  151 added - Salesforce Administrator/Analyst - Global CRM
# Job number  152 added - Sr Business Analyst
# Job number  153 added - Senior Healthcare Analyst
# Job number  154 added - Sr. Business Analyst
# Job number  155 added - Stroke RN Data Analyst
# Job number  156 added - Business Analyst (306)
# Job number  157 added - Business Intelligence Analyst
# Job number  158 added - HR Analyst
# Job number  159 added - Staff Analyst
# Job number  160 added - Business Analyst (W2)
# Job number  161 added - Senior-Technology Business Analysis
# Job number  162 added - Senior Asset & Performance Systems Analyst (Senior Management Systems Analyst)
# Job number  163 added - Sr Analyst, Business Analysis
# Job number  164 added - Data Analyst
# Job number  165 added - Financial Reporting & Analytics Analyst
# Job number  166 added - Senior Business Analyst, Global E-commerce
# Job number  167 added - Business Analyst
# Job number  168 added - Senior Business Analyst
# Job number  169 added - Sr. Technical Business Analyst (308)
# Job number  170 added - ERP Data Migration Analyst
# Job number  171 added - Cost Analyst/Accountant
# Job number  172 added - Asset Analyst - Software Asset Management
# Job number  173 added - Sr Business Analyst
# Job number  174 added - Sr. Market Research Analyst
# Job number  175 added - Risk Modeling Services - DF Data Scientist - Senior Associate
# Job number  176 added - Sr. System Analyst (OMS/WMS Systems)
# Job number  177 added - HR Business Intelligence Analyst - Remote - US
# Job number  178 added - Compensation Analyst - PSE
# Job number  179 added - Energy Management Analyst, Senior
# Job number  180 added - Business Analyst 3
# Job number  181 added - Business Analyst
# Job number  182 added - Senior Analyst Digital & Marketing Product Management(Hybrid/Bellevue)
# Job number  183 added - Commercial Success Analyst
# Job number  184 added - Revenue Management Analyst - Remote - US
# Job number  185 added - Senior Financial Analyst - Digital Finance (Hybrid Seattle)
# Job number  186 added - SAP Data Migration Analyst, Sr. Associate
# Job number  187 added - Business Analyst / Bellevue, WA / Business / SAGS7103717
# Job number  188 added - Jr. Real Estate Analyst
# Job number  189 added - Business Analyst, Dealer Systems
# Job number  190 added - Senior Compensation Analyst
# Job number  191 added - Noise Analyst II
# Job number  192 added - Data Analyst
# Job number  193 added - Board Certified Behavior Analyst
# Job number  194 added - Lead Business Analyst - Accelsior
# Job number  195 added - Senior Trademark Analyst
# Job number  196 added - Senior Data Analyst
# Job number  197 added - Cost Analyst/Accountant
# Job number  198 added - Salesforce Business Analyst - Remote
# Job number  199 added - Cost Analyst/Accountant
# Job number  200 added - Salesforce Business Analyst - Remote

# %% [markdown]
# ### Scrape full job descriptions

# %%
Links_list = dataframe['Links'].tolist()

import random

async def get_description(urls):
  descriptions = []
  async with get_session(Geckodriver(binary=driver_path, log_file=asyncio.subprocess.PIPE), Firefox(**options)) as session:
    for url in urls:
      await session.get("https://www.indeed.com"+url)
      time.sleep(1) #adding a one-second delay
      jd = await session.get_element('#jobDescriptionText')
      descriptions.append(await jd.get_text())
      await asyncio.sleep(random.random() * 1.5)
  return descriptions

## Number of browser instances to use
n = 3

tasks = [asyncio.create_task(get_description(urls)) for urls in np.array_split(Links_list, n)]
dataframe['Descriptions'] = [desc for task in tasks for desc in await task]

# %% [markdown]
# ### Save results

# %%
# Convert the dataframe to a csv file
date = datetime.today().strftime('%Y-%m-%d')
dataframe.to_csv(date + "_" + position + "_" + locations + ".csv", index=False)

# %%
dataframe
# Out:
#                                                Title  \
# 0                                       DATA ANALYST
# 1                          Data Analyst - Tiktok Ads
# 2                                       Data Analyst
# 3                              Data Analyst (Remote)
# 4                            Data Operations Analyst
# ..                                               ...
# 195           Senior Business Analyst ERP - Sourcing
# 196          Board Certified Behavior Analyst (BCBA)
# 197                       Operations Systems Analyst
# 198  Sr. Product Strategy & Operations Analyst (USA)
# 199                          Cost Analyst/Accountant
#
#                             Company  \
# 0          University of Washington
# 1                            TikTok
# 2    Foundation for Tacoma Students
# 3                Path Mental Health
# 4                         BlackRock
# ..                              ...
# 195                          Seagen
# 196              Holly Ridge Center
# 197                  City of SeaTac
# 198                            Lyft
# 199                        Qualitel
#
#                                          Location Rating  \
# 0    Seattle, WA 98195 (University District area)    4.1
# 1                                     Seattle, WA    3.4
# 2               Hybrid remote in Tacoma, WA 98405    4.5
# 3                           Remote in Seattle, WA    4.7
# 4                    Hybrid remote in Seattle, WA    3.8
# ..                                            ...    ...
# 195                             Bothell, WA 98021    3.5
# 196                           Bremerton, WA 98312    4.2
# 197                              SeaTac, WA 98188    3.4
# 198                         Remote in Seattle, WA    3.5
# 199                Everett, WA 98204 (Holly area)    2.8
#
#                           Date                      Salary  \
# 0      PostedPosted 5 days ago     $5,747 - $6,304 a month
# 1    PostedPosted 30+ days ago  $114,000 - $209,000 a year
# 2      PostedPosted 3 days ago    $55,000 - $70,000 a year
# 3     PostedPosted 26 days ago                         NaN
# 4      PostedPosted 7 days ago    $76,000 - $90,000 a year
# ..                         ...                         ...
# 195  PostedPosted 30+ days ago  $127,000 - $164,000 a year
# 196  PostedPosted 30+ days ago     $29.25 - $32.95 an hour
# 197  PostedPosted 30+ days ago                         NaN
# 198    PostedPosted 3 days ago                         NaN
# 199  PostedPosted 30+ days ago                         NaN
#
#                                            Description  \
# 0    Bring together data, analytic engines, and dat...
# 1    Expert experience pulling large and complex da...
# 2    Audits systems and troubleshoot data submissio...
# 3    High focus to detail, including knowing explic...
# 4    Data Operations and Solutions is entrusted wit...
# ..                                                 ...
# 195  Seagen is a global, multi-product biotechnolog...
# 196  Holly Ridge Center is currently recruiting for...
# 197  JOB This position is overtime eligible and a m...
# 198  At Lyft, our mission is to improve people's li...
# 199  Experience with accessing complex data from SQ...
#
#                                                  Links  \
# 0    /rc/clk?jk=67267e3e9ee7c149&fccid=142783ac2edb...
# 1    /rc/clk?jk=ea2bf81d89f746f0&fccid=caed318a9335...
# 2    /pagead/clk?mo=r&ad=-6NYlbfkN0Alt2oG4DKRumPSQw...
# 3    /rc/clk?jk=eb7fe532e33d887a&fccid=d8ebbe8fe3f1...
# 4    /rc/clk?jk=bcd87601c39e0922&fccid=58c732f14833...
# ..                                                 ...
# 195  /rc/clk?jk=be373dcac19941d8&fccid=52558a648544...
# 196  /rc/clk?jk=3de916be95553e62&fccid=df45baffc979...
# 197  /rc/clk?jk=e32298bcc9b93f6b&fccid=73601eb07244...
# 198  /rc/clk?jk=ab6c26a3f5abad8b&fccid=7dcf8477ac40...
# 199  /rc/clk?jk=297734415e6c1657&fccid=249cec7822bd...
#
#                                           Descriptions
# 0    Benefits:\nAs a UW employee, you will enjoy ge...
# 1    Responsibilities\nTikTok is the leading destin...
# 2    Job Description | Data Analyst | Exempt\nAre y...
# 3    Who we are\nPath is a healthtech company dedic...
# 4    Description\nAbout this role\nBlackRock is one...
# ..                                                 ...
# 195  Seagen is a global, multi-product biotechnolog...
# 196  Holly Ridge Center is currently recruiting for...
# 197  JOB\nThis position is overtime eligible and a ...
# 198  At Lyft, our mission is to improve people's li...
# 199  QUALITEL Profile:\nQualitel is a contract manu...
#
# [200 rows x 9 columns]
