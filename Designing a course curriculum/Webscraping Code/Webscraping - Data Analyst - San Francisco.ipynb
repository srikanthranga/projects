# %% [markdown]
# # Web Scraping - Indeed.com
# General steps for Web Scraping
# 1. Check whether the website allows web scraping
# 2. Obtain the source code (HTML File) by using the website URL
# 3. Download the website content
# 4. Parse the content using keywords tags for elements of interest
# 5. Extract relevant data/features
# 6. Organize raw data in structured format (e.g., CSV)

# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from datetime import datetime
from arsenic import get_session
from arsenic.browsers import Firefox
from arsenic.services import Geckodriver
import asyncio
import time

# disable arsenic logging to stdout
import structlog
import logging

logger = logging.getLogger()
logger.setLevel(logging.WARN)
structlog.configure(logger_factory=lambda: logger)

# %% [markdown]
# ### Path to webdriver (Firefox, Chrome)

# %%
# Ensure that the driver path is correct before running this script.
# Microsoft Windows
# driver_path = "./drivers/windows/geckodriver.exe"
#driver_path = "./programs/geckodriver.exe"
driver_path = r"C:\Users\ranga\Downloads\geckodriver-v0.32.1-win64\geckodriver.exe"
# Linux
# driver_path = "./drivers/linux/geckodriver"
# driver_path = "/usr/bin/geckodriver"

options = {
  'moz:firefoxOptions': {
    # if you want it to be headless
    'args': ['-headless'],
    'log': {'level': 'warn'},
    # Needed for windows / non-default firefox install
    'binary': 'C:\\Program Files\\Mozilla Firefox\\firefox.exe'
  }
}

# %% [markdown]
# ### Define position and location

# %%
## Enter a job position
position = "data analyst"
## Enter a location (City, State or Zip or remote)
locations = "san francisco"

def get_url(position, location):
    url_template = "https://www.indeed.com/jobs?q={}&l={}"
    url = url_template.format(position, location)
    return url

url = get_url(position, locations)
dataframe = pd.DataFrame(columns=["Title", "Company", "Location", "Rating", "Date", "Salary", "Description", "Links"])

# %% [markdown]
# ### Scrape job postings

# %%
## Number of postings to scrape
postings = 1600

## Number of browser instances to use
n = 3

pages = list(range(0, postings, 7))

state = {
  'lock': asyncio.Lock(),
  'ids': set(),
  'n': 0
}
             
async def get_jobs(url, pages, state):
  data = []
  async with get_session(Geckodriver(binary=driver_path, log_file=asyncio.subprocess.PIPE), Firefox(**options)) as session:
    for i in pages:
      await session.get(url + "&start=" + str(i))
      jobs = await session.get_elements("[class='job_seen_beacon']")

      for job in jobs:
        result_html = await job.get_property('innerHTML')
        soup = BeautifulSoup(result_html, 'html.parser')

        liens = await job.get_elements("a")
        link = await liens[0].get_attribute("href")

        title = soup.select('.jobTitle')[0].get_text().strip()
        try:
          company = soup.select('.companyName')[0].get_text().strip()
        except:
          continue
        location = soup.select('.companyLocation')[0].get_text().strip()
        try:
            salary = soup.select('.salary-snippet-container')[0].get_text().strip()
        except:
            salary = 'NaN'
        try:
            rating = soup.select('.ratingNumber')[0].get_text().strip()
        except:
            rating = 'NaN'
        try:
            date = soup.select('.date')[0].get_text().strip()
        except:
            date = 'NaN'
        try:
            description = soup.select('.job-snippet')[0].get_text().strip()
        except:
            description = ''
            
        Id = f"{title}{company}{location}{rating}{date}{salary}{description}"
        dupe = False
        async with state['lock']:
          if Id in state['ids']:
            dupe = True
          else:
            state['ids'].add(Id)
            state['n'] = state['n'] + 1
            print("Job number {0:4d} added - {1:s}".format(state['n'],title))
        if dupe:
          continue

        data.append({
          'Title': title,
          "Company": company,
          'Location': location,
          'Rating': rating,
          'Date': date,
          "Salary": salary,
          "Description": description,
          "Links": link
        })

        # print("Job number {0:4d} added - {1:s}".format(jn,title))
      i = i + 10
  return data

tasks = [asyncio.create_task(get_jobs(url, p, state)) for p in np.array_split(pages, n)]
dataframe = pd.DataFrame([j for task in tasks for j in await task])
# Out:
# Job number    1 added - Data Analyst
# Job number    2 added - Senior Data Analyst
# Job number    3 added - Classification and Compensation Analyst (Confidential Administrative Support II) - Office of Human Resources
# Job number    4 added - Data Analyst
# Job number    5 added - Programs & Outreach Coordinator (Administrative Analyst/Specialist - Exempt I) - Institute for Civic & Community Engagement
# Job number    6 added - Data Analyst
# Job number    7 added - Academic Office Coordinator (Administrative Analyst/Specialist, Exempt I) - Computer Science, College of Science & Engineering
# Job number    8 added - Production Analyst
# Job number    9 added - Education Services Analyst - Administrative Analyst Specialist Exempt I
# Job number   10 added - Data Analyst
# Job number   11 added - Grant Support Coordinator (Administrative Analyst/Specialist, Non-Exempt) - Office of Research and Sponsored Programs
# Job number   12 added - Compliance Coordinator (Administrative Analyst/Specialist, Non-Exempt) - Office of Research and Sponsored Program
# Job number   13 added - DATAA001291 Data Analyst
# Job number   14 added - Position Control Analyst - Office of Sr. Business Officer (2022-23)
# Job number   15 added - Data Analyst
# Job number   16 added - Compliance and Systems Analyst
# Job number   17 added - Data Analyst
# Job number   18 added - Research Analyst
# Job number   19 added - data analyst
# Job number   20 added - Senior Programmer Analyst (Senior IT Business Analyst)
# Job number   21 added - Program Analyst, Electronic Revenue Operations
# Job number   22 added - Data Analyst
# Job number   23 added - Senior Talent Acquisition Analyst (Senior Human Resources Analyst) (AM)
# Job number   24 added - Health IT Senior Business Analyst – Limited Term (Open)
# Job number   25 added - Senior Data Analyst
# Job number   26 added - Human Resources Analyst I or II (Employee and Labor Relations Unit)
# Job number   27 added - DATA ANALYST
# Job number   28 added - Associate Program Analyst
# Job number   29 added - Data Analyst
# Job number   30 added - Data Analyst
# Job number   31 added - Business Analyst
# Job number   32 added - Senior Data Analyst
# Job number   33 added - Data Analyst
# Job number   34 added - Senior Data Analyst (Product Analytics)
# Job number   35 added - Senior Data Analyst
# Job number   36 added - Recruitment and Retention Data Analyst - SFPD (1823)
# Job number   37 added - Marketing Data Analyst
# Job number   38 added - Business Data Analyst
# Job number   39 added - Business Analyst
# Job number   40 added - Go to Market Data Analyst
# Job number   41 added - Senior Data Analyst
# Job number   42 added - Healthcare Data Analyst
# Job number   43 added - Data Engineer (Senior Technology Analyst) (JO#5883)
# Job number   44 added - Data Analyst
# Job number   45 added - MARKETING DATA ANALYST (FREELANCE)
# Job number   46 added - Data Analyst, Marketing
# Job number   47 added - Trainee - Business Analyst
# Job number   48 added - Data Analyst
# Job number   49 added - Senior Data Analyst
# Job number   50 added - Data Analyst
# Job number   51 added - Business Analyst
# Job number   52 added - Data Analyst
# Job number   53 added - SFFD EMS COMMUNITY PARAMEDICINE DATA AND POLICY ANALYST
# Job number   54 added - Senior Data Analyst - Finance
# Job number   55 added - Sr. BI Analyst
# Job number   56 added - Senior Analyst, Data and Analysis
# Job number   57 added - Data Reporting and Analytics Consultant II
# Job number   58 added - Business Analyst (Entry Level)
# Job number   59 added - Data Analyst
# Job number   60 added - Business Analyst, Principal - Health Data Strategy
# Job number   61 added - Analyst, Enterprise Analytics
# Job number   62 added - BI Business Analyst
# Job number   63 added - Senior Marketing Data Analyst
# Job number   64 added - Data Analyst, Marketing
# Job number   65 added - Paid Bootcamp- STEM Entry Level Data Analyst and Visualization
# Job number   66 added - Data Analyst
# Job number   67 added - Business Intelligence Analyst
# Job number   68 added - Data Systems/Cloud Data Warehouse Business Systems Analyst (JO#5882)
# Job number   69 added - Senior Data Analyst
# Job number   70 added - Healthcare Economics Data Analyst
# Job number   71 added - Senior Reliability Data Analyst
# Job number   72 added - Business Analyst
# Job number   73 added - Data Analyst
# Job number   74 added - Data Visualization & Democratization, Consultant
# Job number   75 added - Data Governance Analyst
# Job number   76 added - Herbarium Data Analyst/Coordinator
# Job number   77 added - Business Process and Data Analyst
# Job number   78 added - Data Analyst
# Job number   79 added - Sr. Business Systems Analyst (Data Analyst)
# Job number   80 added - Marketing Strategy Analyst \u007C Remote, USA
# Job number   81 added - Data Scientist (Senior Analyst)
# Job number   82 added - Data Hacker / Analyst
# Job number   83 added - Sr. Data and Reporting Analyst
# Job number   84 added - DATA ANALYST |pharma
# Job number   85 added - Business Analyst
# Job number   86 added - Health Technology Data Sr. Analyst
# Job number   87 added - Sr. Fraud Data Analyst
# Job number   88 added - Business Intelligence Data Analyst
# Job number   89 added - Digital Data Analyst (Google Analytics)- Remote
# Job number   90 added - Sr. Data Analyst
# Job number   91 added - Operations Data Analyst
# Job number   92 added - Academic Office Coordinator (Administrative Analyst/Specialist, Exempt I) - Computer Science, College of Science & Engineering
# Job number   93 added - Grant Support Coordinator (Administrative Analyst/Specialist, Non-Exempt) - Office of Research and Sponsored Programs
# Job number   94 added - Compliance Coordinator (Administrative Analyst/Specialist, Non-Exempt) - Office of Research and Sponsored Program
# Job number   95 added - Compliance and Systems Analyst
# Job number   96 added - Senior Talent Acquisition Analyst (Senior Human Resources Analyst) (AM)
# Job number   97 added - Associate Program Analyst
# Job number   98 added - Business Analyst
# Job number   99 added - Health IT Senior Business Analyst – Limited Term (Open)
# Job number  100 added - Health Care Analyst - Access to City Employment (ACE) (2119)
# Job number  101 added - Business Intelligence Analyst
# Job number  102 added - Lead Transaction Data Analyst - Hybrid
# Job number  103 added - Senior Marketplace Insights Data Analyst
# Job number  104 added - Crime Analyst (BPOA)
# Job number  105 added - Senior Analyst, Airbnb for Real Estate
# Job number  106 added - Business Analyst (Remote - U.S. only)
# Job number  107 added - Senior Data Analyst - Sustainability
# Job number  108 added - Data Analyst - Early Clinical Development
# Job number  109 added - Data Analyst (Contractor)
# Job number  110 added - Privacy Data Analyst
# Job number  111 added - Email Marketing Data Analyst
# Job number  112 added - Data and Evaluation Management Analyst (Open and Promotional)
# Job number  113 added - Address Dataset Maintenance Analyst- Department of Technology (1051)
# Job number  114 added - Program Operations Analyst
# Job number  115 added - Data Analyst/Tableau Developer (W2)
# Job number  116 added - Business Intelligence Analyst || Start-up Opportunity ||
# Job number  117 added - Data Visualization & Democratization, Expert
# Job number  118 added - Data Analyst
# Job number  119 added - Sr, Data Analyst
# Job number  120 added - Business Analyst
# Job number  121 added - Hubspot System Admin and CRM Data Analyst
# Job number  122 added - Data Analytics/Data Analyst(W2 ONLY)
# Job number  123 added - Implementation Business Analyst
# Job number  124 added - Technical Business Analyst (USA)
# Job number  125 added - Business Analyst
# Job number  126 added - Viral Hepatitis Data Management Analyst
# Job number  127 added - Marketing Data Analyst/Scientist
# Job number  128 added - Contract Business Analyst
# Job number  129 added - PROGR001232 Programmer/Analyst I
# Job number  130 added - Business Analyst
# Job number  131 added - Business Analyst - Currently remote
# Job number  132 added - Business Intelligence Analyst
# Job number  133 added - Healthcare Business Analyst
# Job number  134 added - Risk Data Analyst
# Job number  135 added - Digital Reporting Analyst, Senior
# Job number  136 added - Business Analyst
# Job number  137 added - Lead Business Intelligence Analyst
# Job number  138 added - Email Marketing Data Analyst
# Job number  139 added - Lead Fraud Data Science Analyst - Fraud Mgmt. Technology
# Job number  140 added - Human Resources Analyst I/II
# Job number  141 added - Data Visualization Specialist
# Job number  142 added - Data Analyst
# Job number  143 added - Senior Data QA Analyst
# Job number  144 added - IS Business Analyst – IT Unit - SF Public Works (1052 TPV)
# Job number  145 added - Programs & Outreach Coordinator (Administrative Analyst/Specialist - Exempt I) - Institute for Civic & Community Engagement
# Job number  146 added - Academic Office Coordinator (Administrative Analyst/Specialist, Exempt I) - Computer Science, College of Science & Engineering
# Job number  147 added - Education Services Analyst - Administrative Analyst Specialist Exempt I
# Job number  148 added - Grant Support Coordinator (Administrative Analyst/Specialist, Non-Exempt) - Office of Research and Sponsored Programs
# Job number  149 added - Compliance Coordinator (Administrative Analyst/Specialist, Non-Exempt) - Office of Research and Sponsored Program
# Job number  150 added - Position Control Analyst - Office of Sr. Business Officer (2022-23)
# Job number  151 added - Compliance and Systems Analyst
# Job number  152 added - Research Analyst
# Job number  153 added - Senior Programmer Analyst (Senior IT Business Analyst)
# Job number  154 added - Program Analyst, Electronic Revenue Operations
# Job number  155 added - Senior Talent Acquisition Analyst (Senior Human Resources Analyst) (AM)
# Job number  156 added - Associate Program Analyst
# Job number  157 added - Business Analyst
# Job number  158 added - Human Resources Analyst I or II (Employee and Labor Relations Unit)
# Job number  159 added - Health IT Senior Business Analyst – Limited Term (Open)
# Job number  160 added - Actuarial Analyst, Associate (Hybrid)
# Job number  161 added - Business Analyst
# Job number  162 added - Credit Analyst, Full Stack
# Job number  163 added - OPERATIONS ANALYST, PRIVATE INVESTMENTS
# Job number  164 added - Business Systems Analyst (Analytics & Insights)
# Job number  165 added - Court Management Analyst I - (Collaborative Courts) - (Open and Promotional)
# Job number  166 added - Principal Personnel Analyst (OPEN UNTIL FILLED)
# Job number  167 added - Business Analyst with clinical Data focus
# Job number  168 added - Data Governance and Privacy Operations Analyst
# Job number  169 added - Functional Business Analyst -
# Job number  170 added - Hiring || Business Analyst || Foster City, CA (Onsite)
# Job number  171 added - Senior Human Resources Analyst
# Job number  172 added - Impact Management Analyst
# Job number  173 added - Business Analyst
# Job number  174 added - Business Analyst - eSignature & eDocument Management (contract)
# Job number  175 added - Data Analyst Lead - ML Ops Engineer
# Job number  176 added - Senior Financial Analyst
# Job number  177 added - Analyst - Strategy & Analytics
# Job number  178 added - Business Analyst
# Job number  179 added - SeRA Business Analyst
# Job number  180 added - Senior Business Analyst - Charles River (contract)
# Job number  181 added - Lead Research Analyst - Energy Efficiency & Decarbonization Data Analytics
# Job number  182 added - Business Analyst
# Job number  183 added - Senior Healthcare Financial Analyst
# Job number  184 added - Senior Business Intelligence Analyst
# Job number  185 added - Business Intelligence Analyst
# Job number  186 added - Senior Financial Analyst
# Job number  187 added - Master Data Management Analyst
# Job number  188 added - Senior Analyst Risk Analytics & Strategy
# Job number  189 added - Staff Data Analyst - SEO Product Analyst
# Job number  190 added - Institutional Research Analyst for Undergraduate Education (6948U) - 49075
# Job number  191 added - Business Analyst - Requirement - San Francisco, CA
# Job number  192 added - Recruiting Analyst
# Job number  193 added - Financial Business Intelligence Analyst
# Job number  194 added - Business Analyst - Senior
# Job number  195 added - Business Intelligence Analyst (Remote Eligible)
# Job number  196 added - IT Business Analyst 2
# Job number  197 added - Business Analyst
# Job number  198 added - Developer and Technical Business Analyst (Hybrid Workplace) - Controller's Office (1054)
# Job number  199 added - Systems Analyst II
# Job number  200 added - SF Reports & Analytics Principal Business Analyst (Hybrid Workplace) - Controller's Office (1054)
# Job number  201 added - Business Analyst - Facilities Operations
# Job number  202 added - Business Intelligence Analyst
# Job number  203 added - IT Business Process Analyst
# Job number  204 added - Senior/Principal Policy and Data Analyst (Senior/Principal Financial Analyst - AFSCME)
# Job number  205 added - Senior Project Business Data Analyst
# Job number  206 added - Senior Business Systems Analyst - ML and Data Science
# Job number  207 added - Sr Business Analyst (US Only)
# Job number  208 added - RETIREMENT COUNSELOR - BENEFITS ANALYST 4 (8 VACCANCIES IN MEMBER SERVICES) (HYBRID)
# Job number  209 added - Senior Business Analyst
# Job number  210 added - PAYROLL / ACCOUNTING BUSINESS ANALYST
# Job number  211 added - Classification and Compensation Analyst
# Job number  212 added - BUSINESS ANALYST - AHMC Seten Medical Center
# Job number  213 added - Records Analyst (4221C), University Police - 49262
# Job number  214 added - Business Intelligence Analyst, Assoc. Dir.
# Job number  215 added - Case Analyst
# Job number  216 added - Medicaid Data Advisory Services Analyst
# Job number  217 added - REPORTING and BUSINESS ANALYST LEAD
# Job number  218 added - Product Operations Analyst
# Job number  219 added - Sr. Analyst, Business Intelligence & Analytics
# Job number  220 added - Senior IT Business Analyst
# Job number  221 added - Senior Talent Systems Analyst
# Job number  222 added - Business Analyst
# Job number  223 added - Sr. IT Business Analyst
# Job number  224 added - Senior Analyst, B2B Marketing Strategy & Analytics
# Job number  225 added - Financial Systems Analyst - FP&A
# Job number  226 added - IT Systems Analyst
# Job number  227 added - Senior IT Business Analyst Oakland CA HYBRID
# Job number  228 added - Senior IT Business Analyst
# Job number  229 added - Project Analyst - 1344165
# Job number  230 added - Compensation & Benefits Analyst
# Job number  231 added - Classification and Compensation Analyst (Confidential Administrative Support II) - Office of Human Resources
# Job number  232 added - Business Analyst, Integrated Planning/Job Req 553966724
# Job number  233 added - Senior Systems Analyst
# Job number  234 added - Club Financial Analyst
# Job number  235 added - Sr Info Mgmt Analyst
# Job number  236 added - Business Analyst - C79640 6.2 San Francisco, CA
# Job number  237 added - IS Business Analyst Senior, Payroll - Department of Technology (1053)
# Job number  238 added - (Senior) Business Analyst
# Job number  239 added - Senior HR Systems Analyst
# Job number  240 added - Business Planning & Analysis - Senior Analyst
# Job number  241 added - Senior Product Analyst
# Job number  242 added - Securities Operations Analyst, Assoc.
# Job number  243 added - Research and Planning Analyst
# Job number  244 added - Business Intelligence Analyst
# Job number  245 added - Business Analyst - Implementation analyst- USA (Hybrid)
# Job number  246 added - SR. HR Analyst
# Job number  247 added - SAP Data Migration Analyst, Sr. Associate
# Job number  248 added - Sales and Marketing Analyst
# Job number  249 added - Analytics Implementation Analyst, Consultant
# Job number  250 added - Senior Technical Business Analyst
# Job number  251 added - Sr. Data Visualization Analyst
# Job number  252 added - NASSCO (National Association of Sewer Service Companies) MACP Analyst
# Job number  253 added - Business Analyst
# Job number  254 added - Business Analyst / Project Coordinator
# Job number  255 added - Functional Business Analyst - (Information Technology Consultant-Career) - Student Health Services
# Job number  256 added - Senior Data Analyst, Workforce Management Optimization
# Job number  257 added - Senior Financial Analyst , Corporate Accounting
# Job number  258 added - Analyst – People/Workforce Analytics
# Job number  259 added - Management Analyst II (LIMTED TERM)
# Job number  260 added - Sr. Data Analyst (W2)
# Job number  261 added - Business Analyst/ Product Owner
# Job number  262 added - Senior Business Intelligence Consultant (California)
# Job number  263 added - Data Analyst
# Job number  264 added - Personnel Analyst, Pathway Recruitment & Credential Analyst (1241)
# Job number  265 added - Business Analyst, Consulting
# Job number  266 added - Senior Business Analyst, Product Strategy
# Job number  267 added - Business Development Analyst
# Job number  268 added - Revenue Cycle Analyst
# Job number  269 added - Data Analyst Lead - Data Scientist
# Job number  270 added - Lead Talent Business Analyst
# Job number  271 added - Senior Software Engineer - Analyst Experience
# Job number  272 added - Senior Business Intelligence Analyst - Sales Finance
# Job number  273 added - Business Analyst
# Job number  274 added - Management Analyst II
# Job number  275 added - Senior Management Analyst
# Job number  276 added - Senior Project Business Analyst
# Job number  277 added - Senior Business Analyst
# Job number  278 added - Senior SuccessFactors Business Analyst, HR Systems
# Job number  279 added - Programming Analyst, Medical Affairs
# Job number  280 added - Senior Analyst, QC Analytical Training and Validation
# Job number  281 added - Senior Consultant and Business Analyst in Regulatory Technology & Compliance Analytics
# Job number  282 added - (Agile1)IT- Business Analyst - Senior
# Job number  283 added - Senior Payroll Analyst
# Job number  284 added - Sr. Salesforce Business Analyst - REMOTE
# Job number  285 added - Senior Salesforce Business Analyst & Administrator, Temp
# Job number  286 added - Sr. Business Intelligence Analyst (Remote Eligible)
# Job number  287 added - Technical BA, For internal project.
# Job number  288 added - Communications & Operations Coordinator (Administrative Analyst/Specialist Non-Exempt) - University Corporation
# Job number  289 added - Grant Human Resource Specialist (Administrative Analyst/Specialist, Non-Exempt) - Office of Research & Sponsored Programs
# Job number  290 added - Community Engagement & Partnerships Coordinator (Administrative Analyst/Specialist, Exempt I) - Institute for Civic and Community Engagement
# Job number  291 added - Community Engagement & Partnerships Coordinator (Administrative Analyst/Specialist, Exempt I) - Institute for Civic and Community Engagement
# Job number  292 added - Technical BA, For internal project.

# %% [markdown]
# ### Scrape full job descriptions

# %%
Links_list = dataframe['Links'].tolist()

import random

async def get_description(urls):
  descriptions = []
  async with get_session(Geckodriver(binary=driver_path, log_file=asyncio.subprocess.PIPE), Firefox(**options)) as session:
    for url in urls:
      await session.get("https://www.indeed.com"+url)
      time.sleep(1) #adding a one-second delay
      jd = await session.get_element('#jobDescriptionText')
      descriptions.append(await jd.get_text())
      await asyncio.sleep(random.random() * 1.5)
  return descriptions

## Number of browser instances to use
n = 3

tasks = [asyncio.create_task(get_description(urls)) for urls in np.array_split(Links_list, n)]
dataframe['Descriptions'] = [desc for task in tasks for desc in await task]

# %% [markdown]
# ### Save results

# %%
# Convert the dataframe to a csv file
date = datetime.today().strftime('%Y-%m-%d')
dataframe.to_csv(date + "_" + position + "_" + locations + ".csv", index=False)

# %%
dataframe
# Out:
#                                                  Title  \
# 0                                         Data Analyst
# 1                                  Senior Data Analyst
# 2                                         Data Analyst
# 3                                         Data Analyst
# 4                                   Production Analyst
# ..                                                 ...
# 287  Senior Talent Acquisition Analyst (Senior Huma...
# 288  Health IT Senior Business Analyst – Limited Te...
# 289  Human Resources Analyst I or II (Employee and ...
# 290                          Associate Program Analyst
# 291  Classification and Compensation Analyst (Confi...
#
#                                              Company  \
# 0                                                RPX
# 1                        North East Medical Services
# 2                                   Attentive Mobile
# 3                                     Vetro Tech Inc
# 4                                   Procter & Gamble
# ..                                               ...
# 287                                City of Santa Ana
# 288                              County of San Mateo
# 289  Superior Court of California, County of Alameda
# 290         Alameda County Transportation Commission
# 291                   San Francisco State University
#
#                                               Location Rating  \
# 0    San Francisco, CA 94105 (Financial District area)    NaN
# 1                                  Daly City, CA 94014    2.7
# 2                   Hybrid remote in San Francisco, CA    3.6
# 3                          Remote in San Francisco, CA    NaN
# 4                                    San Francisco, CA    4.1
# ..                                                 ...    ...
# 287                             Civic Center Plaza, CA    4.3
# 288                                      San Mateo, CA    3.9
# 289                                  Oakland, CA 94612    2.4
# 290                  Oakland, CA 94607 (Downtown area)    NaN
# 291           San Francisco, CA 94132 (Lakeshore area)    4.2
#
#                           Date                      Salary  \
# 0      PostedPosted 9 days ago    $80,000 - $92,000 a year
# 1            PostedJust posted  $125,544 - $145,496 a year
# 2      PostedPosted 6 days ago   $85,200 - $127,000 a year
# 3    EmployerActive 4 days ago    $83,000 - $93,000 a year
# 4     PostedPosted 25 days ago   $71,700 - $102,400 a year
# ..                         ...                         ...
# 287   PostedPosted 14 days ago                         NaN
# 288    PostedPosted 3 days ago                         NaN
# 289   PostedPosted 21 days ago                         NaN
# 290   PostedPosted 17 days ago                         NaN
# 291  PostedPosted 30+ days ago    $65,004 - $70,008 a year
#
#                                            Description  \
# 0    Provide data-based answers to questions posed ...
# 1    Perform research by gathering data from a vari...
# 2    Our primary data visualization tool is Looker....
# 3    Proven working experience as a data analyst or...
# 4    Strong background in data analysis and ability...
# ..                                                 ...
# 287  Provides complex professional staff assistance...
# 288  Performs other duties as assignedIdeal candida...
# 289  Assists in the development, maintenance, and a...
# 290  Three (3) years of responsible professional-le...
# 291  Job no: 521243 Work type: Staff Location: San ...
#
#                                                  Links  \
# 0    /rc/clk?jk=a269faf55acfd4cc&fccid=3bd140ae8fb1...
# 1    /rc/clk?jk=a23f5b0b575886ab&fccid=9bf2c3dc844c...
# 2    /rc/clk?jk=c350edef327bb8ab&fccid=6bab5fc4ce26...
# 3    /company/Vetro-Tech-Inc/jobs/Data-Analyst-b338...
# 4    /rc/clk?jk=869cc4f55b98f8f3&fccid=2da0dedf6df9...
# ..                                                 ...
# 287  /rc/clk?jk=076fd2c44b6bff66&fccid=4b76342a7e1a...
# 288  /rc/clk?jk=1c10e09ff29f326f&fccid=12de6aa257aa...
# 289  /rc/clk?jk=d50afde47e8681db&fccid=7d7bd3fb4c71...
# 290  /rc/clk?jk=980ac5fae7eca87c&fccid=300684e1f07e...
# 291  /rc/clk?jk=b61ccc97b370a68b&fccid=078571361184...
#
#                                           Descriptions
# 0    RPX Corporation is the leading provider of a c...
# 1    The Senior Data Analyst will be responsible fo...
# 2    SAN FRANCISCO, CA /\nENGINEERING /\nFULL-TIME\...
# 3    We are looking for a passionate certified Data...
# 4    P&G is the largest consumer packaged goods com...
# ..                                                 ...
# 287  JOB\nThe City of Santa Ana is looking for indi...
# 288  JOB\nSan Mateo County Health is seeking a well...
# 289  JOB\nThe Superior Court of California, County ...
# 290  JOB\nTHE OPPORTUNITY\n\nUnder general supervis...
# 291  Job no: 521243\nWork type: Staff\nLocation: Sa...
#
# [292 rows x 9 columns]
