# %% [markdown]
# # Web Scraping - Indeed.com
# General steps for Web Scraping
# 1. Check whether the website allows web scraping
# 2. Obtain the source code (HTML File) by using the website URL
# 3. Download the website content
# 4. Parse the content using keywords tags for elements of interest
# 5. Extract relevant data/features
# 6. Organize raw data in structured format (e.g., CSV)

# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from datetime import datetime
from arsenic import get_session
from arsenic.browsers import Firefox
from arsenic.services import Geckodriver
import asyncio
import time

# disable arsenic logging to stdout
import structlog
import logging

logger = logging.getLogger()
logger.setLevel(logging.WARN)
structlog.configure(logger_factory=lambda: logger)

# %% [markdown]
# ### Path to webdriver (Firefox, Chrome)

# %%
# Ensure that the driver path is correct before running this script.
# Microsoft Windows
# driver_path = "./drivers/windows/geckodriver.exe"
#driver_path = "./programs/geckodriver.exe"
driver_path = r"C:\Users\ranga\Downloads\geckodriver-v0.32.1-win64\geckodriver.exe"
# Linux
# driver_path = "./drivers/linux/geckodriver"
# driver_path = "/usr/bin/geckodriver"

options = {
  'moz:firefoxOptions': {
    # if you want it to be headless
    'args': ['-headless'],
    'log': {'level': 'warn'},
    # Needed for windows / non-default firefox install
    'binary': 'C:\\Program Files\\Mozilla Firefox\\firefox.exe'
  }
}

# %% [markdown]
# ### Define position and location

# %%
## Enter a job position
position = "director of analytics"
## Enter a location (City, State or Zip or remote)
locations = "california"

def get_url(position, location):
    url_template = "https://www.indeed.com/jobs?q={}&l={}"
    url = url_template.format(position, location)
    return url

url = get_url(position, locations)
dataframe = pd.DataFrame(columns=["Title", "Company", "Location", "Rating", "Date", "Salary", "Description", "Links"])

# %% [markdown]
# ### Scrape job postings

# %%
## Number of postings to scrape
postings = 1000

## Number of browser instances to use
n = 3

pages = list(range(0, postings, 10))

state = {
  'lock': asyncio.Lock(),
  'ids': set(),
  'n': 0
}
             
async def get_jobs(url, pages, state):
  data = []
  async with get_session(Geckodriver(binary=driver_path, log_file=asyncio.subprocess.PIPE), Firefox(**options)) as session:
    for i in pages:
      await session.get(url + "&start=" + str(i))
      jobs = await session.get_elements("[class='job_seen_beacon']")

      for job in jobs:
        result_html = await job.get_property('innerHTML')
        soup = BeautifulSoup(result_html, 'html.parser')

        liens = await job.get_elements("a")
        link = await liens[0].get_attribute("href")

        title = soup.select('.jobTitle')[0].get_text().strip()
        try:
          company = soup.select('.companyName')[0].get_text().strip()
        except:
          continue
        location = soup.select('.companyLocation')[0].get_text().strip()
        try:
            salary = soup.select('.salary-snippet-container')[0].get_text().strip()
        except:
            salary = 'NaN'
        try:
            rating = soup.select('.ratingNumber')[0].get_text().strip()
        except:
            rating = 'NaN'
        try:
            date = soup.select('.date')[0].get_text().strip()
        except:
            date = 'NaN'
        try:
            description = soup.select('.job-snippet')[0].get_text().strip()
        except:
            description = ''
            
        Id = f"{title}{company}{location}{rating}{date}{salary}{description}"
        dupe = False
        async with state['lock']:
          if Id in state['ids']:
            dupe = True
          else:
            state['ids'].add(Id)
            state['n'] = state['n'] + 1
            print("Job number {0:4d} added - {1:s}".format(state['n'],title))
        if dupe:
          continue

        data.append({
          'Title': title,
          "Company": company,
          'Location': location,
          'Rating': rating,
          'Date': date,
          "Salary": salary,
          "Description": description,
          "Links": link
        })

        # print("Job number {0:4d} added - {1:s}".format(jn,title))
      i = i + 10
  return data

tasks = [asyncio.create_task(get_jobs(url, p, state)) for p in np.array_split(pages, n)]
dataframe = pd.DataFrame([j for task in tasks for j in await task])
# Out:
# Job number    1 added - Head of Partnerships Tech & Analytics
# Job number    2 added - Director, Geospatial Products & Analytics
# Job number    3 added - Director, Product Analytics
# Job number    4 added - Director of Operations
# Job number    5 added - Director of Threat Research - Intrusion Prevention
# Job number    6 added - Assoc Director/Director, Strategy & Analytics
# Job number    7 added - Medical Director/Senior Medical Director
# Job number    8 added - Assistant Director Evaluation
# Job number    9 added - Director of Business and Portfolio Analytics
# Job number   10 added - Director Clinical Pharmacology
# Job number   11 added - Transaction Advisory Services Director – Technology, Media, and Telecommunications (TMT)
# Job number   12 added - Director of Product Management (SASE - Visibility and Analytics)
# Job number   13 added - Associate Director, Prospect Management and Research
# Job number   14 added - Director of Analytics & Performance Reporting
# Job number   15 added - Credit Analyst, Director - Global Infrastructure Group - San Francisco
# Job number   16 added - Director Of Operations
# Job number   17 added - Financial Planning & Analysis Director
# Job number   18 added - Director of IT Operations
# Job number   19 added - Director, Sheriff's Administrative Services
# Job number   20 added - Director of Engineering, Central Technology
# Job number   21 added - Clinical Director
# Job number   22 added - Director of Engineering - HPE Ezmeral
# Job number   23 added - Associate Director, Clinical Quality Assurance & Compliance (JR 2643)
# Job number   24 added - Director of HRIS & Analytics
# Job number   25 added - 526104 - Assistant Director, Business Advising Center
# Job number   26 added - Director of Observability
# Job number   27 added - Chinese Marketing Director
# Job number   28 added - Director of Information Technology
# Job number   29 added - Software Director
# Job number   30 added - Senior Manager/Director - Building Simulation & Energy Analysis Lead
# Job number   31 added - Assistant Director of Alumni Marketing Strategy and Analytics
# Job number   32 added - Director of Business Intelligence
# Job number   33 added - Director, Business Intelligence
# Job number   34 added - Director of Customer Experience
# Job number   35 added - Senior Director of Business Intelligence
# Job number   36 added - Director of Research and Development Manufacturing Operations
# Job number   37 added - Director of Finance
# Job number   38 added - Director, Technology- US Skin Health & Beauty
# Job number   39 added - Director, Analyst Relations
# Job number   40 added - Assistant Director of Analytics and Communication
# Job number   41 added - Director of Bioinformatics
# Job number   42 added - Director of Talent
# Job number   43 added - Director, Healthcare Products
# Job number   44 added - Director of Marketing
# Job number   45 added - FVP/SVP, Director of Project Management
# Job number   46 added - Director of Marketing Analytics & Insight (Remote)
# Job number   47 added - Director of Supply Chain
# Job number   48 added - Director of Technical Program Management
# Job number   49 added - Head of Trust & Safety
# Job number   50 added - CapCut - Head of US Operations
# Job number   51 added - Head of Analytics, Shopping Strategy
# Job number   52 added - Assistant Director of Analytics and Communication
# Job number   53 added - Director of Bioinformatics
# Job number   54 added - Director
# Job number   55 added - Head of Risk Strategy and Analytics
# Job number   56 added - Director, Engineering Program Management
# Job number   57 added - Vans: Director, Financial Planning and Analysis
# Job number   58 added - Director of Revenue Strategy and Operations
# Job number   59 added - Director of Marketing
# Job number   60 added - Director, Product Analytics
# Job number   61 added - Director of Engineering, Data Platform, Google Workspace
# Job number   62 added - Director of IT
# Job number   63 added - Head of Business Intelligence
# Job number   64 added - Director of IT
# Job number   65 added - Senior Director, Global HR Operations & Technology
# Job number   66 added - Director of Financial Planning and Analysis
# Job number   67 added - Director, Safety Science
# Job number   68 added - Director of Affiliate and Performance Marketing
# Job number   69 added - Director - Technology, Data Platforms
# Job number   70 added - Director of Financial Planning & Analysis
# Job number   71 added - Director of Hardware
# Job number   72 added - SVP, Director of IT Operations
# Job number   73 added - Head of Product Analytics
# Job number   74 added - Director of Customer Experience
# Job number   75 added - Sr Director, Global Data & Analytics Technology - Remote
# Job number   76 added - Director of Workplace Services
# Job number   77 added - Director of IS Operations - IS - PMO - FT Days
# Job number   78 added - Director, Business Strategy
# Job number   79 added - Director of Production Audit
# Job number   80 added - CapCut - Head of US Operations
# Job number   81 added - Director, Technical Program Management/Chief of Staff
# Job number   82 added - Associate Director, Analytics
# Job number   83 added - Director of Audit - Digital Enablement
# Job number   84 added - Executive Director, HR Reporting and Analytics Services
# Job number   85 added - Director of Applications (1070)
# Job number   86 added - Director of Revenue Operations
# Job number   87 added - Director, Learning Programs Team - Opportunity for Working Remotely Palo Alto, CA
# Job number   88 added - Director, Biomarker Sciences
# Job number   89 added - Head of TS Online Banking and User Experience, Director
# Job number   90 added - Director of Operations - GPU
# Job number   91 added - Head of Product Growth
# Job number   92 added - Senior Manager/Associate Director, Trade Operations, Analytics, and Reporting
# Job number   93 added - Head of Revenue Operations
# Job number   94 added - Director of Quality
# Job number   95 added - Head of Audience and Marketing Analytics
# Job number   96 added - Director, Data Science & Analytics
# Job number   97 added - Director, Revenue Operations
# Job number   98 added - Executive Director, Enterprise Data and Analytics
# Job number   99 added - Head of Digital Medical, US Medical Affairs (Executive Director)
# Job number  100 added - Associate Director, Advanced Analytics
# Job number  101 added - Director, Consumer Insights
# Job number  102 added - Director of Enterprise Applications
# Job number  103 added - Senior Director, BI and Data Strategy
# Job number  104 added - Associate Director of Admission, Knight-Hennessy Scholars (Evaluation)
# Job number  105 added - Director of Product Management, Beacon
# Job number  106 added - Director of Technology Services
# Job number  107 added - Director of Enterprise Applications
# Job number  108 added - Associate Director, Operations & Strategy
# Job number  109 added - Senior Director of Research
# Job number  110 added - Director of Fraud Strategy
# Job number  111 added - Director of R&D - Polymer Materials
# Job number  112 added - Senior Director, Cybersecurity Risk Management
# Job number  113 added - Director of Operations
# Job number  114 added - Associate Director, Revenue Cycle Management
# Job number  115 added - Director of Digital Transformation & Automation
# Job number  116 added - Director of Operations
# Job number  117 added - Senior Director, HR Technology and Innovation
# Job number  118 added - Managing Director, Head of UX Design, Content, and Research
# Job number  119 added - Sr. Director of Engineering, CX & Trust
# Job number  120 added - I.T. Director, Sonoma Valley Hospital – UCSF
# Job number  121 added - Director Of Information Technology
# Job number  122 added - Director of Product Management
# Job number  123 added - Director of Product Operations
# Job number  124 added - Director, Customer Success Ops, Expert Planning
# Job number  125 added - Director IT Operations
# Job number  126 added - Associate Director, Sales Analytics
# Job number  127 added - Director of Product Management
# Job number  128 added - Assistant Director of Information Technology
# Job number  129 added - Director, Quality Analytics - Hybrid/Remote
# Job number  130 added - Buying Director, RTW
# Job number  131 added - Director, Product - Consumer(Remote)
# Job number  132 added - Director of Information Technology
# Job number  133 added - Director, Data Science and Analytics
# Job number  134 added - Relationship Executive, Technology Group, Corporate Client Banking, Executive Director
# Job number  135 added - Director of Trading
# Job number  136 added - Director, Payment Risk & Fraud
# Job number  137 added - Director, Product Management
# Job number  138 added - Director, Data Analytics
# Job number  139 added - DIRECTOR, BUSINESS INTELLIGENCE
# Job number  140 added - Director of Finance
# Job number  141 added - Director, Competitive Intelligence
# Job number  142 added - Director of Information Technology
# Job number  143 added - Executive Director, Insights and Business Analysis - Pharmaceuticals
# Job number  144 added - Director of Strategic Quality & Results
# Job number  145 added - Senior Director, System Data Analytics (IT/Data Processing)
# Job number  146 added - Director, Revenue Operations
# Job number  147 added - Associate Dir/Assistant Director - Research (Hybrid or Remote)
# Job number  148 added - Biostatistics Director- San Diego
# Job number  149 added - Director, Enterprise Architecture
# Job number  150 added - Director of Revenue Analysis
# Job number  151 added - FP&A Systems Director
# Job number  152 added - Director, Data Science & Advanced Analytics
# Job number  153 added - Director of Technical Accounting & Financial Reporting
# Job number  154 added - Director of Research
# Job number  155 added - Director - Global Energy Transition Initiative - Africa Program
# Job number  156 added - Director of Audit-Compliance
# Job number  157 added - Senior Director-Supply Chain Technology
# Job number  158 added - Director of Clinical Affairs
# Job number  159 added - Director, Provider Business Development - Provider Relations
# Job number  160 added - Director of Infrastructure Project Management
# Job number  161 added - AI Solution Director, Healthcare
# Job number  162 added - Sr. Director, Consumer Insights
# Job number  163 added - Senior Director of Engineering IT
# Job number  164 added - Director of Human Resources
# Job number  165 added - Sr. Director, Revenue Operations
# Job number  166 added - Associate Director, Market Access Operations Analytics
# Job number  167 added - Director or Sr. Director, Social Media
# Job number  168 added - Director - Technology, Data Platforms
# Job number  169 added - Director, Commercial Analytics
# Job number  170 added - Associate Director, Competitive Intelligence – HIV
# Job number  171 added - Director, Content Acquisitions
# Job number  172 added - Director of IT
# Job number  173 added - Director of R&D - Polymer Materials
# Job number  174 added - Data Governance & Risk Analytics, Assoc. Dir.
# Job number  175 added - Dir Finance Plan & Analysis
# Job number  176 added - Senior Director of Product Data Science and Analytics
# Job number  177 added - Senior Director of Data & Evaluation
# Job number  178 added - Regional Retail Director
# Job number  179 added - Senior Director of Product Management
# Job number  180 added - Director, Social & Influencer Marketing - OLEHENRIKSEN
# Job number  181 added - Data Analytics Director
# Job number  182 added - Product Director, Analytics (Product Management) -8613
# Job number  183 added - Director of Payments and Checkout
# Job number  184 added - Executive Director, Insights & Analytics - Product Management
# Job number  185 added - Director, IT (Cyber Defense)
# Job number  186 added - AIML - Head of Data Engineering, Data & Machine Learning Innovation
# Job number  187 added - Director, Discovery Biology
# Job number  188 added - Director of Compliance
# Job number  189 added - Director, Financial Planning & Analysis
# Job number  190 added - Sr Director, Analytics Data Platform
# Job number  191 added - Director, ERP Applications - Oracle
# Job number  192 added - Director, Supply Chain Data Analytics - Supply Chain Administration
# Job number  193 added - Director - Data Science
# Job number  194 added - Director of Financial Planning and Analysis
# Job number  195 added - Director, Fraud Analytics
# Job number  196 added - Director, Global Paid Media & Analytics
# Job number  197 added - Director, Business Intelligence and Analytics – Santa Monica, California
# Job number  198 added - Director of Product Management: Payments Platform
# Job number  199 added - Director, Data Products
# Job number  200 added - Senior Director, SMB Programs
# Job number  201 added - VP and Head of Product (Film, Television, and Streaming)
# Job number  202 added - Director, IT Product Freight Forwarding
# Job number  203 added - Senior Director of UX (Employee Experiences)
# Job number  204 added - Director of Pricing Algorithms & Data Science
# Job number  205 added - Director Procurement Operations
# Job number  206 added - Associate Director, Market Intelligence (Zepzelca)
# Job number  207 added - Director, Talent Operations
# Job number  208 added - Associate Director, Cloud Development - Remote
# Job number  209 added - People Partner Director
# Job number  210 added - Director of AI/ML - Insights & Measurement
# Job number  211 added - Director of Financial Planning and Analysis
# Job number  212 added - (USA) Associate Director, Digital Media/Creator Analytics
# Job number  213 added - Technical Program Director - Health SDK
# Job number  214 added - Director of Paid Search, Display and YouTube
# Job number  215 added - Government Affairs Director
# Job number  216 added - Director, Quantitative Science/Psychometrician
# Job number  217 added - Associate Director, Quantitative Science
# Job number  218 added - Director of Product Management - AppSec - Web App & API Security, SBOM
# Job number  219 added - Director of Product Development (BUS DEV HC MGR 2)
# Job number  220 added - Director, Portfolio Monetization Analytics & Strategy
# Job number  221 added - Director of Product Management - SaaS & Subscriptions
# Job number  222 added - Associate Director Post Market, Dispensing Solutions & Pharmacy Automation (Onsite)
# Job number  223 added - Director, Knowledge Management
# Job number  224 added - Director of Product Management (Technical)
# Job number  225 added - Head of Product Management
# Job number  226 added - Associate Director, Regulated Systems Business Analyst
# Job number  227 added - Senior Director Revenue Cycle Risk Adjustment
# Job number  228 added - Director, IT (Data Technologies)
# Job number  229 added - Director, Quality Analytics (Director II)
# Job number  230 added - Director of EDI and Billing Systems- Remote
# Job number  231 added - IT Technical Services Director
# Job number  232 added - REMOTE: Director, Prospect Development - Data & Analytics
# Job number  233 added - Head of Product Design
# Job number  234 added - Assistant Director of Prospect Analytics (6794U) University Development and Alumni Relations - 40300
# Job number  235 added - Associate Director
# Job number  236 added - Director of Machine Learning
# Job number  237 added - Head of Data Platform, Ventures
# Job number  238 added - Associate Director
# Job number  239 added - Director of Data & Analytics
# Job number  240 added - Associate Director - Technology Risk
# Job number  241 added - Head of Data
# Job number  242 added - Director Of Information Technology
# Job number  243 added - Associate Director, Genomic Assay Research and Development
# Job number  244 added - Executive Director, Data Science
# Job number  245 added - Associate Director, Genomic Assay Research and Development
# Job number  246 added - Director, Direct to Consumer
# Job number  247 added - Director, People and Engagement Technology Management
# Job number  248 added - Director of Revenue Operations
# Job number  249 added - Director, CFO Advisory | Corporate Finance & Restructuring
# Job number  250 added - Assistant Director, Enrollment Analyst
# Job number  251 added - Director of Paid Social
# Job number  252 added - Sr. Director of Statistical Programming - Job ID: 1105
# Job number  253 added - Director of Optical Engineering
# Job number  254 added - Associate Director, Field Planning & Analytics
# Job number  255 added - Head of Financial Planning and Analysis
# Job number  256 added - Partnership Director, EV & Advanced Vehicle Technology- REMOTE
# Job number  257 added - Senior Director of Reagent Development and System Integration
# Job number  258 added - Director, Global C2C Selling Initiatives
# Job number  259 added - Director of Operations
# Job number  260 added - (USA) Director, User Experience - Customer Platform
# Job number  261 added - Vice President, Head of Web Strategy and Governance
# Job number  262 added - Director, Talent Management & Development
# Job number  263 added - IT Business Solutions Director
# Job number  264 added - Senior Director, SMB Programs
# Job number  265 added - Director of Adoption, Consulting Processes and Tools
# Job number  266 added - Head of Product
# Job number  267 added - Director of Machine Learning
# Job number  268 added - Director, Portfolio Monetization Analytics & Strategy
# Job number  269 added - Director, Data Science
# Job number  270 added - Sr. Principal Cloud Specialist - Customer Success Director
# Job number  271 added - Director of Field Operations - Americas
# Job number  272 added - (Associate) Director, Recruiting
# Job number  273 added - Director, Financial Services
# Job number  274 added - Director, Data Strategy & Governance
# Job number  275 added - Senior Director, Data Science
# Job number  276 added - Director Crisis Management
# Job number  277 added - Assistant Director - Transportation Department
# Job number  278 added - Senior Director, Actuary - Network Contract Trend Analytics
# Job number  279 added - Director of Accounting - Hybrid
# Job number  280 added - Technical Director, Machine Learning
# Job number  281 added - Assistant Director of Admissions Technology
# Job number  282 added - Director, Group Operations - Orange County, CA
# Job number  283 added - Associate Director, GPro Product Owner
# Job number  284 added - Director, Athlete Marketing
# Job number  285 added - Director Sales – Data Analytics
# Job number  286 added - Director, Data Management - Hybrid/Remote
# Job number  287 added - Director of Engineering
# Job number  288 added - Director of Operations
# Job number  289 added - Senior Director, Enterprise Applications
# Job number  290 added - Associate Director, IS Strategic Planning and Analysis
# Job number  291 added - Epic Program Director - Technology Expert II DPH 9978
# Job number  292 added - HYBRID: DIR-REPORTING & ANALYTICS ACCOUNTABLE CARE OPERATIONS
# Job number  293 added - Executive Director, Advancement Information Services and Chief Technology Officer, UDAR (0668U) 36535
# Job number  294 added - Director of Institutional Research and Effectiveness
# Job number  295 added - HEAD OF BIOMETRICS
# Job number  296 added - Associate Director, Global Energy Transition Initiative (Southeast Asia)
# Job number  297 added - Director of Channel Marketing - Americas
# Job number  298 added - Director, Social & Influencer Marketing - OLEHENRIKSEN
# Job number  299 added - Senior Director, Clinical Biomarker Science, Oncology and Immuno-therapy
# Job number  300 added - Associate Director, NGS R&D
# Job number  301 added - Director of eCommerce DTC Experience
# Job number  302 added - Director - Global Pricing & Analytics Lead, Liver/Inflammation and Oncology
# Job number  303 added - Director, Commercial Data Science & AI (3 roles)
# Job number  304 added - (USA) Director, User Experience - Research
# Job number  305 added - IT - Information Security - Director - Information Security
# Job number  306 added - Director of Strategic Finance
# Job number  307 added - Director of Product Management
# Job number  308 added - Director of Property & Asset Management
# Job number  309 added - Director of Capital Projects (Measure H)
# Job number  310 added - Director, Market Research
# Job number  311 added - Consultant / Senior Consultant / Director, Healthcare Consulting
# Job number  312 added - Senior Director of Marketing and Communications
# Job number  313 added - Director, Financial Planning & Analysis
# Job number  314 added - Director, Release Management – Santa Monica, California
# Job number  315 added - Workplace Sales Director, West - Bay Area, CA / Virtual / Remote
# Job number  316 added - Associate Director of Technology and Support Operations
# Job number  317 added - Director, Technology Consulting
# Job number  318 added - Head of Data Science - InMobi Ads Platform
# Job number  319 added - Executive Director, Domestic Distribution Finance
# Job number  320 added - Director, Technical Incubation Services
# Job number  321 added - Director, Risk and Analytics
# Job number  322 added - Product Management Director
# Job number  323 added - Senior Director , M&A Strategy & Operations
# Job number  324 added - Director Quality and Risk
# Job number  325 added - Director of Integrated Technology
# Job number  326 added - Medical Education Technology Director
# Job number  327 added - IT Director
# Job number  328 added - Director of Research and Data Science
# Job number  329 added - Director Data Science JS8
# Job number  330 added - Director of B2B Product Management
# Job number  331 added - Director, Product Management
# Job number  332 added - Senior Director, Product Management (Enterprise Data Products & Insights)
# Job number  333 added - Associate Director, Data Management
# Job number  334 added - IT Audit Director
# Job number  335 added - Director, IT Customer Success
# Job number  336 added - Associate Medical Director | Hybrid Position | Beaver Medical Group
# Job number  337 added - Director of Engineering
# Job number  338 added - Senior Director, Systems Architecture
# Job number  339 added - DARPA Technical Director
# Job number  340 added - Assistant Director for Faculty Development and Diversity (Hybrid)
# Job number  341 added - Senior Director, Technology $140,000 - $170,000
# Job number  342 added - Financial Planning & Analysis, Associate Director
# Job number  343 added - Director, IT Strategy Consulting, State and Local Government
# Job number  344 added - Senior Director, Tax Technology
# Job number  345 added - Director Business Informatics and Analysis
# Job number  346 added - Director, Business Intelligence
# Job number  347 added - Director of Financial Planning and Analysis
# Job number  348 added - Director, Product Management
# Job number  349 added - Internal Audit IT and Digital Services Audit Director
# Job number  350 added - Director of Product Management, Content Platforms
# Job number  351 added - Financial, Planning and Analysis, Director
# Job number  352 added - Senior Director, Data & Analytics
# Job number  353 added - Director of B2B Product Management
# Job number  354 added - Director of Financial Planning & Analysis
# Job number  355 added - IT Director
# Job number  356 added - Sr. Director, Digital Media Strategy and Operations
# Job number  357 added - Director of Financial Planning & Analysis
# Job number  358 added - Director, Data Management
# Job number  359 added - Associate Director, Biostatistics
# Job number  360 added - Director of People Operations
# Job number  361 added - Director, BU CFO for EPI and ACE - (M6)
# Job number  362 added - Director, Commercial Data Insights
# Job number  363 added - Associate Director/Director, Antibody Process Development
# Job number  364 added - Associate Director / Director of Statistics
# Job number  365 added - DIRECTOR/SENIOR DIRECTOR, RNA (VACCINE TECHNOLOGY)
# Job number  366 added - Head of Product Data Science, Venmo
# Job number  367 added - Director of Technology
# Job number  368 added - IT Director
# Job number  369 added - Director of Information Technology - Seton Medical Center
# Job number  370 added - Director of Payroll – Newport Beach, CA
# Job number  371 added - Director, Program Mgmt & Seller Advocacy
# Job number  372 added - Director of Research, Evaluation, & Innovation
# Job number  373 added - Product Director (Infrastructure/Data Pipeline)
# Job number  374 added - Oakley - Director- Quality Assurance
# Job number  375 added - Assistant Director, Information Technology (BC)
# Job number  376 added - Senior Director, Marketing Operations
# Job number  377 added - Director – Program Controls and Analytics
# Job number  378 added - Sr Director Qual Engineering
# Job number  379 added - Director, Financial Planning and Analysis, Medical Financial Operations
# Job number  380 added - cxLoyalty Director, Knowledge Management
# Job number  381 added - Director of Finance
# Job number  382 added - Director of Infrastructure (1070): Department of Technology
# Job number  383 added - Director of Data Engineering
# Job number  384 added - Director, Cloud Services
# Job number  385 added - Data Science Sr Director
# Job number  386 added - MIS Director
# Job number  387 added - Director of Health IT Security Operations
# Job number  388 added - Director, Scientific Data Division
# Job number  389 added - Director of IT Operations
# Job number  390 added - Director of Business Planning & Analysis, Commercial Finance
# Job number  391 added - Production Systems Support Director
# Job number  392 added - Sr. Director, Digital Data & Analytics
# Job number  393 added - Director, Controller for the FEP Business Unit - (M6)
# Job number  394 added - Corporate Director Information Technology (IT)
# Job number  395 added - Director, Black Maternal Health Program
# Job number  396 added - Director, Platform Engineering Leader, Development Services and Experiences
# Job number  397 added - Statistical Science Director, Late Oncology
# Job number  398 added - Associate Director, Statistics
# Job number  399 added - Director, Product Management- Software
# Job number  400 added - IT Enterprise Business Systems Director
# Job number  401 added - Director, Financial Analysis & Enterprise Risk Management
# Job number  402 added - Director Licensing Product Management
# Job number  403 added - Director, Financial Planning & Analysis
# Job number  404 added - Director of Software and Systems
# Job number  405 added - Director Marketing - FT - Days - Marketing and Communication
# Job number  406 added - Sales Director, HiTech – R01523780
# Job number  407 added - Regional Marketing Director
# Job number  408 added - Director Clinical Pharmacology
# Job number  409 added - Director of Threat Research - Intrusion Prevention
# Job number  410 added - Information Systems Deputy Director
# Job number  411 added - Associate Dean and Executive Director of MD Admissions
# Job number  412 added - Director Human Resources
# Job number  413 added - Director, CFO Advisory | Corporate Finance & Restructuring
# Job number  414 added - Director, Utilization Management/Job Req 537138689
# Job number  415 added - Director, Product Management
# Job number  416 added - Credit Analyst, Director - Global Infrastructure Group - San Francisco
# Job number  417 added - Associate Director - California Market Transformation Engineering and Technical Assessment
# Job number  418 added - Director, Sheriff's Administrative Services
# Job number  419 added - Statistical Science Associate Director, Late Oncology
# Job number  420 added - Director, Product Management
# Job number  421 added - Associate Director, Prospect Management and Research
# Job number  422 added - Director of Enterprise Application Services
# Job number  423 added - Strategy Director
# Job number  424 added - Manager/Senior Manager/Director, Grants and Capital Programming
# Job number  425 added - Executive Director, Global IT - SAP FICO/FICA
# Job number  426 added - 526104 - Assistant Director, Business Advising Center
# Job number  427 added - Chinese Marketing Director
# Job number  428 added - Transaction Advisory Services Director – Technology, Media, and Telecommunications (TMT)
# Job number  429 added - Director of Information Technology
# Job number  430 added - Senior Manager/Director - Building Simulation & Energy Analysis Lead
# Job number  431 added - Software Director
# Job number  432 added - Head of Security
# Job number  433 added - Director of Engineering - Data Platform
# Job number  434 added - Director - Commercial Data Engineer
# Job number  435 added - Director of Ticketing & Sales Operations
# Job number  436 added - Senior Director, Product Management - Automation and Integration
# Job number  437 added - Director, Financial Planning and Analysis
# Job number  438 added - Sr. Director, Total Rewards, Systems, & Analytics
# Job number  439 added - Director, Accounts Receivable
# Job number  440 added - Director, Policy Planning and Strategy - Information Security & Trust
# Job number  441 added - Associate Director of Admissions and Recruitment
# Job number  442 added - Director of Engineering, Collaboration Marketplace | Brand Platform
# Job number  443 added - Executive Director, Trade & Distribution
# Job number  444 added - Sr. Director UI/UX
# Job number  445 added - Education Campus Director
# Job number  446 added - Director, Ad Solutions
# Job number  447 added - Rec Sports Associate Director and Workforce Analysis & Strategic Projects Manager (7398U), Recreational Sports - 51162
# Job number  448 added - Principal Director
# Job number  449 added - Director, Accounting
# Job number  450 added - Head of Field Application Support
# Job number  451 added - Assistant Finance Director
# Job number  452 added - Senior Director, Development
# Job number  453 added - Director, Product Management - External Data Platform Governance
# Job number  454 added - Director of People Talent and Culture
# Job number  455 added - IT Risk Compliance, Dir.
# Job number  456 added - Director of Programs
# Job number  457 added - Senior Director, Enterprise Applications
# Job number  458 added - Associate Director, CRM and MDM Capabilities Lead
# Job number  459 added - Principal Research Scientist II/Associate Director - Ophthalmology Discovery Research - Advanced Cell Systems
# Job number  460 added - Strategic Design Director - Innovation Initiatives
# Job number  461 added - Director of Product Management
# Job number  462 added - Director of Talent (23-24SY)
# Job number  463 added - Senior Director - R&D
# Job number  464 added - Director, Supportability & Release Readiness
# Job number  465 added - Director, Oracle ERP Program Manager
# Job number  466 added - Associate Medical Director, Clinical Science
# Job number  467 added - Director, Product Management
# Job number  468 added - Partner Engagement Director
# Job number  469 added - Director/Sr. Director Battery Printer Engineering, Office of the CTO
# Job number  470 added - Digital Product Lead- Digital Lending- Executive Director
# Job number  471 added - Senior Scientist (Study Director), Advanced Pathology Services
# Job number  472 added - Director of Technology
# Job number  473 added - Project Scientist, Co-Director High-throughput Screening California Institute for Quantitative Biosciences Core Facility
# Job number  474 added - Executive Director, Trade & Distribution
# Job number  475 added - Field Sales Strategy Director
# Job number  476 added - Managing Director
# Job number  477 added - Director, Enterprise Applications
# Job number  478 added - Director of Population Health
# Job number  479 added - Department Director, Communication Software Implementation Department
# Job number  480 added - Director of Growth Marketing
# Job number  481 added - Senior Director, Financial Analytics
# Job number  482 added - DIRECTOR CLINICAL QUALITY RESOURCES
# Job number  483 added - Director, Digital Marketing Analytics
# Job number  484 added - Senior Principal Scientist/Associate Director CV Remodeling and Targeted Delivery
# Job number  485 added - Director Demand Generation and Digital Marketing
# Job number  486 added - Associate Director, Product Strategy
# Job number  487 added - Director, IT Support Services
# Job number  488 added - Legislative Analyst & Policy Director - SF Adult Probation Dept. (0931)
# Job number  489 added - Commercial Forecasting Associate Director (Menlo Park, CA) #2989
# Job number  490 added - Senior Director of Impact and Evaluation
# Job number  491 added - Associate Director, Competitive Intelligence (CI) Cross-TA Strategy & Innovation
# Job number  492 added - Head of AI
# Job number  493 added - Analytics and Modeling Senior Data Engineer, Director
# Job number  494 added - Director, Educational Support Systems
# Job number  495 added - Director of Admissions
# Job number  496 added - ATE Test Engineering - Manager/Director
# Job number  497 added - Growth Director
# Job number  498 added - Executive Director, Care Coordination & Resource Stewardship-SCAL & HI
# Job number  499 added - Director, Business Development
# Job number  500 added - HR Director - Strategic Business Partner
# Job number  501 added - Director, Product Management
# Job number  502 added - Program Director (Strategic Projects) - REMOTE
# Job number  503 added - DIRECTOR OF TECHNICAL ACCOUNT MANAGEMENT, DATA PARTNERS
# Job number  504 added - Associate Director/Sr. Research Investigator, QSP (Preclinical Oncology)
# Job number  505 added - Director of Sexual Health and Wellness
# Job number  506 added - Senior Experience Design Director
# Job number  507 added - Director of Admissions
# Job number  508 added - Director of Assessment and Evaluation
# Job number  509 added - Director Product Engineering
# Job number  510 added - Director Test and Product Engineering (AI2136)
# Job number  511 added - Director/Sr Director Product Management
# Job number  512 added - Science Director

# %% [markdown]
# ### Scrape full job descriptions

# %%
Links_list = dataframe['Links'].tolist()

import random

async def get_description(urls):
  descriptions = []
  async with get_session(Geckodriver(binary=driver_path, log_file=asyncio.subprocess.PIPE), Firefox(**options)) as session:
    for url in urls:
      await session.get("https://www.indeed.com"+url)
      time.sleep(1) #adding a one-second delay
      jd = await session.get_element('#jobDescriptionText')
      descriptions.append(await jd.get_text())
      await asyncio.sleep(random.random() * 1.5)
  return descriptions

## Number of browser instances to use
n = 3

tasks = [asyncio.create_task(get_description(urls)) for urls in np.array_split(Links_list, n)]
dataframe['Descriptions'] = [desc for task in tasks for desc in await task]

# %% [markdown]
# ### Save results

# %%
# Convert the dataframe to a csv file
date = datetime.today().strftime('%Y-%m-%d')
dataframe.to_csv(date + "_" + position + "_" + locations + ".csv", index=False)

# %%
dataframe
# Out:
#                                                  Title  \
# 0                Head of Partnerships Tech & Analytics
# 1            Director, Geospatial Products & Analytics
# 2                          Director, Product Analytics
# 3                               Director of Operations
# 4        Assoc Director/Director, Strategy & Analytics
# ..                                                 ...
# 507                         Chinese Marketing Director
# 508  Transaction Advisory Services Director – Techn...
# 509                 Director of Information Technology
# 510  Senior Manager/Director - Building Simulation ...
# 511                                  Software Director
#
#                                      Company  \
# 0                                   Snapchat
# 1                                   Prologis
# 2                                 ServiceNow
# 3    PSA (Professional Sports Authenticator)
# 4                Sony Music Entertainment US
# ..                                       ...
# 507                          The One Pioneer
# 508                               RSM US LLP
# 509                         Cornbread Hustle
# 510                                      TRC
# 511                          quadric.io, Inc
#
#                                               Location Rating  \
# 0                  Los Angeles, CA 90291 (Venice area)    3.6
# 1                   Hybrid remote in San Francisco, CA    3.9
# 2                                Santa Clara, CA 95054    3.7
# 3                                        Santa Ana, CA    NaN
# 4                                      Los Angeles, CA    4.3
# ..                                                 ...    ...
# 507                                  Arcadia, CA 91006    NaN
# 508  San Francisco, CA 94104 (Financial District area)    3.6
# 509                                Imperial Valley, CA    NaN
# 510                        Remote in Oakland, CA 94612    3.5
# 511                               Burlingame, CA 94010    NaN
#
#                           Date                      Salary  \
# 0     PostedPosted 12 days ago  $196,000 - $285,000 a year
# 1      PostedPosted 5 days ago  $170,000 - $210,000 a year
# 2       PostedPosted 1 day ago  $198,500 - $347,500 a year
# 3     PostedPosted 27 days ago  $150,682 - $234,443 a year
# 4    PostedPosted 30+ days ago  $100,000 - $120,000 a year
# ..                         ...                         ...
# 507  EmployerActive 9 days ago    $50,000 - $75,000 a year
# 508    PostedPosted 5 days ago                         NaN
# 509    PostedPosted 3 days ago  $115,000 - $140,000 a year
# 510   PostedPosted 23 days ago                         NaN
# 511  PostedPosted 30+ days ago                         NaN
#
#                                            Description  \
# 0    The Strategy & Ops Team is a core group within...
# 1    Refine and execute the strategic plan for the ...
# 2    Provide thought leadership in the area of Prod...
# 3    In this role, you will lead all operations and...
# 4    As Associate Director/Director, Strategy & Ana...
# ..                                                 ...
# 507  The Director of Marketing will be responsible ...
# 508  RSM is seeking a Transaction Advisory Services...
# 509  Had Enough of “Typical” Tech Jobs?\nDrive Inno...
# 510  Strong quantitative and data analytics skills....
# 511  Quadric is building a full-stack system that i...
#
#                                                  Links  \
# 0    /rc/clk?jk=84b5e99096caca3e&fccid=f368300325e8...
# 1    /rc/clk?jk=22251926e7343040&fccid=594d10b1768e...
# 2    /rc/clk?jk=bdc9c70e47688613&fccid=7442885bc0fa...
# 3    /rc/clk?jk=17cbc7f854984298&fccid=dd616958bd9d...
# 4    /rc/clk?jk=00c843be7039172a&fccid=c5284eeef83d...
# ..                                                 ...
# 507  /company/The-One-Pioneer/jobs/Chinese-Marketin...
# 508  /rc/clk?jk=f6f5ecba3c3f39b9&fccid=198b7374e1f8...
# 509  /pagead/clk?mo=r&ad=-6NYlbfkN0AryF7OTLCWq605df...
# 510  /rc/clk?jk=75ab6b6451ebe0c4&fccid=68cfe21d4d32...
# 511  /rc/clk?jk=4f685dd39850c872&fccid=c54f93d4127e...
#
#                                           Descriptions
# 0    Snap Inc\nis a technology company. We believe ...
# 1    Prologis is the global leader in logistics rea...
# 2    Company Description\n\nAt ServiceNow, our tech...
# 3    Collectors is building the future of how colle...
# 4    At AWAL, we are on a mission to partner with i...
# ..                                                 ...
# 507  The Director of Marketing will be responsible ...
# 508  RSM is seeking a Transaction Advisory Services...
# 509  Had Enough of “Typical” Tech Jobs? Drive Innov...
# 510  TRC Advanced Energy (TRC) is a nationally know...
# 511  Quadric is building a full-stack system that i...
#
# [512 rows x 9 columns]
