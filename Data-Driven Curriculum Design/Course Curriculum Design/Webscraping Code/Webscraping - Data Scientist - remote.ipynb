# %% [markdown]
# # Web Scraping - Indeed.com
# General steps for Web Scraping
# 1. Check whether the website allows web scraping
# 2. Obtain the source code (HTML File) by using the website URL
# 3. Download the website content
# 4. Parse the content using keywords tags for elements of interest
# 5. Extract relevant data/features
# 6. Organize raw data in structured format (e.g., CSV)

# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from datetime import datetime
from arsenic import get_session
from arsenic.browsers import Firefox
from arsenic.services import Geckodriver
import asyncio
import time

# disable arsenic logging to stdout
import structlog
import logging

logger = logging.getLogger()
logger.setLevel(logging.WARN)
structlog.configure(logger_factory=lambda: logger)

# %% [markdown]
# ### Path to webdriver (Firefox, Chrome)

# %%
# Ensure that the driver path is correct before running this script.
# Microsoft Windows
# driver_path = "./drivers/windows/geckodriver.exe"
#driver_path = "./programs/geckodriver.exe"
driver_path = r"C:\Users\ranga\Downloads\geckodriver-v0.32.1-win64\geckodriver.exe"
# Linux
# driver_path = "./drivers/linux/geckodriver"
# driver_path = "/usr/bin/geckodriver"

options = {
  'moz:firefoxOptions': {
    # if you want it to be headless
    'args': ['-headless'],
    'log': {'level': 'warn'},
    # Needed for windows / non-default firefox install
    'binary': 'C:\\Program Files\\Mozilla Firefox\\firefox.exe'
  }
}

# %% [markdown]
# ### Define position and location

# %%
## Enter a job position
position = "data scientist"
## Enter a location (City, State or Zip or remote)
locations = "remote"

def get_url(position, location):
    url_template = "https://www.indeed.com/jobs?q={}&l={}"
    url = url_template.format(position, location)
    return url

url = get_url(position, locations)
dataframe = pd.DataFrame(columns=["Title", "Company", "Location", "Rating", "Date", "Salary", "Description", "Links"])

# %% [markdown]
# ### Scrape job postings

# %%
## Number of postings to scrape
postings = 1600

## Number of browser instances to use
n = 3

pages = list(range(0, postings, 10))

state = {
  'lock': asyncio.Lock(),
  'ids': set(),
  'n': 0
}
             
async def get_jobs(url, pages, state):
  data = []
  async with get_session(Geckodriver(binary=driver_path, log_file=asyncio.subprocess.PIPE), Firefox(**options)) as session:
    for i in pages:
      await session.get(url + "&start=" + str(i))
      jobs = await session.get_elements("[class='job_seen_beacon']")

      for job in jobs:
        result_html = await job.get_property('innerHTML')
        soup = BeautifulSoup(result_html, 'html.parser')

        liens = await job.get_elements("a")
        link = await liens[0].get_attribute("href")

        title = soup.select('.jobTitle')[0].get_text().strip()
        try:
          company = soup.select('.companyName')[0].get_text().strip()
        except:
          continue
        location = soup.select('.companyLocation')[0].get_text().strip()
        try:
            salary = soup.select('.salary-snippet-container')[0].get_text().strip()
        except:
            salary = 'NaN'
        try:
            rating = soup.select('.ratingNumber')[0].get_text().strip()
        except:
            rating = 'NaN'
        try:
            date = soup.select('.date')[0].get_text().strip()
        except:
            date = 'NaN'
        try:
            description = soup.select('.job-snippet')[0].get_text().strip()
        except:
            description = ''
            
        Id = f"{title}{company}{location}{rating}{date}{salary}{description}"
        dupe = False
        async with state['lock']:
          if Id in state['ids']:
            dupe = True
          else:
            state['ids'].add(Id)
            state['n'] = state['n'] + 1
            print("Job number {0:4d} added - {1:s}".format(state['n'],title))
        if dupe:
          continue

        data.append({
          'Title': title,
          "Company": company,
          'Location': location,
          'Rating': rating,
          'Date': date,
          "Salary": salary,
          "Description": description,
          "Links": link
        })

        # print("Job number {0:4d} added - {1:s}".format(jn,title))
      i = i + 10
  return data

tasks = [asyncio.create_task(get_jobs(url, p, state)) for p in np.array_split(pages, n)]
dataframe = pd.DataFrame([j for task in tasks for j in await task])
# Out:
# Job number    1 added - Statistician III
# Job number    2 added - Chief Data Officer
# Job number    3 added - Software Developer (AI/ML)
# Job number    4 added - Statistician
# Job number    5 added - Sr Data Engineer
# Job number    6 added - Associate Data Scientist - Rotational Program
# Job number    7 added - Senior Reliability Data Analyst
# Job number    8 added - Data Scientist - RWD
# Job number    9 added - Staff Data Scientist - Marketing
# Job number   10 added - Jr. Data Scientist
# Job number   11 added - Data Scientist
# Job number   12 added - Senior IT Data Analyst
# Job number   13 added - Interdisciplinary-Microbiologist/Data Scientist
# Job number   14 added - Senior Staff Machine Learning Engineer, Perception
# Job number   15 added - Data Scientist I, Product Analytics
# Job number   16 added - AI Developer/Software Engineer (Remote)
# Job number   17 added - Jr. Data Scientist
# Job number   18 added - Genesys Business Analyst with AI and CX Experience
# Job number   19 added - Computational Biologist / Data Scientist
# Job number   20 added - Statistical Programmer
# Job number   21 added - Data Scientist with AI and ML experience
# Job number   22 added - Data Scientist
# Job number   23 added - Mid-Level Data Scientist
# Job number   24 added - Associate Data Scientist
# Job number   25 added - Senior Data Analyst
# Job number   26 added - Data Scientist
# Job number   27 added - PhD Residency - Network Security, Privacy, and AI/ML
# Job number   28 added - Senior Manager US Data Science & Advanced Analytics - Fully Remote
# Job number   29 added - Data Scientist / NLP (Python, Django/Flask, NLP, Clustering, Rest API)
# Job number   30 added - Senior Marketplace Insights Data Analyst
# Job number   31 added - Senior Statistician
# Job number   32 added - Software Engineer IV (Machine Learning, .Net Core)
# Job number   33 added - Data Scientist (All Levels)
# Job number   34 added - Statistical Programmer (Remote)
# Job number   35 added - Staff MLOps Engineer, Data Platform
# Job number   36 added - Director- Machine Learning Engineer - MLOps (REMOTE)
# Job number   37 added - Senior Tech Lead, Machine Learning
# Job number   38 added - Senior Statistician (US Office)
# Job number   39 added - Lead Statistician
# Job number   40 added - HR/Payroll Senior Data Analyst - Report Writer
# Job number   41 added - Machine Learning Engineer
# Job number   42 added - Senior Statistical Programmer
# Job number   43 added - Machine Learning Engineer
# Job number   44 added - Product Manager - Analytics
# Job number   45 added - Senior Machine Learning Engineer
# Job number   46 added - MAGNet Lead (ASU) Data Scientist
# Job number   47 added - Expert Machine Learning Engineer
# Job number   48 added - Data Science Engineer III
# Job number   49 added - Cloud Infrastructure Architect, Data Science Solutions
# Job number   50 added - Senior Data Scientist
# Job number   51 added - Healthcare Data Science
# Job number   52 added - Lead Data Governance Engineer - REQ 616
# Job number   53 added - Senior Machine Learning Engineer - Ads (Remote)
# Job number   54 added - Senior Data Analyst, Travel Insights
# Job number   55 added - Machine Learning Scientist, Frontier Research - Prescient Design *Remote Work*
# Job number   56 added - Data Scientist
# Job number   57 added - Statistical Programmer II
# Job number   58 added - Lead Analyst - Data Science, Analytics
# Job number   59 added - PhD Residency - Network Security, Privacy, and AI/ML
# Job number   60 added - Manager of Data Science
# Job number   61 added - Principal Data Scientist
# Job number   62 added - Manager EHS Global Audit, Data and Analytics
# Job number   63 added - Part-Time Researcher Using Machine Learning In Finance
# Job number   64 added - Data Scientist jobs
# Job number   65 added - Data Engineer 3
# Job number   66 added - Data Scientist - Fully remote
# Job number   67 added - Senior Data Analyst
# Job number   68 added - Data Scientist
# Job number   69 added - Data Scientist
# Job number   70 added - AI Business Analyst
# Job number   71 added - Data Scientist
# Job number   72 added - Data Scientist
# Job number   73 added - Healthcare Data Scientist
# Job number   74 added - Research Associate, Artificial Intelligence
# Job number   75 added - Data Scientist
# Job number   76 added - Staff MLOps Engineer, Data Platform
# Job number   77 added - Director- Machine Learning Engineer - MLOps (REMOTE)
# Job number   78 added - HR/Payroll Senior Data Analyst - Report Writer
# Job number   79 added - Machine Learning Engineer
# Job number   80 added - Product Manager - Analytics
# Job number   81 added - Data Statistician
# Job number   82 added - Principal Machine Learning Engineer
# Job number   83 added - Machine Learning Software Engineer
# Job number   84 added - Senior Machine Learning Engineer
# Job number   85 added - Data Scientist, Ecosystem
# Job number   86 added - Head of Data
# Job number   87 added - Principal Statistician
# Job number   88 added - Data Scientist-Health
# Job number   89 added - Senior Marketing Data Analyst
# Job number   90 added - Associate Principal Data Scientist (Lead Clinical Data Manager)
# Job number   91 added - Machine Learning Engineer: Natural Language Processing
# Job number   92 added - Senior Data Analyst
# Job number   93 added - Data Scientist - Public Sector
# Job number   94 added - AI/ML Engineer
# Job number   95 added - Sr. Data Scientist
# Job number   96 added - Machine Learning Ops Engineer
# Job number   97 added - Big Data ETL Developer
# Job number   98 added - Director, Data Science (P83)
# Job number   99 added - Frontend Big Data Engineer - PySpark
# Job number  100 added - Data Scientist (Engineer II)
# Job number  101 added - Business Analyst (AI Governance)
# Job number  102 added - Remote Spatial Data Scientist - RBG
# Job number  103 added - Remote Senior Data Analyst
# Job number  104 added - Data Scientist
# Job number  105 added - Mid-Level Data Scientist
# Job number  106 added - Data Scientist, CV/NLP
# Job number  107 added - Data Scientist
# Job number  108 added - Senior Data Scientist
# Job number  109 added - Data Scientist - Remote or Hybrid
# Job number  110 added - Technical Program Manager (AI)
# Job number  111 added - Data Scientist - REMOTE
# Job number  112 added - Senior Data Scientist (US Remote Eligible)
# Job number  113 added - Senior Manager, Decision Science
# Job number  114 added - Data Science Manager
# Job number  115 added - Data Scientist
# Job number  116 added - Customer Support Engineer, Machine Learning (Remote)
# Job number  117 added - Data Engineer
# Job number  118 added - AVP, Data Scientist
# Job number  119 added - Sr. Statistical Programmer
# Job number  120 added - Sr. Manager, Data Analyst
# Job number  121 added - Data Scientist (Remote)
# Job number  122 added - Data Scientist- Epidemiology
# Job number  123 added - Senior Data Analyst
# Job number  124 added - AI/ML Engineer
# Job number  125 added - Senior Data Analyst
# Job number  126 added - Data Scientist
# Job number  127 added - Informatician- Data Lake Product Manager - Research Scientist 3
# Job number  128 added - Data Scientist I
# Job number  129 added - Sr. Architect - Customer Data
# Job number  130 added - Data Scientist, Customer Experimentation
# Job number  131 added - Product Owner - Data Management, Data Science & Analytics (Remote)
# Job number  132 added - Freelance Data Scientist
# Job number  133 added - Sr. Machine Learning Engineer - (REMOTE)
# Job number  134 added - AI engineer
# Job number  135 added - Data Scientist, Abuse Prevention
# Job number  136 added - Sr. Data Analyst
# Job number  137 added - ML Engineer - Entry Level
# Job number  138 added - Data Scientist
# Job number  139 added - Senior Revenue Operations Data Analyst (Remote)
# Job number  140 added - Principal Data Scientist
# Job number  141 added - Product Manager (Retail_Machine Learning_Data Analytics_Merchandising)
# Job number  142 added - Senior Software Engineer - Machine Learning
# Job number  143 added - Lead Data Scientist
# Job number  144 added - Senior Data Scientist
# Job number  145 added - Sr. Data Scientist (Remote)
# Job number  146 added - Sr. Data Analyst (Product)
# Job number  147 added - Data Scientist, Machine Learning
# Job number  148 added - Sr. Data Scientist II (Remote)
# Job number  149 added - Software Engineer(AI/ML)
# Job number  150 added - Cloud Data Engineer
# Job number  151 added - Senior Data Analyst / Data Modeler
# Job number  152 added - Data Scientist
# Job number  153 added - Senior Analyst/Statistician
# Job number  154 added - Senior Data Science Analyst
# Job number  155 added - Senior/Staff Machine Learning Engineer, Infrastructure
# Job number  156 added - Senior Financial Data Analyst
# Job number  157 added - Associate Data Scientist (Remote)
# Job number  158 added - Senior Data Scientist
# Job number  159 added - Data Scientist (Hybrid)
# Job number  160 added - Senior Data Analyst
# Job number  161 added - Data Scientist Advisor
# Job number  162 added - Data Scientist
# Job number  163 added - Data Scientist
# Job number  164 added - Lead Data Scientist
# Job number  165 added - Data Forensics Scientist
# Job number  166 added - Data Science Specialist
# Job number  167 added - Data Science, eBay Shipping Initiatives
# Job number  168 added - Staff Software Engineer - Data Infrastructure - (Permanent Remote, US)
# Job number  169 added - Artificial Intelligence (AI) Scientist - Cell & Gene Therapies
# Job number  170 added - Machine Learning Engineer (Associate)
# Job number  171 added - Sr. Principal Applied Research Scientist (AI and Machine Learning)
# Job number  172 added - Staff Data Scientist
# Job number  173 added - Digital Transformation/Data Science Student Employee
# Job number  174 added - Program Integrity Data Scientist
# Job number  175 added - Statistical Programmer
# Job number  176 added - Revenue Mgmt Data Science - Principal Analyst (Remote)
# Job number  177 added - Sr Data Scientist (SAS & Healthcare domain expr mandatory) - 10 Years only
# Job number  178 added - Product Manager, Machine Learning
# Job number  179 added - Statistician - Behavioral Biology
# Job number  180 added - Data Scientist / Machine Learning Engineer
# Job number  181 added - Senior Data Scientist
# Job number  182 added - Senior Data Analyst (Business Analysis)
# Job number  183 added - Data Scientist
# Job number  184 added - Senior Data Analyst
# Job number  185 added - (Senior) Data Scientist, Clinical & Genomics
# Job number  186 added - Data Scientist
# Job number  187 added - Informatician - Data Exchange Hub Product Manager - Research Scientist 3
# Job number  188 added - Manager, Data Science
# Job number  189 added - Senior Financial Data Analyst (Remote) - Medical School Financial Reporting
# Job number  190 added - Senior Data Scientist
# Job number  191 added - Data Scientist or Statistician, Postdoc
# Job number  192 added - Data Scientist
# Job number  193 added - Applied Scientist - Ad Market Dynamic (Remote)
# Job number  194 added - Data Scientist (Manufacturing)
# Job number  195 added - Data Scientist - Remote
# Job number  196 added - Senior Machine Learning Manager
# Job number  197 added - Azure Data Engineer (Remote)
# Job number  198 added - Data Scientist, Space Optimization (Remote)
# Job number  199 added - Data Scientist
# Job number  200 added - Hiring for Data Science and Data Engineer on w2
# Job number  201 added - Applied Data Scientist
# Job number  202 added - Sr. Health Data Analyst Remote
# Job number  203 added - Machine Learning Content Writer
# Job number  204 added - Senior Data Analyst - Brand Solutions
# Job number  205 added - Data Scientist
# Job number  206 added - Associate Director, Statistical Programming
# Job number  207 added - Lead Data Scientist
# Job number  208 added - Senior/Staff Clinical Data Engineer
# Job number  209 added - Senior Data Scientist (REMOTE POSITION)
# Job number  210 added - Sr Provider Data Analyst - Remote
# Job number  211 added - Statistical Programmer 2 (Oncology) FSP: Remote
# Job number  212 added - Data Scientist (GeoMatch)
# Job number  213 added - Data Scientist
# Job number  214 added - DATA SCIENTISTS
# Job number  215 added - Data Scientist
# Job number  216 added - Manager, CRM Data Science Analytics
# Job number  217 added - Senior Director, Data Science
# Job number  218 added - Senior Data Scientist
# Job number  219 added - Data Scientist
# Job number  220 added - Senior Data Analyst, Research and Development
# Job number  221 added - Machine Learning Engineer
# Job number  222 added - Machine Learning Engineer, Senior
# Job number  223 added - Senior Consultant, Decision Science
# Job number  224 added - Senior Manager, Data Science
# Job number  225 added - Senior Data Scientist
# Job number  226 added - Data Scientist III REMOTE (VA,MD,WV,NC,SC,TN,FL,TX,GA)
# Job number  227 added - Manager Analytics and Data Science - Stars Program
# Job number  228 added - Data Scientist
# Job number  229 added - Machine Learning Engineer (NLP)
# Job number  230 added - Sr. Data Analyst I
# Job number  231 added - Senior Data Scientist (Experience with Media Mix Modeling)
# Job number  232 added - Senior Data Scientist
# Job number  233 added - Data Scientist - W2 no C2C
# Job number  234 added - Data Scientist (Remote USA ONLY)
# Job number  235 added - Data Scientist, Data Quality Engineer
# Job number  236 added - Data Scientist - Location Analytics
# Job number  237 added - Artificial Intelligence Researcher
# Job number  238 added - Sr. Business Systems Analyst (Data Analyst)
# Job number  239 added - Python Developer (NLP)
# Job number  240 added - Senior Computer Vision and Machine Learning Engineer
# Job number  241 added - Data Scientist
# Job number  242 added - Data Scientist
# Job number  243 added - Senior Data Science Engineer
# Job number  244 added - Senior Compliance Data Analyst
# Job number  245 added - Principal Machine Learning Engineer
# Job number  246 added - Data Scientist
# Job number  247 added - Statistical Programmer
# Job number  248 added - Python Machine Learning Developer
# Job number  249 added - Senior Data Scientist
# Job number  250 added - Senior Data Scientist I - Remote
# Job number  251 added - Data Scientist
# Job number  252 added - SENIOR DATA ANALYST - CLT/REMOTE
# Job number  253 added - Senior Data Scientist
# Job number  254 added - Google Cloud Data Engineer
# Job number  255 added - Data Scientist
# Job number  256 added - Lead Data Scientist, Real Estate
# Job number  257 added - Patient Safety Principal Statistician
# Job number  258 added - Senior Statistical Programmer I
# Job number  259 added - Sr. Data Analyst
# Job number  260 added - Data Engineer
# Job number  261 added - Principle Machine Learning Engineer, Battery Storage
# Job number  262 added - Data Scientist - Risk & Analytics
# Job number  263 added - Sr. Data Analyst
# Job number  264 added - Data Scientist
# Job number  265 added - Senior Financial Data Analyst
# Job number  266 added - Data Scientist
# Job number  267 added - Senior Machine Learning Platform Engineer
# Job number  268 added - Sr. Data Analyst
# Job number  269 added - Senior Auditor
# Job number  270 added - Sr. Data Scientist, Model Risk Management
# Job number  271 added - Senior Applied Scientist - NLP
# Job number  272 added - Job Title: ML Engineer Job Location: Remote Job Type: Contract
# Job number  273 added - Senior Healthcare Data Analyst
# Job number  274 added - Manager, Data Science Engineer
# Job number  275 added - Senior Data Scientist
# Job number  276 added - Sr. Director, Data Science
# Job number  277 added - Sr Data Analyst
# Job number  278 added - AI Engineer / Architect with Experience in Edtech or Gaming Industry
# Job number  279 added - Machine Learning Engineer (Remote)
# Job number  280 added - Data Scientist
# Job number  281 added - Data Scientist
# Job number  282 added - Clinical Data Analyst
# Job number  283 added - Data Scientist
# Job number  284 added - Data Scientist
# Job number  285 added - Machine Learning Architect
# Job number  286 added - Senior Data Analyst (Clinical Research)
# Job number  287 added - Principal Stat Programmer
# Job number  288 added - Director of Machine Learning Research
# Job number  289 added - Senior/Staff Data Scientist, Classifier Design
# Job number  290 added - Lead Biostatistician / Data Scientist
# Job number  291 added - Sr Data Scientist
# Job number  292 added - Senior Data Scientist
# Job number  293 added - Senior Data Scientist
# Job number  294 added - Senior Technical Project Manager / Business Data Analyst - REMOTE
# Job number  295 added - Data Scientist
# Job number  296 added - Senior Analyst Data Strategy
# Job number  297 added - Sr. Machine Learning Engineer
# Job number  298 added - Data Scientist
# Job number  299 added - Machine Learning Engineer, Browse and Retention Engineering, TL Architect
# Job number  300 added - Manager, Machine Learning Infrastructure
# Job number  301 added - Marketing Data Science, Sr. Manager - Remote
# Job number  302 added - Sr. NLP/AI Engineer
# Job number  303 added - Data Scientist
# Job number  304 added - Senior Software Engineer, Detection Machine Learning Infrastructure
# Job number  305 added - Senior Data Scientist
# Job number  306 added - Sr. Software Engineer - Data
# Job number  307 added - Machine Learning Engineer
# Job number  308 added - Data Engineer/Data Scientist
# Job number  309 added - Senior Data Scientist - Telematics (REMOTE)
# Job number  310 added - Data Scientist
# Job number  311 added - Job Open for Data Scientist with Azure_Remote
# Job number  312 added - AI Research Engineer
# Job number  313 added - Sr. Data Analyst
# Job number  314 added - Machine Learning Software Engineer
# Job number  315 added - Machine Learning Engineer
# Job number  316 added - Associate Principal Statistical Programmer, Submission Data Standards Quality Management (SDS QM) (Remote)
# Job number  317 added - Sr. Product Data Scientist (Remote)
# Job number  318 added - Senior Machine Learning Product Owner (100% Remote)
# Job number  319 added - Data Scientist
# Job number  320 added - Machine Learning Engineer in the Optimization team - US Remote
# Job number  321 added - Data Specialist
# Job number  322 added - Data Scientist
# Job number  323 added - Senior Data Analyst
# Job number  324 added - Full stack data scientist (able to do pre-sales)
# Job number  325 added - Data Scientist, Statistics
# Job number  326 added - Senior Azure Data Engineer (Remote - US)
# Job number  327 added - Data Scientist - remote
# Job number  328 added - Senior Statistical Programmer - FSP model
# Job number  329 added - Data Scientist
# Job number  330 added - Senior Clinical Data Analyst
# Job number  331 added - Data Scientist
# Job number  332 added - Senior Data Scientist – Product R&D
# Job number  333 added - Data Scientist I
# Job number  334 added - Director of Pricing Algorithms & Data Science
# Job number  335 added - Senior Data Analyst
# Job number  336 added - Machine Learning Engineer - Automatic Speech Recongnition
# Job number  337 added - Data Scientist (Remote)
# Job number  338 added - Staff Machine Learning Engineer
# Job number  339 added - Data Scientist II (Remote/US)
# Job number  340 added - Data Scientist - Commercial Analytics (Remote)
# Job number  341 added - Data Scientist
# Job number  342 added - Sports Data Scientist
# Job number  343 added - Data Visualization Specialist
# Job number  344 added - Data Scientist (Remote)
# Job number  345 added - Associate Data Scientist
# Job number  346 added - Sr Biomarker Data Analyst
# Job number  347 added - Senior Labor Market Data Analyst
# Job number  348 added - Data Scientist - Natural Language Processing (remote)
# Job number  349 added - Data Scientist (Remote)
# Job number  350 added - Data Scientist
# Job number  351 added - AI Specialist - Compiler
# Job number  352 added - Data Scientist
# Job number  353 added - HR/Payroll Senior Data Analyst - Report Writer
# Job number  354 added - Data Scientist
# Job number  355 added - Senior Data Scientist - Digital Bidding
# Job number  356 added - Machine Learning Engineer
# Job number  357 added - Junior Data Scientist / Survey Operations
# Job number  358 added - Data Scientist | Remote-US
# Job number  359 added - Senior Data Scientist
# Job number  360 added - Mid-Level Data Scientist
# Job number  361 added - Machine Learning Engineer
# Job number  362 added - Data Science Engineer
# Job number  363 added - Senior Data Scientist (Remote)
# Job number  364 added - Data Scientist, Junior
# Job number  365 added - Data Scientist
# Job number  366 added - Data Scientist
# Job number  367 added - Lead Data Scientist
# Job number  368 added - Principal Data Scientist Artificial Intelligence Machine Learning Scientist - Financial Advice
# Job number  369 added - Informatics Data Scientist
# Job number  370 added - Senior Data Analyst
# Job number  371 added - Machine Learning Engineer
# Job number  372 added - Data Engineer - Remote Opportunity - SimioCloud
# Job number  373 added - Principal Statistical Programmer
# Job number  374 added - Senior Data Scientist (Deep Learning)
# Job number  375 added - Senior Data Analyst - US Remote
# Job number  376 added - Principal Statistician - EMEA - The Americas - Office or Remote
# Job number  377 added - Data Scientist (Machine Learning)
# Job number  378 added - Statistical Modeler II (hybrid / remote)
# Job number  379 added - Data Scientist - Role can be remote
# Job number  380 added - Senior Consumer Compliance Data Analyst - Hybrid/Remote
# Job number  381 added - Data Scientist
# Job number  382 added - Data Scientist - REMOTE
# Job number  383 added - Sr. Artificial Intelligence Architect
# Job number  384 added - Staff Applied Scientist
# Job number  385 added - Machine Learning Engineer: Recall Team (Remote)
# Job number  386 added - Senior Research Scientist/Director - Epidemiology, Data Analytics - Evidera
# Job number  387 added - Data Scientist
# Job number  388 added - Marketing Data Scientist
# Job number  389 added - Data Scientist
# Job number  390 added - Sr. Data Scientist 17960
# Job number  391 added - Machine Learning Engineer: Recall Team (Remote)
# Job number  392 added - Senior Research Scientist/Director - Epidemiology, Data Analytics - Evidera
# Job number  393 added - Staff Applied Scientist - Remote Eligible
# Job number  394 added - Machine Learning Engineer: Recall Team (Remote)
# Job number  395 added - Senior Research Scientist/Director - Epidemiology, Data Analytics - Evidera
# Job number  396 added - Machine Learning Engineer
# Job number  397 added - Data Scientist, Commercial
# Job number  398 added - Data Scientist
# Job number  399 added - Machine Learning Engineer
# Job number  400 added - Senior Data Scientist
# Job number  401 added - Senior Data Analyst, Research Success
# Job number  402 added - Sr. Data Analyst, Collections (REMOTE)
# Job number  403 added - Senior Data Scientist - Ads Ranking
# Job number  404 added - Principal Data Engineer- Machine Learning Op (REMOTE /Contract)
# Job number  405 added - Machine Learning Scientist
# Job number  406 added - Data Science Manager (Remote)
# Job number  407 added - Cryptocurrency Algorithmic Trader
# Job number  408 added - Data Scientist
# Job number  409 added - Senior Data Scientist (Remote)
# Job number  410 added - Senior Data Analyst
# Job number  411 added - Machine Learning Engineer
# Job number  412 added - 0501WFH - 1447 Data Scientist
# Job number  413 added - Sr. Data Analyst - Healthcare Rev Cycle Reporting (Epic/SQL) - 100% Remote
# Job number  414 added - Data Scientist III
# Job number  415 added - Data Scientist
# Job number  416 added - NLP Developer
# Job number  417 added - Staff Data Scientist
# Job number  418 added - Applied NLP Engineer
# Job number  419 added - Machine Learning Engineer
# Job number  420 added - Data Scientist
# Job number  421 added - Junior Data Scientist
# Job number  422 added - Senior Data Analyst | No-Code SaaS | 100% Remote
# Job number  423 added - Data Scientist/Analyst
# Job number  424 added - Data Scientist
# Job number  425 added - Senior Data Analyst (Product Analytics)
# Job number  426 added - SR HEALTHCARE DATA ANALYST - Remote
# Job number  427 added - Data Mining Scientist
# Job number  428 added - Senior Data Science QA Engineer
# Job number  429 added - Data Scientist II -18859
# Job number  430 added - Senior Data Scientist
# Job number  431 added - Senior Data Scientist
# Job number  432 added - Lead Data Scientist
# Job number  433 added - Junior to Senior Data Analyst/Power BI Analyst
# Job number  434 added - Data Scientist
# Job number  435 added - Data Scientist - Analytics
# Job number  436 added - Artificial Intelligence Developer
# Job number  437 added - Data Scientist - Remote
# Job number  438 added - Data Scientist - Marketing (Remote Eligible)
# Job number  439 added - Sr. Data Scientist
# Job number  440 added - Quality Measurement Analyst (Analytics and Data Science, Remote)
# Job number  441 added - Quantitative Researcher
# Job number  442 added - Data Scientist
# Job number  443 added - Data Science Admissions Specialist (Part-time)
# Job number  444 added - Machine Learning Engineer
# Job number  445 added - Data Visualization Specialist
# Job number  446 added - AI Machine Learning Data Analyst
# Job number  447 added - Staff Machine Learning Engineer, Ads Marketplace Quality
# Job number  448 added - Data Scientist
# Job number  449 added - Senior Data Analyst
# Job number  450 added - Machine Learning Engineer
# Job number  451 added - Data Scientist
# Job number  452 added - Data Scientist
# Job number  453 added - Sr. Data Engineer
# Job number  454 added - Machine Learning Engineer
# Job number  455 added - Senior Data Scientist
# Job number  456 added - Statistical Analyst
# Job number  457 added - Machine Learning Engineer: Recall Team (Remote)
# Job number  458 added - Senior Research Scientist/Director - Epidemiology, Data Analytics - Evidera
# Job number  459 added - Senior Data Analyst
# Job number  460 added - Data Science Engineer
# Job number  461 added - Data Scientist II
# Job number  462 added - Actuarial Data Scientist - Remote
# Job number  463 added - Senior Data Scientist
# Job number  464 added - Senior Data Analyst- Evernorth Health Services- Remote
# Job number  465 added - Lead Data Scientist
# Job number  466 added - Staff Data Scientist - Revenue Cycle
# Job number  467 added - Vitria Data Scientist
# Job number  468 added - Data Scientist / Data Analyst
# Job number  469 added - Data Scientist
# Job number  470 added - Senior Data Scientist
# Job number  471 added - Data Scientist
# Job number  472 added - Senior Machine Learning Engineer
# Job number  473 added - Senior Data Scientist
# Job number  474 added - Sr. Data Scientist
# Job number  475 added - Sr. Marketing Data Analyst
# Job number  476 added - Global Data Scientist
# Job number  477 added - Sr. Data Analyst/Project Lead - Health Plan Sales Analytics - 100% Remote
# Job number  478 added - Data Scientist
# Job number  479 added - Data Scientist
# Job number  480 added - Conversational A.I. Engineer
# Job number  481 added - Senior Data Scientist
# Job number  482 added - Sr Data Engineer
# Job number  483 added - Data Science Developer
# Job number  484 added - Machine Learning Engineer - All Levels (REMOTE)
# Job number  485 added - Statistician SFCC
# Job number  486 added - Data Scientist, Level II
# Job number  487 added - Data Scientist
# Job number  488 added - Data Scientist
# Job number  489 added - Credit Strategy Analyst, Credit Risk Analytics
# Job number  490 added - Lead Data Scientist
# Job number  491 added - Sr Data Analyst, IQVIA Biotech, Homebased
# Job number  492 added - Senior Data Scientist
# Job number  493 added - Applied Data Scientist
# Job number  494 added - Data Scientist I
# Job number  495 added - Senior Data Analyst
# Job number  496 added - Machine Learning Scientist
# Job number  497 added - ML Engineer
# Job number  498 added - Data Scientist (Remote)
# Job number  499 added - Senior Data Scientist – Remote/Flex
# Job number  500 added - Senior Data Scientist (Deep Learning)
# Job number  501 added - Senior Data Analyst - US Remote
# Job number  502 added - Senior Data Scientist - Remote
# Job number  503 added - Principal Statistician - EMEA - The Americas - Office or Remote
# Job number  504 added - Director of Machine Learning Research
# Job number  505 added - Senior Clinical Data Analyst
# Job number  506 added - Director of Pricing Algorithms & Data Science
# Job number  507 added - Statistical Modeler II (hybrid / remote)
# Job number  508 added - Senior Financial Data Analyst
# Job number  509 added - Commercial Analytics Data Scientist
# Job number  510 added - Senior Consumer Compliance Data Analyst - Hybrid/Remote
# Job number  511 added - Sr. Artificial Intelligence Architect
# Job number  512 added - Senior Associate Data Scientist, Cloud, Data & Analytics Team
# Job number  513 added - Staff Applied Scientist
# Job number  514 added - Senior Statistical Programmer
# Job number  515 added - Senior Data Scientist, Trust and Safety
# Job number  516 added - Job Title: ML Engineer Job Location: Remote Job Type: Contract
# Job number  517 added - Senior Data Scientist
# Job number  518 added - Machine Learning Engineer: Recall Team (Remote)
# Job number  519 added - Data Scientist
# Job number  520 added - Senior Research Scientist/Director - Epidemiology, Data Analytics - Evidera
# Job number  521 added - Backend Web Developer - Machine Learning - Remote
# Job number  522 added - Data Scientist
# Job number  523 added - Sr. Machine Learning Engineer - Generative Modeling (Remote)
# Job number  524 added - Data Scientist (Machine Learning)
# Job number  525 added - Sr. Data Scientist (NLP)
# Job number  526 added - Machine Learning Mentor (Summer 2023)
# Job number  527 added - Data Scientist
# Job number  528 added - Senior Data Scientist, Marketing & Online (Remote)
# Job number  529 added - Machine Learning Engineer - Join Our AI Adventure!
# Job number  530 added - Senior Natural Language Processing Researcher
# Job number  531 added - Sr. Data Analyst
# Job number  532 added - Sr Data Scientist, West
# Job number  533 added - Senior Data Engineer
# Job number  534 added - Research Data Scientist
# Job number  535 added - Sr. Machine Learning Engineer
# Job number  536 added - Staff Software Engineer, Machine Learning - Homefeed & Notifications
# Job number  537 added - Azure Data Engineer (Remote)
# Job number  538 added - Data Scientist - Vyasa
# Job number  539 added - Sr. Data Analyst, Electric Vehicles
# Job number  540 added - Senior Data Scientist
# Job number  541 added - Data Scientist
# Job number  542 added - Hiring for Data Science and Data Engineer on W2
# Job number  543 added - Mathematical Statistician (Direct Hire Authority)
# Job number  544 added - Analytics & Insights Analyst
# Job number  545 added - Senior Data Scientist – Privacy (remote)
# Job number  546 added - Machine Learning Engineer
# Job number  547 added - Senior Data Analyst
# Job number  548 added - Data Scientist
# Job number  549 added - Staff Machine Learning Engineer
# Job number  550 added - Senior Data Analyst
# Job number  551 added - LEAD DATA SCIENTIST
# Job number  552 added - Statistical Analyst
# Job number  553 added - Machine Learning Engineer III
# Job number  554 added - Computational and Data Science Research Specialist 3
# Job number  555 added - Senior Data Analyst
# Job number  556 added - Senior Healthcare Data Analyst
# Job number  557 added - Senior Consultant, Decision Science
# Job number  558 added - Data Management Architect - REMOTE
# Job number  559 added - Senior Machine Learning Engineer
# Job number  560 added - Data Scientist Journeyman
# Job number  561 added - Sr. Product Data Analyst
# Job number  562 added - AI Sales Engineer
# Job number  563 added - Director for Data Strategy and Data Governance
# Job number  564 added - Senior Data Analyst - Marketing (REMOTE)
# Job number  565 added - Senior Data Scientist
# Job number  566 added - Staff Machine Learning Engineer
# Job number  567 added - AI Engineer
# Job number  568 added - Senior Data Analyst - CDC DPEI (NM)
# Job number  569 added - Sr. Business Data Analyst
# Job number  570 added - Staff Business Systems Analyst - Data Science
# Job number  571 added - Senior Data Scientist - Marketplace
# Job number  572 added - Data Scientist
# Job number  573 added - Data Scientist - Talent Network
# Job number  574 added - Data Scientist Journeyman
# Job number  575 added - AI Sales Engineer
# Job number  576 added - Senior Data Scientist – Product R&D
# Job number  577 added - Sr. Data Analyst I
# Job number  578 added - Junior Data Scientist
# Job number  579 added - Health Informatics Data Science Application Developer
# Job number  580 added - Data Science Consultant - Remote
# Job number  581 added - Co-Op, Machine Learning Data Scientist
# Job number  582 added - Senior Data Scientist - IntelliScript (Remote)
# Job number  583 added - Data Scientist
# Job number  584 added - Data Scientist
# Job number  585 added - AI Engineer (NLP)
# Job number  586 added - Senior Machine Learning Engineer – Document Intelligence
# Job number  587 added - Data Science Practice Lead - Health IT
# Job number  588 added - Natural Language Generation Developer
# Job number  589 added - Data Scientist Solutions Architect
# Job number  590 added - Machine Learning Co-Op
# Job number  591 added - Data Scientist (Vaccine) (Remote)
# Job number  592 added - Data Scientist
# Job number  593 added - Data Scientist
# Job number  594 added - Sr. Data Analyst, Pricing & Packaging
# Job number  595 added - Tech Lead Senior ML Engineer
# Job number  596 added - Mathematical Statistician
# Job number  597 added - Senior Data Scientist
# Job number  598 added - Data Scientist
# Job number  599 added - Sr. Data Scientist
# Job number  600 added - Senior Data Scientist, Core Data Science
# Job number  601 added - Senior Data Scientist
# Job number  602 added - Data Engineer
# Job number  603 added - Machine Learning Engineer - Python
# Job number  604 added - Senior Data Analyst
# Job number  605 added - Computational & Data Scientist
# Job number  606 added - Sr. Data Architect
# Job number  607 added - Blockchain Data Analyst
# Job number  608 added - Data Scientist, Forecasting, Supply Chain & Labor Planning
# Job number  609 added - Senior Data Analyst
# Job number  610 added - Lead Data Scientist
# Job number  611 added - Senior Data Scientist
# Job number  612 added - Machine Learning Engineer
# Job number  613 added - Data Scientist
# Job number  614 added - Senior Data Analyst
# Job number  615 added - Risk Intelligence - Data Analytics Lead (REMOTE/Contract))
# Job number  616 added - Manager of Manufacturing Analytics/ Data Science (Remote)
# Job number  617 added - Data Engineer/Scientist (Remote)
# Job number  618 added - Machine Learning Engineer (Remote)
# Job number  619 added - Data Scientist
# Job number  620 added - Associate Director - Data Science - Remote
# Job number  621 added - Data Scientist
# Job number  622 added - Data Scientist Principal
# Job number  623 added - Enterprise Data Specialist - Machine Learning
# Job number  624 added - Machine Learning Engineer
# Job number  625 added - Machine Learning Research Team Lead
# Job number  626 added - Senior Data Scientist | Machine Learning
# Job number  627 added - Embedded BI Data Scientist SIBU510
# Job number  628 added - Data Scientist
# Job number  629 added - Sr Clinical Data Scientist
# Job number  630 added - Senior Data Scientist
# Job number  631 added - Business Data Analyst, Sr Consultant - Remote
# Job number  632 added - Machine Learning Engineer
# Job number  633 added - Natural Language Processing (NLP) Engineer
# Job number  634 added - Data Acquisition Analyst
# Job number  635 added - Manager, Data Science
# Job number  636 added - Lead Data Scientist
# Job number  637 added - Instructor, Data Science
# Job number  638 added - Sr. Data Analyst, Clinical and Quality Analytics
# Job number  639 added - Senior Data Scientist (Remote)
# Job number  640 added - Statistician, Bayesian Statistics
# Job number  641 added - Senior Data Scientist
# Job number  642 added - Science Data Visualizer- Earth Science
# Job number  643 added - Statistician
# Job number  644 added - Sr People Data Analyst, HR People Analytics, Days
# Job number  645 added - Senior Principal Data Scientist
# Job number  646 added - Senior Data Analyst - Ataccama
# Job number  647 added - Senior Data Scientist
# Job number  648 added - Machine Learning Engineer
# Job number  649 added - Senior Data Scientist I - Remote
# Job number  650 added - Senior Data Analyst (CX/Op's)
# Job number  651 added - Senior Health Data Analyst
# Job number  652 added - CYBER SECURITY DATA SCIENTIST WITH SIEM
# Job number  653 added - Data Scientist, Search
# Job number  654 added - Associate Data Scientist (Genomic) - Epigenetics & Molecular Carcinogenesis (Ting Laboratory)
# Job number  655 added - Data Science Lead
# Job number  656 added - Data Scientist - Digital Marketing and Sales
# Job number  657 added - Data Scientist - Business Optimization
# Job number  658 added - Remote Senior Data Analyst (Supply Chain) - MB
# Job number  659 added - Software Engineer - Machine Learning Systems
# Job number  660 added - Data Engineer
# Job number  661 added - Sr. Data Analyst
# Job number  662 added - Expert Data Scientist
# Job number  663 added - Data Analyst II
# Job number  664 added - Sr. Data Analyst
# Job number  665 added - Machine Learning Engineer
# Job number  666 added - Machine Learning Engineer
# Job number  667 added - Machine Learning Engineer
# Job number  668 added - Data Engineer / Data Scientist
# Job number  669 added - Machine Learning Engineer
# Job number  670 added - Data Science and Analytics Specialist
# Job number  671 added - Machine Learning Engineer
# Job number  672 added - Senior Data Analyst
# Job number  673 added - Senior Data Analyst
# Job number  674 added - Data Scientist
# Job number  675 added - Statistician
# Job number  676 added - Senior Data Scientist, Product Analytics
# Job number  677 added - Data Scientist III
# Job number  678 added - Data Engineer
# Job number  679 added - Senior Data Engineering Manager (Level V)
# Job number  680 added - Consultant – Analytic Consulting and Data Science
# Job number  681 added - Machine Learning Engineer
# Job number  682 added - Principal Statistician
# Job number  683 added - Senior Data Analyst
# Job number  684 added - Machine Learning Engineer
# Job number  685 added - Staff Scientist, Artificial Intelligence
# Job number  686 added - Conversational AI / NLP Engineer
# Job number  687 added - Machine Learning Lead
# Job number  688 added - Sr. Data Analyst-Cloud
# Job number  689 added - Senior Sales Data Analyst
# Job number  690 added - Statistician - Direct Hire (Remote eligible)
# Job number  691 added - Senior Data Scientist
# Job number  692 added - AI Operations Manager
# Job number  693 added - Senior Data Scientist - Delivery Technology
# Job number  694 added - Senior Data Analyst
# Job number  695 added - Data Scientist, Insurance
# Job number  696 added - Statistician
# Job number  697 added - Senior Data Scientist (Computer Vision)
# Job number  698 added - Senior Data Analyst (Remote in TX)
# Job number  699 added - Data Science Analyst
# Job number  700 added - Big Data Developer(Remote)
# Job number  701 added - Staff Data Scientist, Innovation
# Job number  702 added - AI Research Engineer- Remote
# Job number  703 added - Head of Data Science and Analytics
# Job number  704 added - RWE (Real World Evidence)/RWD/HEOR Statistical Analyst
# Job number  705 added - Senior Data Analyst, Growth Marketing
# Job number  706 added - Senior Risk Adjustment Data Analyst 8332 REMOTE
# Job number  707 added - Machine Learning Engineer (Remote)
# Job number  708 added - Senior Data Scientist, Pricing
# Job number  709 added - NLP Applied Scientist
# Job number  710 added - Senior Data Analyst (HEDIS & Performance Specialist)
# Job number  711 added - Machine Learning Engineer
# Job number  712 added - Sr. Fraud Data Analyst
# Job number  713 added - Staff Data Scientist
# Job number  714 added - AI/ML Senior Engineer (Remote)
# Job number  715 added - Machine Learning Engineer
# Job number  716 added - Junior AI/ML Software Developer
# Job number  717 added - Data Scientist
# Job number  718 added - Data Scientist/Software Developer
# Job number  719 added - Senior Data Analyst (Remote)
# Job number  720 added - Data Science Platform Engineer
# Job number  721 added - Sr. Data Scientist - Adtech/Identity (Remote)
# Job number  722 added - Data/Marketing Analyst - AIU (Data Analysis/Data Science, Tableau, Excel, Google Analytics, BigQuery, SQL, Visual Basic, R & Python
# Job number  723 added - Senior Market Data Analyst
# Job number  724 added - Lead ML / AI Data warehouse Engineer
# Job number  725 added - Senior Data Analyst
# Job number  726 added - Product Leader - Banking, Financial Services, Insurance, AI & Data Science
# Job number  727 added - Senior Data Analyst - Remote Eligible
# Job number  728 added - Senior / Staff ML Engineer
# Job number  729 added - Senior Machine Learning Data Scientist
# Job number  730 added - Senior Financial Data Analyst - Health Care Industry
# Job number  731 added - Senior Data Scientist
# Job number  732 added - Senior Healthcare Data Analyst Expert
# Job number  733 added - VP, Software & Data Systems
# Job number  734 added - Bioinformatics Engineer/AWS Data/ data scientist
# Job number  735 added - Senior Data Scientist
# Job number  736 added - Transportation Data Scientist
# Job number  737 added - Senior Data Scientist
# Job number  738 added - Senior Statistician
# Job number  739 added - Staff Machine Learning Engineer
# Job number  740 added - Data Scientist- Application Developer
# Job number  741 added - AI Engineer
# Job number  742 added - Data Scientist
# Job number  743 added - ML Engineer, Reinforcement Learning from Human Feedback - US Remote
# Job number  744 added - Senior Data Analyst
# Job number  745 added - Senior Machine Learning Engineer (Remote)
# Job number  746 added - Data Engineer
# Job number  747 added - Local Data Automation Reporter
# Job number  748 added - ESG Data Scientist
# Job number  749 added - Sr. Principal Data Scientist - Deep Learning - Remote
# Job number  750 added - Senior Statistician- Fully Remote
# Job number  751 added - Healthcare Data Scientist II
# Job number  752 added - Ops Engineer - Machine Learning
# Job number  753 added - Senior Data Scientist
# Job number  754 added - Data Scientist III
# Job number  755 added - Principal Data Scientist
# Job number  756 added - Data Engineer
# Job number  757 added - Data Scientist
# Job number  758 added - Sr. Data Analyst (Remote Possible)
# Job number  759 added - Senior Data Analyst (Remote)
# Job number  760 added - Director, Machine Learning & Analytics Platform Architecture
# Job number  761 added - Machine Learning Ops Engineer-Data Scientist
# Job number  762 added - Lead Machine Learning Engineer
# Job number  763 added - Data Scientist/Sr. Data Scientist
# Job number  764 added - Lead Data Scientist
# Job number  765 added - Data Scientist II, Sr or Lead - Remote GA, FL, SC, AL, TN
# Job number  766 added - Senior Data Scientist, Merch Analytics - Remote
# Job number  767 added - Machine Learning Engineer
# Job number  768 added - Senior Data Scientist | Remote-US
# Job number  769 added - Staff Software Engineer, AI
# Job number  770 added - Senior Data Analyst
# Job number  771 added - Statistician
# Job number  772 added - Conversational AI Design Specialist, NLP/NLU *REMOTE*
# Job number  773 added - Machine Learning Engineer
# Job number  774 added - Damage Detection Machine Learning Engineer
# Job number  775 added - Data Scientist I
# Job number  776 added - Senior Data Analyst
# Job number  777 added - Principal Data Scientist I (Remote)
# Job number  778 added - Senior Research Scientist, Real World Evidence, Data Analytics & Evidence Synthesis
# Job number  779 added - Staff Data Scientist, Analytics
# Job number  780 added - Data Science, Inventory Planning Sr. Manager
# Job number  781 added - Principal Data Scientist
# Job number  782 added - Sr. Data Scientist - Machine Learning
# Job number  783 added - 100% Remote Cloud Engineer (Python, AWS, AI/ML)
# Job number  784 added - Sr. Data Analyst (Partner Analytics)
# Job number  785 added - Senior Staff Data Scientist
# Job number  786 added - Customer Data Owner
# Job number  787 added - Associate Director, Data Engineering (Remote)
# Job number  788 added - Director of Data Science
# Job number  789 added - Statistical Programmer
# Job number  790 added - Data Engineer
# Job number  791 added - Data Science Marketing Specialist
# Job number  792 added - Manager, Project Management (Data Science)
# Job number  793 added - AI/ML Infrastructure Engineer
# Job number  794 added - Principal Machine Learning Engineer
# Job number  795 added - eComm Principal Data Scientist
# Job number  796 added - Data Scientist
# Job number  797 added - Senior Data Analyst
# Job number  798 added - Oracle FAW (Fusion Analytics Warehouse) Developer-Consultant
# Job number  799 added - Deep Learning Engineer
# Job number  800 added - Senior Data Engineer
# Job number  801 added - Data Architect
# Job number  802 added - Senior Data Scientist
# Job number  803 added - Sr. AI Developer
# Job number  804 added - Product Management Lead - Ad Delivery & Decision Science
# Job number  805 added - Senior Data Scientist (US East Coast)
# Job number  806 added - Sr. Data Engineer (Data Analytics & AI)
# Job number  807 added - Sr. Data Analyst
# Job number  808 added - Data Scientist (Remote in Texas)
# Job number  809 added - Senior Quantitative Analyst - Artificial Intelligence/Machine Learning Expert - Minneapolis or Remote
# Job number  810 added - AI Engineer
# Job number  811 added - Director - Data Science (Remote)
# Job number  812 added - Machine Learning Research Team Lead
# Job number  813 added - AWS Serverless Python AI Software Engineer
# Job number  814 added - Product Owner - Federated Customer Data Management
# Job number  815 added - Sr. Data Analyst
# Job number  816 added - HR Data Analyst - Remote
# Job number  817 added - Senior Data Scientist
# Job number  818 added - Data Scientist - Ads (Senior / Staff)
# Job number  819 added - Senior Associate, Digital Data Analyst/Architect
# Job number  820 added - Research Software Engineer, Data Science
# Job number  821 added - Geospatial Machine Learning Software Develope
# Job number  822 added - Senior Data Analyst
# Job number  823 added - Data Analyst - Senior Data Analyst
# Job number  824 added - Machine Learning Engineer - Information Retrieval
# Job number  825 added - Sr. Data Scientist
# Job number  826 added - Senior Data Analyst
# Job number  827 added - Data Scientist and Analytics Manager (Beverly, MA or 100% Remote)
# Job number  828 added - AI Software Engineer
# Job number  829 added - Data Science Engineer
# Job number  830 added - Machine Learning Engineer
# Job number  831 added - Manager, Data Science
# Job number  832 added - Director, Data Science - Remote U.S.
# Job number  833 added - Data Technician
# Job number  834 added - Research Scientist, Artificial intelligence in drug discovery
# Job number  835 added - Senior Staff Data Scientist
# Job number  836 added - Machine Learning Solutions Engineer
# Job number  837 added - Healthcare Solutions Lead, AI & NLP
# Job number  838 added - Conversational AI Design Specialist, NLP/NLU (REMOTE)
# Job number  839 added - Senior Statistician - Remote
# Job number  840 added - Senior Data Scientist
# Job number  841 added - Senior Data Analyst
# Job number  842 added - Lead Data Scientist, Real Estate
# Job number  843 added - Sr. Data Science Manager
# Job number  844 added - Sr. Data Analyst
# Job number  845 added - Sr Ecommerce Data Analyst
# Job number  846 added - AI Scientist, Deep Learning
# Job number  847 added - Machine Learning Engineer
# Job number  848 added - ML Engineer
# Job number  849 added - Study Lead Statistician
# Job number  850 added - Senior Marketing Data Analyst
# Job number  851 added - Machine Learning Engineer
# Job number  852 added - Senior Business Data Analyst (REMOTE)
# Job number  853 added - Director, Data Science (Remote)
# Job number  854 added - Director, Decision Science - Claim Analytic Insights
# Job number  855 added - Senior Data Analyst - Finance
# Job number  856 added - Machine Learning Engineer
# Job number  857 added - Data Scientist
# Job number  858 added - Senior Data Analyst
# Job number  859 added - AI Interactions Engineer (Remote)
# Job number  860 added - Statistician III
# Job number  861 added - Consulting Statistician
# Job number  862 added - Senior Data Analyst II (Remote)
# Job number  863 added - Sr. Data Scientist, Analytics
# Job number  864 added - Senior Data Scientist, NLP
# Job number  865 added - Machine Learning Engineer
# Job number  866 added - Mid-Level Data Scientist
# Job number  867 added - Data Scientist
# Job number  868 added - Data Engineer
# Job number  869 added - Test Data Engineer Consultant (REMOTE)
# Job number  870 added - Sr Data Analyst
# Job number  871 added - NLP Scientist
# Job number  872 added - Data Science Manager
# Job number  873 added - Senior Data Analyst
# Job number  874 added - Data Scientist III Supervisor
# Job number  875 added - Statistical Programmer
# Job number  876 added - Decision Scientist
# Job number  877 added - Data Science Manager
# Job number  878 added - Senior Data Analyst
# Job number  879 added - Statistician - Clinical Trials
# Job number  880 added - CORP - Data Science Manager (Remote Okay)
# Job number  881 added - Senior Data Analyst
# Job number  882 added - Lead Data Scientist II
# Job number  883 added - Senior AI Data Engineer
# Job number  884 added - Manager, Data Science & Machine Learning
# Job number  885 added - Senior Software Engineer, AI Products
# Job number  886 added - Senior Data Engineer (REMOTE)
# Job number  887 added - Senior Staff Software Engineer, Machine Learning Infrastructure [Remote Friendly]
# Job number  888 added - Senior Data Scientist
# Job number  889 added - Architect, Data Science, Field CTO Office
# Job number  890 added - Senior Machine Learning Engineer
# Job number  891 added - Senior Data Analyst
# Job number  892 added - Principal Data Scientist - VIRTUAL!
# Job number  893 added - Data Science Fraud Manager
# Job number  894 added - Lead ML / AI Datawarehouse Engineer (AI, SQL Scripting)
# Job number  895 added - Principal Data Scientist
# Job number  896 added - Senior Data Scientist, Business Intelligence
# Job number  897 added - Data Scientist 4 - 127300
# Job number  898 added - Sr Technical Manager-ML/AI/Data Science
# Job number  899 added - Senior Advisor, Data Science (REMOTE)
# Job number  900 added - Senior Machine Learning Operations Engineer (Remote)

# %% [markdown]
# ### Scrape full job descriptions

# %%
Links_list = dataframe['Links'].tolist()

import random

async def get_description(urls):
  descriptions = []
  async with get_session(Geckodriver(binary=driver_path, log_file=asyncio.subprocess.PIPE), Firefox(**options)) as session:
    for url in urls:
      await session.get("https://www.indeed.com"+url)
      time.sleep(1) #adding a one-second delay
      jd = await session.get_element('#jobDescriptionText')
      descriptions.append(await jd.get_text())
      await asyncio.sleep(random.random() * 1.5)
  return descriptions

## Number of browser instances to use
n = 3

tasks = [asyncio.create_task(get_description(urls)) for urls in np.array_split(Links_list, n)]
dataframe['Descriptions'] = [desc for task in tasks for desc in await task]

# %% [markdown]
# ### Save results

# %%
# Convert the dataframe to a csv file
date = datetime.today().strftime('%Y-%m-%d')
dataframe.to_csv(date + "_" + position + "_" + locations + ".csv", index=False)

# %%
dataframe
# Out:
#                                                  Title  \
# 0        Associate Data Scientist - Rotational Program
# 1                                 Data Scientist - RWD
# 2                                   Jr. Data Scientist
# 3                                       Data Scientist
# 4      Interdisciplinary-Microbiologist/Data Scientist
# ..                                                 ...
# 895  Job Title: ML Engineer Job Location: Remote Jo...
# 896    Machine Learning Engineer: Recall Team (Remote)
# 897  Senior Research Scientist/Director - Epidemiol...
# 898           Senior Data Scientist, Product Analytics
# 899          Senior Data Engineering Manager (Level V)
#
#                            Company                        Location Rating  \
# 0                  Mutual of Omaha                          Remote    3.7
# 1                        Norstella                          Remote    NaN
# 2                       Net2Aspire                          Remote    NaN
# 3                Synchrony Systems                          Remote    NaN
# 4                             USDA                          Remote    4.1
# ..                             ...                             ...    ...
# 895  Global Information Technology  Remote in Southfield, MI 48076    4.1
# 896                    Constructor                          Remote    4.3
# 897       Thermo Fisher Scientific        Remote in Wilmington, NC    3.5
# 898                      Coalition            Remote in Austin, TX    NaN
# 899                        BENlabs             Remote in Provo, UT    NaN
#
#                           Date                      Salary  \
# 0                  PostedToday   $72,000 - $114,000 a year
# 1    EmployerActive 7 days ago  $125,000 - $175,000 a year
# 2    EmployerActive 5 days ago    $65,000 - $80,000 a year
# 3                  PostedToday           $70 - $75 an hour
# 4     EmployerActive 1 day ago   $98,496 - $158,432 a year
# ..                         ...                         ...
# 895  PostedPosted 30+ days ago                         NaN
# 896  PostedPosted 30+ days ago                         NaN
# 897    PostedPosted 6 days ago                         NaN
# 898  PostedPosted 30+ days ago                         NaN
# 899   PostedPosted 25 days ago  $195,000 - $215,000 a year
#
#                                            Description  \
# 0    The program lets the associate data scientists...
# 1    Design data pipelines and queries and analyze ...
# 2     Create data dashboards and other data visual...
# 3    Must have strong data visualization skills.\nP...
# 4    Analyzing data provided by NAHLN laboratories ...
# ..                                                 ...
# 895  Job Description: Work closely with Tech Anchor...
# 896  About us Constructor.io powers product search ...
# 897  At Thermo Fisher Scientific, you’ll discover m...
# 898  Lead cross-functional projects using quantitat...
# 899  You also have the desire to work closely with ...
#
#                                                  Links  \
# 0    /rc/clk?jk=20c8f542b3f17ed7&fccid=7f07a4e82fbe...
# 1    /company/NorStella/jobs/Data-Scientist-98a669a...
# 2    /company/net2aspire/jobs/Junior-Data-Scientist...
# 3    /company/Synchrony-Systems/jobs/Data-Scientist...
# 4    /company/US-Department-of-Agriculture/jobs/Int...
# ..                                                 ...
# 895  /rc/clk?jk=efc9366f75880b50&fccid=e23935f4162c...
# 896  /rc/clk?jk=277d4ed20b74f7f9&fccid=546a4f6b509c...
# 897  /rc/clk?jk=047ce743223110a7&fccid=126e3afd205c...
# 898  /rc/clk?jk=8fe89543d44ab679&fccid=5da39dba7be7...
# 899  /rc/clk?jk=44f338e2cdde900a&fccid=3a67c6225dc8...
#
#                                           Descriptions
# 0    Location: Various Locations\nWork Type: Full T...
# 1    Job Summary:\nWe are seeking an experienced Da...
# 2     Apply Statistical and Machine Learning metho...
# 3    Role: Data Scientist\nLocation: REMOTE\nJob De...
# 4    MUST APPLY ON USAJOBS - https://www.usajobs.go...
# ..                                                 ...
# 895  Job Description:\nWork closely with Tech Ancho...
# 896  About us\nConstructor.io powers product search...
# 897  At Thermo Fisher Scientific, you’ll discover m...
# 898  About Us\nFounded in 2017, Coalition combines ...
# 899  Who WE Are\nBENlabs connects global brands to ...
#
# [900 rows x 9 columns]
