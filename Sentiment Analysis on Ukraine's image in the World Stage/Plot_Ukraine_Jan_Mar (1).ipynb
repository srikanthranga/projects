# %% [markdown]
# # **Imports and Installs**

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
#import preprocessor as p
import re
import warnings
warnings.filterwarnings("ignore")
from bs4 import BeautifulSoup
import string
import html
import requests
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
import nltk
from nltk import word_tokenize, FreqDist
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords
nltk.download
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('vader_lexicon')
nltk.download('punkt')
from nltk.tokenize import TweetTokenizer
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
import os
import pickle
from sklearn.metrics import classification_report, accuracy_score
from google.colab import files
import io
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# !pip install preprocessor
# !pip install bertopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting preprocessor
#   Downloading preprocessor-1.1.3.tar.gz (4.2 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: preprocessor
#   Building wheel for preprocessor (setup.py) ... done
#   Created wheel for preprocessor: filename=preprocessor-1.1.3-py3-none-any.whl size=4473 sha256=07ac72d1981710e0b790d7dbf4f6f1ac9034e2da20bc749cbe99c230adcfafa6
#   Stored in directory: /root/.cache/pip/wheels/18/41/3e/30e0c08b0759166f31aee174d58d288ad5c277bd102c8ad869
# Successfully built preprocessor
# Installing collected packages: preprocessor
# Successfully installed preprocessor-1.1.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bertopic
#   Downloading bertopic-0.14.1-py2.py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 KB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (5.13.1)
# Collecting hdbscan>=0.8.29
#   Downloading hdbscan-0.8.29.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 22.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.4.4)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (4.65.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.2.2)
# Collecting umap-learn>=0.5.0
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 10.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sentence-transformers>=0.4.1
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 11.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (1.1.1)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.33)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (1.10.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=4.7.0->bertopic) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 36.5 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (1.13.1+cu116)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.14.1+cu116)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 26.6 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.9/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.10.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (23.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.27.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (67.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 23.1 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.10.31)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (8.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.26.15)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp39-cp39-linux_x86_64.whl size=3582088 sha256=66629f7f6f8d64851c559fc2fdde7978826316cbffd2673d689de4068f757db7
#   Stored in directory: /root/.cache/pip/wheels/05/6f/88/1a4c04276b98306f00217a1e300e6ba0252c6aa4f7616067ae
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125942 sha256=23a55a618bdba4e2f513d59ed9bcd5ce214a7c8f01bcc6ddb73790d7f6be88f9
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82830 sha256=0606cd13cb56c1d919cdb878a28ebe4f911d7f4db545787800c0e3f65c5ff50a
#   Stored in directory: /root/.cache/pip/wheels/f4/3e/1c/596d0a463d17475af648688443fa4846fef624d1390339e7e9
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55509 sha256=7f8d2b7693349f091e2f60a44b71d205738bf6bb7c451b9355319eca1f6990cc
#   Stored in directory: /root/.cache/pip/wheels/b9/89/cc/59ab91ef5b21dc2ab3635528d7d227f49dfc9169905dcb959d
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: tokenizers, sentencepiece, huggingface-hub, transformers, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
# Successfully installed bertopic-0.14.1 hdbscan-0.8.29 huggingface-hub-0.13.3 pynndescent-0.5.8 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.13.2 transformers-4.27.4 umap-learn-0.5.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Tweet Preprocessing**

# %%
df_ukraine_jan = pd.read_csv("/content/drive/MyDrive/Datasets/tweet_ukraine_jan.csv")
df_ukraine_feb = pd.read_csv("/content/drive/MyDrive/Datasets/tweet_ukraine_feb.csv")
df_ukraine_mar = pd.read_csv("/content/drive/MyDrive/Datasets/tweet_ukraine_apr.csv")

# %%
col = ["Unnamed:0", "ID", "Date", "Tweet"]
df_ukraine = pd.DataFrame(columns=col)

df_ukraine = pd.concat([df_ukraine, df_ukraine_jan])
df_ukraine = pd.concat([df_ukraine, df_ukraine_feb])
df_ukraine = pd.concat([df_ukraine, df_ukraine_mar])

# %%
def clean_text(_sentence):

    #removes emojis, pictographs, map symbols and flags
    emoji_pattern = re.compile(pattern = "["
          u"\U0001F600-\U0001F64F" 
          u"\U0001F300-\U0001F5FF" 
          u"\U0001F680-\U0001F6FF" 
          u"\U0001F1E0-\U0001F1FF" 
                            "]+", flags = re.UNICODE)
    _sentence = emoji_pattern.sub(r'',_sentence)

    #emoves tags and attributes
    _sentence = re.sub('(<[^>]*>)','',_sentence)

    #converts character code to string
    _sentence = html.unescape(_sentence)

    #removes urls
    _sentence = re.sub("(\w+:\/\/\S+)|(http[^\s]+)|(www.[^\s]+)",'',_sentence, flags=re.MULTILINE)
    
    #removes RT
    _sentence = re.sub("RT",'',_sentence)
    
    #converts the sentence to a lower case
    _sentence = _sentence.lower()

    #removes punctuation
    _sentence = re.sub(r'\@\w+|\#\w+','', _sentence)
    _sentence = _sentence.translate(str.maketrans('', '', (string.punctuation)))
    
    #checks for stop words
    stop_words = set(stopwords.words('english'))
    _sentence = [word for word in str(_sentence).split() if word not in stop_words]

    #joins the word and returns a sentence
    return " ".join(_sentence)

#function to preprocess tweets
def preprocess_tweets(tweets_df,column):

    #apply clean text in a vectorized format
    vfunc_clean_text = np.vectorize(clean_text)
    tweets_df[column] = vfunc_clean_text(tweets_df[column]) #create a new column that consists of preprocessed tweets
    
    return tweets_df

# %%
df_ukraine.drop_duplicates(subset=["Tweet"],keep='first',inplace=False,ignore_index=True)
# Out:
#        Unnamed:0                   ID                       Date  \
# 0            NaN  1609317246685384704  2022-12-31 22:35:05+00:00
# 1            NaN  1609317246416961536  2022-12-31 22:35:05+00:00
# 2            NaN  1609317250061697025  2022-12-31 22:35:06+00:00
# 3            NaN  1609317264783728640  2022-12-31 22:35:10+00:00
# 4            NaN  1609317275714174980  2022-12-31 22:35:12+00:00
# ...          ...                  ...                        ...
# 487034       NaN  1640908291533422592  2023-03-29 02:46:37+00:00
# 487035       NaN  1640908302946299906  2023-03-29 02:46:40+00:00
# 487036       NaN  1640908313800966146  2023-03-29 02:46:43+00:00
# 487037       NaN  1640908322059735041  2023-03-29 02:46:45+00:00
# 487038       NaN  1640908337360379907  2023-03-29 02:46:48+00:00
#
#                                                     Tweet  Unnamed: 0
# 0       @BGRnl1 @IsraeliPM and in Russia's mind Ukrain...      5498.0
# 1       Russia’s invasion of its neighbour Ukraine unl...      5499.0
# 2       Happy New Year everyone!! May peace conquer 20...      5497.0
# 3       Ukraine conflict casts shadow on Russia as it ...      5496.0
# 4       The Russian president Vladimir Putin was likel...      5495.0
# ...                                                   ...         ...
# 487034  Blinken Backs Ukraine’s Peace Proposal, Warns ...    165004.0
# 487035  @cwebbonline @RyanPinesworth Listen to Marjori...    165003.0
# 487036  We were the laughing stock of the world becaus...    165002.0
# 487037  @HarryTHop @Kanthan2030 To use Washingtonian l...    165001.0
# 487038  Ukraine war: Russia fails at UN to get Nord St...    165000.0
#
# [487039 rows x 5 columns]

# %%
ukraine_df = preprocess_tweets(df_ukraine,'Tweet')

# %% [markdown]
# # **Logistic Regression Model Training**

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/sentiment_analysis.csv")
df = df.drop(['ID'], axis=1)
df.head()
# Out:
#                                                 text  label
# 0  Josh Jenkins is looking forward to TAB Breeder...      1
# 1  RT @MianUsmanJaved: Congratulations Pakistan o...      1
# 2  RT @PEPalerts: This September, @YESmag is taki...      1
# 3  RT @david_gaibis: Newly painted walls, thanks ...      1
# 4  RT @CedricFeschotte: Excited to announce: as o...      1

# %%
df = preprocess_tweets(df,'text')

# %%
X = df.loc[:, ['text']]
y = df['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=1)

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer()
bag = count.fit_transform(X_train['text'].tolist())

# %%
import numpy as np

from sklearn.feature_extraction.text import TfidfTransformer

tfidf = TfidfTransformer(use_idf=True,
                         norm='l2',
                         smooth_idf=True)

np.set_printoptions(precision=2)

# %%
from collections import Counter

vocab = Counter()
for twit in X_train.text:
    for word in twit.split(' '):
        vocab[word] += 1

vocab.most_common(20)
# Out:
# [('love', 42385),
#  ('happy', 40825),
#  ('great', 23262),
#  ('good', 21919),
#  ('im', 20543),
#  ('best', 20086),
#  ('amazing', 19574),
#  ('day', 18533),
#  ('birthday', 17562),
#  ('one', 13723),
#  ('thank', 13584),
#  ('found', 13340),
#  ('dont', 12588),
#  ('like', 12383),
#  ('beautiful', 12258),
#  ('transponder', 11427),
#  ('much', 11133),
#  ('get', 10924),
#  ('today', 10857),
#  ('cant', 10325)]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()

# %%
import math

def plot_distribution(vocabulary):

    hist, edges = np.histogram(list(map(lambda x:math.log(x[1]),vocabulary.most_common())), density=True, bins=500)

    p = figure(tools="pan,wheel_zoom,reset,save",
               toolbar_location="above",
               title="Word distribution accross all twits")
    p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555", )
    show(p)

plot_distribution(vocab)
# Out:
#   <div class="bk-root" id="024eed4f-87bc-4f6b-a463-85e280d55e15" data-root-id="1002"></div>

# %%
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')

vocab_reduced = Counter()
for w, c in vocab.items():
    if not w in stop:
        vocab_reduced[w]=c

vocab_reduced.most_common(20)

plot_distribution(vocab_reduced)
# Out:
#   <div class="bk-root" id="783fd7e7-e9a8-47a7-b611-02b0d433459a" data-root-id="1090"></div>

# %%
from nltk.stem import PorterStemmer

porter = PorterStemmer()

def tokenizer(text):
    return text.split()

def tokenizer_porter(text):
    return [porter.stem(word) for word in text.split()]

# %%
# Best parameters
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(strip_accents=None,
                        lowercase=False,
                        preprocessor=None)


param_grid = [{'vect__ngram_range': [(1, 1)],
               'vect__tokenizer': [tokenizer],
               'clf__penalty': ['l2'],
               'clf__C': [10.0],
              'clf__solver': ['liblinear'],
              'clf__max_iter': [1000]}
]

lr_tfidf = Pipeline([('vect', tfidf),
                     ('clf', LogisticRegression(random_state=0))])

gs_lr_tfidf = GridSearchCV(lr_tfidf, param_grid,
                           scoring='accuracy',
                           cv=5,
                           verbose=1)

# %%
# Note: This process took 25 hours
gs_lr_tfidf.fit(X_train.values.ravel(), y_train.values.ravel())
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('vect',
#                                         TfidfVectorizer(lowercase=False)),
#                                        ('clf',
#                                         LogisticRegression(random_state=0))]),
#              param_grid=[{'clf__C': [10.0], 'clf__max_iter': [1000],
#                           'clf__penalty': ['l2'], 'clf__solver': ['liblinear'],
#                           'vect__ngram_range': [(1, 1)],
#                           'vect__tokenizer': [<function tokenizer at 0x7fea4cddf430>]}],
#              scoring='accuracy', verbose=1)

# %%
#print('Best parameter set: ' + str(gs_lr_tfidf.best_params_))
print('Best accuracy: %.3f' % gs_lr_tfidf.best_score_)
# Out:
# Best accuracy: 0.974

# %%
clf = gs_lr_tfidf.best_estimator_
#clf.fit(X_train.values, y_train)
clf.fit(X_test['text'].tolist(), y_test)
print('Accuracy in test: %.3f' % clf.score(X_test['text'].tolist(), y_test))
# Out:
# Accuracy in test: 0.992

# %% [markdown]
# # **Vader**

# %%
def Vader_process(data_df):
    sid = SentimentIntensityAnalyzer()
    res = [*data_df['Tweet'].apply(sid.polarity_scores)]
    #print(res[:3])

    sentiment_df = pd.DataFrame.from_records(res)
    data_df = pd.concat([data_df.reset_index(drop=True), sentiment_df.reset_index(drop=True)], axis=1, join="inner")
    #print(data_df.head())
    
    conditions = [
    (data_df['compound'] <= -0.5),
    (data_df['compound'] > -0.5) & (data_df['compound'] < 0.5),
    (data_df['compound'] >= 0.5)
    ]

    values = [0, -1, 1]
    senti=['negative','neutral','positive']
    data_df['sentiment']=np.select(conditions,senti)
    data_df['label']=np.select(conditions,values)

    #print(data_df.head())
    
    X_df = data_df[data_df.label != -1]
    X_df = X_df[['Tweet','label']]
    #print(X_df.head())
    
    return X_df,data_df

# %%
X_ukraine,data = Vader_process(ukraine_df)

# %%
X_ukraine
# Out:
#                                                     Tweet  label
# 0       russias mind ukraine chose war go okay russia ...      0
# 1       russia’s invasion neighbour ukraine unleashed ...      0
# 2       happy new year everyone may peace conquer 2023...      1
# 4       russian president vladimir putin likely influe...      0
# 5              wish ukraine victory evil russia collapses      0
# ...                                                   ...    ...
# 494989                         ukraine flag top page lmao      1
# 494990  don’t understand people hate ukraine supposed ...      0
# 494997  laughing stock world man supporters people lef...      1
# 494998  use washingtonian logic russia attacking ukrai...      0
# 494999  ukraine war russia fails un get nord stream bl...      0
#
# [209799 rows x 2 columns]

# %%
x=data.groupby('sentiment').size()
x.plot.pie(title="#putin Tweets Sentiment Distribution May - Jul 22",autopct='%1.1f%%')
# Out:
# <Axes: title={'center': '#putin\xa0Tweets\xa0Sentiment\xa0Distribution\xa0May\xa0-\xa0Jul\xa022'}, ylabel='None'>

# %%
data['Date']=pd.to_datetime(data['Date'])
data.set_index('Date',inplace=True)
freq_per_month=data.groupby(pd.Grouper(freq='D'))['sentiment'].value_counts()
freq_per_month=freq_per_month.unstack(level='sentiment')
freq_per_month.plot(kind='line',figsize=(8,6),title='Frequency of Sentiment per Month')
# Out:
# <Axes: title={'center': 'Frequency\xa0of\xa0Sentiment\xa0per\xa0Month'}, xlabel='Date'>

# %% [markdown]
# # **Logistic regression for predicting labels**

# %%
X_ukraine['Predicted Label'] = clf.predict(X_ukraine['Tweet'])

# %%
print("Report for Tweets with Putin Jan to March")
print(classification_report(X_ukraine['label'],X_ukraine['Predicted Label']))
# Out:
# Report for Tweets with Putin Jan to March
#               precision    recall  f1-score   support
#
#            0       0.76      0.98      0.86    130742
#            1       0.94      0.49      0.64     79057
#
#     accuracy                           0.80    209799
#    macro avg       0.85      0.74      0.75    209799
# weighted avg       0.83      0.80      0.78    209799

# %% [markdown]
# # **BERTopic Modelling**

# %%
import nltk
from nltk.corpus import stopwords
from umap import UMAP
from bertopic import BERTopic

# %%
umap_model = UMAP(random_state=3231)
bert_topic_model= BERTopic(embedding_model = "all-MiniLM-L6-v2", umap_model=umap_model)

bert_negative = X_ukraine[X_ukraine['label']==0] #change this to 1 if positive. keep 0 if negative.
bert_negative = bert_negative.Tweet.tolist()
topics, probs = bert_topic_model.fit_transform(bert_negative)

# %%
pd.set_option('display.max_rows', None)

# %%
topic_list=bert_topic_model.get_topic_info()
topic_list
# Out:
#       Topic  Count                                               Name
# 0        -1  60249                        -1_biden_trump_putin_russia
# 1         0   3656                        0_money_tax_dollars_billion
# 2         1   3095                           1_nato_natos_join_member
# 3         2   1194                     2_tanks_leopard_germany_abrams
# 4         3   1004                          3_china_chinese_chinas_xi
# 5         4    993                           4_flag_flags_profile_bio
# 6         5    959                      5_nuclear_nukes_nuke_tactical
# 7         6    939                      6_video_videos_footage_photos
# 8         7    809                    7_laundering_scheme_audit_fraud
# 9         8    733            8_zelensky_zelenskyy_zelenskys_zelenski
# 10        9    693                      9_weapons_weapon_sending_arms
# 11       10    688                         10_guns_gun_schools_school
# 12       11    674                     11_twitter_tweet_trolls_tweets
# 13       12    545                       12_bakhmut_city_battle_rages
# 14       13    507       13_israel_palestinians_palestine_palestinian
# 15       14    497                    14_crimes_hague_committed_crime
# 16       15    466                     15_2023_2022_february_nintendo
# 17       16    432              16_wagner_group_prigozhin_mercenaries
# 18       17    427          17_corruption_corrupt_manufacturers_index
# 19       18    425                  18_taiwan_china_taiwanese_chinese
# 20       19    396                   19_proxy_proxies_usrussia_waging
# 21       20    390               20_canada_trudeau_canadians_canadian
# 22       21    385                  21_fascist_fascists_fascism_nazis
# 23       22    382                           22_prices_gas_oil_energy
# 24       23    382                   23_brexit_covid_climate_pandemic
# 25       24    377              24_church_orthodox_christian_churches
# 26       25    368                 25_ruzzia_ruzzian_ruzzians_ruzzias
# 27       26    356                                26_fuck_wtf_fu_shit
# 28       27    344                     27_labs_biolabs_bio_biological
# 29       28    336                    28_kids_sons_daughters_children
# 30       29    329                         29_drone_drones_downed_sea
# 31       30    327                       30_starlink_musk_elon_spacex
# 32       31    308          31_protest_protests_protesters_protesting
# 33       32    301         32_belarus_moldova_transnistria_lukashenko
# 34       33    271                      33_inflation_rates_gas_prices
# 35       34    265                           34_coup_2014_elected_cia
# 36       35    265            35_propaganda_media_coverage_mainstream
# 37       36    260                  36_ohio_disaster_train_derailment
# 38       37    248         37_vaccine_vaccines_vaccination_vaccinated
# 39       38    238                           38_end_ends_pluto_ending
# 40       39    238                     39_debt_ceiling_limit_trillion
# 41       40    235                40_desantis_ron_dispute_territorial
# 42       41    231                         41_biden_joe_bidens_caused
# 43       42    228                     42_activist_loud_illegal_quiet
# 44       43    226                 43_uranium_depleted_shells_defects
# 45       44    223                 44_minsk_merkel_accords_agreements
# 46       45    221                   45_athletes_olympics_ioc_olympic
# 47       46    219              46_warrant_arrest_court_international
# 48       47    219  47_russiaukraine_russianukraine_russoukraine_l...
# 49       48    218                        48_irgc_terrorist_iran_list
# 50       49    217                  49_pipeline_nord_stream_pipelines
# 51       50    212                  50_chemical_using_warfare_weapons
# 52       51    208                  51_losses_lost_escaped_casualties
# 53       52    196                52_freezing_rtd_dominoes_directions
# 54       53    195              53_children_kidnapped_kids_kidnapping
# 55       54    194          54_armored_howitzer_selfpropelled_brigade
# 56       55    192                   55_poland_polands_polish_baltics
# 57       56    190                         56_gay_lgbtq_lgbt_marriage
# 58       57    180                  57_dnipro_apartment_missile_block
# 59       58    176                         58_fuck_allens_brice_wings
# 60       59    172                          59_sirens_s300_air_flight
# 61       60    165                  60_refugees_ireland_irish_seekers
# 62       61    165               61_mccarthy_kevin_speaker_invitation
# 63       62    161                         62_ru_ua_retweet_positions
# 64       63    160                    63_mexico_cartels_mexican_texas
# 65       64    159              64_helicopter_interior_crash_minister
# 66       65    157                    65_vs_guerre_belligerents_spade
# 67       66    147                        66_grain_food_wheat_farmers
# 68       67    142             67_slava_conscription_peremoha_heroyam
# 69       68    141              68_documents_classified_hunter_family
# 70       69    140   69_negotiate_negotiations_negotiated_negotiation
# 71       70    139                  70_uit_stops_strategy_intervening
# 72       71    139                       71_icc_warrant_arrest_issues
# 73       72    137             72_information_daily_february_thursday
# 74       73    137                       73_hate_hating_dwellers_wink
# 75       74    134             74_homeless_homelessness_veterans_vets
# 76       75    134                             75_lying_lie_lied_lies
# 77       76    129                    76_reparations_pay_pays_damages
# 78       77    128                        77_lying_liar_krystal_liars
# 79       78    128                  78_fentanyl_border_cartel_cartels
# 80       79    127                     79_racist_racism_black_racists
# 81       80    127                    80_soledar_soledars_fierce_town
# 82       81    126                  81_tucker_carlson_autistic_greene
# 83       82    124         82_zelensky_zelenskyy_zelesky_facilitating
# 84       83    124        83_chelsea_warmongers_distraction_warmonger
# 85       84    123              84_christmas_ceasefire_truce_orthodox
# 86       85    122                       85_logic_its_invaded_started
# 87       86    122                   86_scam_scammers_footysummer_ypb
# 88       87    122                         87_ends_leaves_stops_quits
# 89       88    122             88_hypersonic_kinzhal_missiles_barrage
# 90       89    121                   89_trump_president_donald_wouldn
# 91       90    120                   90_winter_conscripts_losses_oryx
# 92       91    119                  91_donbass_donbas_civilians_14000
# 93       92    116                         92_women_men_feminist_male
# 94       93    116                       93_clown_clowns_rat_symoneko
# 95       94    115                       94_biden_zellenskyy_weak_joe
# 96       95    114                          95_india_korea_north_modi
# 97       96    112                     96_torture_tortured_camps_pows
# 98       97    112               97_paying_pay_multibilliondollar_gdp
# 99       98    106            98_turncoat_conspiracy_republicans_lied
# 100      99    106                  99_torture_rape_violations_rights
# 101     100    105             100_indecision_killing_vanish_murdered
# 102     101    103                 101_cuba_cuban_memorandum_budapest
# 103     102    103                 102_language_fascist_toolkit_nazis
# 104     103    102            103_invaided_developers_gaulle_hegemony
# 105     104    102                        104_update_daily_waali_1203
# 106     105    101                         105_fuch_ksa_muster_resign
# 107     106    101                        106_map_updates_marinka_mar
# 108     107    101                107_stealing_launder_cocaine_stolen
# 109     108     99                 108_fronts_according_combat_losses
# 110     109     99                    109_prayers_pray_praying_prayer
# 111     110     98                 110_orcs_orc_moscovian_transnistia
# 112     111     97                      111_63_strike_rubble_building
# 113     112     97             112_helicopters_helicopter_mi24_shoots
# 114     113     96     113_escalation_escalate_escalating_escalations
# 115     114     95              114_training_equipment_logistics_culd
# 116     115     95                  115_strikes_shaffer_launches_tony
# 117     116     94                      116_155_district_jccc_caliber
# 118     117     94                    117_ritter_scott_footag_mayanov
# 119     118     93                          118_hours_24_trump_donald
# 120     119     93                       119_iran_irans_tehran_israel
# 121     120     91                120_stems_ordeal_humiliating_orange
# 122     121     90             121_switzerland_swiss_neutrality_alain
# 123     122     90       122_cyber_cyberattacks_hackers_cybersecurity
# 124     123     90                    123_banks_deficit_bailouts_bank
# 125     124     89           124_terrorist_terrorism_toodeh_kurdsthis
# 126     125     89      125_earthquake_turkey_earthquakes_turkeysyria
# 127     126     86          126_explained_reunites_separated_driscoll
# 128     127     86                127_clock_doomsday_midnight_seconds
# 129     128     84                 128_scholz_olaf_chancellor_scholzs
# 130     129     82                          129_shes_she_miss_reacted
# 131     130     81                    130_updates_live_hotline_update
# 132     131     80           131_putinrussian_ethnic_hypocrisy_slavic
# 133     132     79                      132_losing_lose_georgian_lost
# 134     133     79    133_sanctions_kazakhstani_ricocheted_moskalkova
# 135     134     78                    134_health_2024_election_latest
# 136     135     77                    135_hoc_invade_invading_dispute
# 137     136     76               136_shipwreck_famous_station_mission
# 138     137     74                       137_portlander_pizza_fux_tau
# 139     138     74              138_squabble_civil_homeland_kalinovka
# 140     139     72            139_drones_iranian_iran_iraniandesigned
# 141     140     71                     140_electricity_grid_eve_popik
# 142     141     71                    141_chechnya_georgia_dot_chutes
# 143     142     71                    142_ding_setback_oklahoma_dwarf
# 144     143     71                 143_drone_soilders_footage_graphic
# 145     144     71     144_parasite_collapseusa_afghanistan_equipment
# 146     145     71   145_philosophy_philosophers_20230327_disciplines
# 147     146     70              146_donetsk_civilians_4400_estimation
# 148     147     69                147_syria_libya_afghanistan_chomsky
# 149     148     69                  148_jets_fighter_scuds_production
# 150     149     69                     149_petition_cancer_51st_share
# 151     150     69                150_cize_peterson_convincing_medium
# 152     151     69             151_loopholes_diplomacy_compromise_tin
# 153     152     69                  152_wagner_footage_group_horrible
# 154     153     68                  153_wagner_bakhmut_group_fighters
# 155     154     68                  154_carrier_drone_footage_kherson
# 156     155     67                155_stops_deformed_proletariat_tard
# 157     156     67           156_medvedev_dmitry_apocalypse_threatens
# 158     157     67   157_pedagogy_trackanazimerc_lectures_radicalized
# 159     158     67          158_taliban_afghanistan_hannity_confidant
# 160     159     66                       159_civilians_tbd_1010_songs
# 161     160     66                160_donbass_donbas_shelling_cavalry
# 162     161     66                          161_07_alarming_yards_dec
# 163     162     66       162_unavailable_temporarily_violates_account
# 164     163     66           163_sunflowers_defective_sock_fertilizer
# 165     164     65               164_jewish_jews_supremacists_dempsey
# 166     165     65                      165_ufo_ufos_sightings_aliens
# 167     166     65                  166_daughters_sons_zelenskyy_wasn
# 168     167     65                   167_vietnam_warned_fallacy_nixon
# 169     168     64                     168_dynamo_perplexed_joe_biden
# 170     169     64                 169_antiimperialists_透過_plotas_shi
# 171     170     63       170_genocide_moscowmick_circassian_circassia
# 172     171     62                      171_infrared_haz_destiny_adam
# 173     172     62               172_punk_hurt_insanity_embarrassment
# 174     173     62                     173_macgregor_douglas_col_doug
# 175     174     62              174_daughter_reading_sentenced_aughts
# 176     175     61                    175_graham_lindsey_2017_senator
# 177     176     61         176_fake_geolocationfake_geolocation_faked
# 178     177     61                    177_brutality_ff_sleep_lootings
# 179     178     61        178_surrender_shaping_battleground_corridor
# 180     179     60                    179_dawn_robots_advances_killer
# 181     180     60                180_bradley_avenger_stryker_armored
# 182     181     60             181_antiukraine_blah_neverkevin_greene
# 183     182     60               182_classified_docs_documents_laptop
# 184     183     59              183_navalnyy_bullied_academy_bullying
# 185     184     59                184_coup_libya_directionless_afghan
# 186     185     59                 185_blame_blaming_emboldens_stance
# 187     186     59               186_qualified_namely_mouths_standard
# 188     187     59                            187_helmet_cam_rpg_ural
# 189     188     59                   188_marjorie_taylor_greene_obama
# 190     189     58                    189_patricks_tiktok_st_concerns
# 191     190     58               190_garland_merrick_attorney_attends
# 192     191     58    191_georgia_restraints_westernisation_therecwas
# 193     192     58                      192_wall_border_drug_trailers
# 194     193     58             193_ruscists_butchers_eradicate_filthy
# 195     194     58           194_fouts_perets_ballerinas_connectivity
# 196     195     57             195_obey_україна_supersimple_homeowner
# 197     196     57                         196_losing_lose_lost_norte
# 198     197     57                                197_ist_die_wer_und
# 199     198     57                  198_gopro_brutally_forest_footage
# 200     199     56         199_organization_roles_argentina_condition
# 201     200     55                  200_kosovo_serbia_serbias_serbian
# 202     201     55                      201_smartnews_read_levels_405
# 203     202     55                      202_vatnik_v2_saddens_vatniks
# 204     203     55          203_mercenaries_surpassing_tigray_eritrea
# 205     204     55                204_stalin_starved_holodomor_193233
# 206     205     55               205_poorest_terror_supercell_windsor
# 207     206     54                    206_disgusting_sick_wtf_bonkers
# 208     207     54                    207_def_support_scumbag_terrain
# 209     208     54         208_evil_hostile_chovinistic_informational
# 210     209     54                          209_f16s_f16_ger_hardcore
# 211     210     54                  210_nazi_dresses_lowest_languages
# 212     211     53             211_neonazi_neonazis_exposes_newsnight
# 213     212     53                    212_scam_scams_scammers_scammer
# 214     213     53               213_johnson_boris_potapova_kasatkina
# 215     214     53                          214_loot_liar_lying_fifty
# 216     215     53                 215_180000_wounded_chiefs_casualty
# 217     216     53              216_terrorist_state_extermination_tsu
# 218     217     53        217_ger_punching_neutralitydrunk_kramarenko
# 219     218     52                     218_yemen_saudi_houthis_saudis
# 220     219     51                   219_election_awash_stolen_rigged
# 221     220     51              220_blah_lawsuits_impeachment_cheated
# 222     221     51              221_women_perversions_children_mother
# 223     222     51        222_genocide_congratulating_lymann_wuhledar
# 224     223     51                     223_jinping_xi_settlement_jade
# 225     224     50                           224_pows_poet_pow_seagal
# 226     225     50                 225_kurti_khabib_bullying_organize
# 227     226     50               226_netrebko_comfortable_anna_breath
# 228     227     50                 227_piano_thingthey_loyalists_fail
# 229     228     49   228_seychelles_nationalism_definition_patriotism
# 230     229     49     229_impartiality_behaviour_violates_recognised
# 231     230     49     230_antisemitism_podcast_presidential_concerns
# 232     231     49                    231_upbeat_airsoft_phases_enemy
# 233     232     49                    232_lwnjs_poverty_gvnt_starving
# 234     233     48          233_impatient_shouldve_gambling_freedland
# 235     234     48                    234_petr_merab_antiwar_putinazi
# 236     235     48                   235_mongolia_draw_motion_extends
# 237     236     48                    236_ruf_arrow_missiles_altitude
# 238     237     48                    237_completley_arming_race_arms
# 239     238     48                238_hoorah_marxists_cos_nationalism
# 240     239     48                  239_lula_brazil_brazilian_brazils
# 241     240     48                240_year_saboteurs_crossed_reminder
# 242     241     48               241_anniversary_oneyear_poland_visit
# 243     242     48              242_gods_satans_superstate_ownerships
# 244     243     48                     243_balloon_balloons_shoot_spy
# 245     244     48                      244_blinken_antony_discuss_yi
# 246     245     48                     245_toeveryone_shady_biden_100
# 247     246     48                     246_germany_junior_reveals_gas
# 248     247     48               247_pences_laundering_morals_robbing
# 249     248     47                 248_uchicago_posters_kgb_bonaparte
# 250     249     47                249_evading_partys_rino_ukrainefrom
# 251     250     47              250_landbridge_stops_dragged_chrisean
# 252     251     47                        251_ambush_560_elite_wagner
# 253     252     47        252_changed_forever_kennan_russiainstigated
# 254     253     47             253_meaningful_cmd_maladventure_jstars
# 255     254     47                  254_prison_sing_crackhead_maximun
# 256     255     46                    255_false_flag_accuses_planning
# 257     256     46         256_fail_zionistsisraelis_noes_recapturing
# 258     257     46      257_civil_secession_lutherans_kremlindirected
# 259     258     46                     258_animals_mental_animal_bice
# 260     259     46                      259_pilots_a10s_jets_airspace
# 261     260     46           260_liberalism_simulation_leftist_fooles
# 262     261     46    261_annexationthe_syndromes_institutes_slouches
# 263     262     46        262_exchange_prisoner_journalists_exchanged
# 264     263     46                   263_map_maps_08jan2023_14feb2023
# 265     264     46                264_polemic_1784_crimeans_discourse
# 266     265     45            265_hungarian_volunteer_minority_šandor
# 267     266     45                  266_warn_chiefs_drags_radioactive
# 268     267     45                      267_affiliated_truth_fox_lies
# 269     268     45               268_natlists_lessons_reaction_sesmic
# 270     269     45                       269_student_loan_debt_cancel
# 271     270     45               270_staed_proves_mtg_reprobertgarcia
# 272     271     45             271_clancy_dearest_defecting_dissident
# 273     272     45                 272_strife_bugs_zelly_scrutinising
# 274     273     45            273_production_glsdb_innovation_produce
# 275     274     45  274_preferred_ukriane_proendless_authoritarian...
# 276     275     45                  275_west_jaishankar_handled_whyas
# 277     276     45            276_zelensky_13715_zelenskys_zelenskiys
# 278     277     44                       277_at4_column_hideouts_58th
# 279     278     44                   278_glory_enemies_death_soldiers
# 280     279     44                    279_fanning_warns_flames_winnie
# 281     280     44                   280_balloon_balloons_spy_chinese
# 282     281     44               281_clash_advantage_selectivity_budd
# 283     282     44           282_facial_recognition_software_backdrop
# 284     283     44                   283_grenade_drops_grenades_drone
# 285     284     44             284_checked_funding_investors_kutyanks
# 286     285     44                        285_roger_waters_pink_floyd
# 287     286     44           286_fking_immediatelyyour_wading_dipdong
# 288     287     43               287_ammo_ammunition_production_130mm
# 289     288     43                 288_assails_brutality_marg_extends
# 290     289     43             289_winwin_harming_sacrosanct_fundings
# 291     290     43                 290_treason_treasonous_garbage_gqp
# 292     291     43                 291_ammunition_ammo_bulgarian_ar15
# 293     292     43                 292_language_fascists_nazi_fascist
# 294     293     43                  293_georgia_assad_damascus_bashar
# 295     294     43         294_prosecutor_fired_investigating_burisma
# 296     295     43                          295_nhs_tory_tories_onand
# 297     296     43         296_seized_rifles_antitank_reverseengineer
# 298     297     42               297_puppet_envoy_boogyman_freeforall
# 299     298     42      298_gangster_anc_aksenov_russiachinairansaudi
# 300     299     42                    299_t90_vuhledar_threeweek_t72b
# 301     300     42         300_divide_targetdestroy_deepening_default
# 302     301     42            301_devs_narrativethey_cought_followedi
# 303     302     42               302_mental_instagram_illness_student
# 304     303     42                    303_pump_inflation_credit_rates
# 305     304     42                   304_guterres_wider_antónio_chief
# 306     305     42              305_ka52_alligator_helicopter_cockpit
# 307     306     42              306_jewish_soured_despise_antisemites
# 308     307     42  307_mythological_personified_dismembering_terr...
# 309     308     41                     308_famine_holodomor_1932_1933
# 310     309     41                309_emerges_poland_nattrass_ryabkov
# 311     310     41            310_angry_btch_clintons_ukrainebillions
# 312     311     41                       311_jews_stepan_bandera_azov
# 313     312     41                  312_690_toll_140000_approximately
# 314     313     41        313_innocent_killing_panic_menwomenchildren
# 315     314     41          314_nigeria_nigerians_refugeesince_shldnt
# 316     315     41                          315_bridge_kerch_emt_road
# 317     316     41         316_unbearable_murderer_preemptive_sadness
# 318     317     41             317_eurovision_rostovnadon_contest_ass
# 319     318     41                         318_danish_ari_zel_stirred
# 320     319     40                 319_hahahahahahaha_tycoon_ga_smith
# 321     320     40                        320_mar_grid_fronts_kherson
# 322     321     40                 321_countrywide_most_sparking_raid
# 323     322     40                       322_cannon_fodder_bridge_uss
# 324     323     40                            323_slava_hua_cdr_exile
# 325     324     40                  324_kengor_traitor_vance_traitors
# 326     325     40                           325_lab_wuhan_virus_leak
# 327     326     39        326_orchestrated_wobbling_righteou_hegelian
# 328     327     39                          327_ji_smile_lover_indira
# 329     328     39                 328_scores_deadliest_anger_strikes
# 330     329     39                   329_hoax_lied_collusion_election
# 331     330     39             330_ratting_lipsyncing_criticisms_blah
# 332     331     39            331_dnipropetrovsk_thursday_morning_six
# 333     332     39               332_putrid_invader_hereexactly_thtab
# 334     333     39              333_evil_insanity_peoplekids_pisshole
# 335     334     39                         334_reed_pete_marine_medic
# 336     335     39  335_bidens_longshot_nationbuilding_redponblevf...
# 337     336     39          336_communist_dictator_genocidal_colombia
# 338     337     39                  337_massing_cs_agonizing_valorant
# 339     338     39                         338_jews_jewish_whites_jew
# 340     339     39                            339_taxes_cuts_tax_ummm
# 341     340     39                     340_trenches_drop_hiding_bombs
# 342     341     39             341_chechens_chechen_battling_birkenau
# 343     342     39                  342_rand_corp_trajectory_avoiding
# 344     343     38       343_charter_crimeans_zylenskies_loseloselose
# 345     344     38            344_otto_autocracy_democracy_decorative
# 346     345     38          345_vermin_scotland_dingbat_aggressorthis
# 347     346     38                   346_warrior_charlies_phillip_hal
# 348     347     38              347_widows_mobilisation_calls_alqaeda
# 349     348     38              348_trench_wagner_facetoface_brutally
# 350     349     38              349_nazism_language_nazis_ukrainegive
# 351     350     38                350_versus_madman_devil_resusitated
# 352     351     38                 351_grid_substation_dneper_flashes
# 353     352     38                352_eventthe_forwe_warwhat_hellthis
# 354     353     37      353_win_startedbetter_cricketsir_globalglobal
# 355     354     37        354_illuminati_symbols_price_russianukraine
# 356     355     37             355_referenced_goddamn_guenapig_202024
# 357     356     37          356_babysitting_ownthis_heheheh_polarises
# 358     357     37                 357_pessimism_skilled_range_breech
# 359     358     37              358_wmds_aggressionwar_newton_decoded
# 360     359     37           359_corbyn_jeremy_antisemitism_salesbury
# 361     360     37                 360_macron_french_emmanuel_crushed
# 362     361     37                361_ribs_predictions_spanish_seesaw
# 363     362     37                      362_audit_dealer_vatsak_outto
# 364     363     37                   363_2202_collage_jail_girlfriend
# 365     364     37                364_glance_rishi_vows_determination
# 366     365     37            365_existential_harbor_threat_squeamish
# 367     366     37            366_update_ruzzia_ruzzian_counterattack
# 368     367     37                    367_alongside_rapists_kid_women
# 369     368     37                    368_70th_divisive_looms_bothers
# 370     369     37            369_concessions_youas_wintershall_rpaul
# 371     370     37                370_toplevel_samarkand_usrussia_ten
# 372     371     36                        371_debt_imf_loan_creditors
# 373     372     36             372_deportation_warrant_court_unlawful
# 374     373     36              373_gerasimov_valery_replaces_general
# 375     374     36                           374_aids_data_seeks_olaf
# 376     375     36                  375_wall_immigration_aliens_walls
# 377     376     36          376_admissions_gauleiter_razumkov_squadif
# 378     377     36           377_otherise_neutered_scary_assassinated
# 379     378     36            378_tactical_belarus_terrifying_station
# 380     379     36                     379_dog_dogs_wag_adrenachromes
# 381     380     36             380_usstate_ayatollah_tortures_scolded
# 382     381     36                     381_young_dam_ovi_unbelievable
# 383     382     36           382_kaliningrad_west_promoted_anythingit
# 384     383     36                         383_milley_mark_gen_chiefs
# 385     384     35         384_artillery_headquarters_precision_blows
# 386     385     35                         385_drone_airbase_a50_a50u
# 387     386     35                   386_fishi_donbass_donbas_raining
# 388     387     35              387_glance_russiaukraine_guardian_day
# 389     388     35                   388_convoy_dramatic_ambush_drone
# 390     389     35              389_official_arming_warns_destruction
# 391     390     35             390_unilateral_ruzzists_tranport_water
# 392     391     35                           391_kia_100k_200k_mossad
# 393     392     35        392_sadam_exterminate_losingcomplete_mislav
# 394     393     35     393_tycoons_mightier_nationalization_bullshhit
# 395     394     35                      394_map_update_news18_bakhmut
# 396     395     35                   395_slowly_ground_around_bakhmut
# 397     396     35             396_guided_dashcam_worker_adrenochrome
# 398     397     35             397_passiveness_poke_duckibg_authonomy
# 399     398     35                        398_fury_usyk_tyson_donates
# 400     399     35                  399_hillary_culpable_clinton_lied
# 401     400     34   400_monitoring_offcause_selfgenocidal_ruspeaking
# 402     401     34                            401_himars_mar_23_fired
# 403     402     34                          402_himars_660_base_alert
# 404     403     34               403_hear_facts_russiaukraine_spanish
# 405     404     34                 404_mearsheimer_john_prof_manstein
# 406     405     34          405_strasbourg_oppressed_iranians_request
# 407     406     34                  406_bitcoin_crypto_unveils_raises
# 408     407     34     407_intelligentsia_speakers_сivicminded_rzzian
# 409     408     34     408_reoffend_offenders_behavioral_perpetuating
# 410     409     34  409_downplay_authoritarianism_potuses_goddaughter
# 411     410     34                   410_code_procedure_criminal_a263
# 412     411     34                     411_refugees_ova_racism_racist
# 413     412     34                   412_eitherand_falled_5pm_irannot
# 414     413     34                            413_javelin_at4_t72_mar
# 415     414     34                       414_planning_10b_24_february
# 416     415     34            415_cynically_2014_divide_frontsbattles
# 417     416     34  416_ukraineeuusa_negotiations_perfectly_bushbl...
# 418     417     34                 417_fronts_according_combat_losses
# 419     418     33                  418_f88k_airing_succeeding_tothru
# 420     419     33    419_collective_stoltenberg_nazioccupied_promote
# 421     420     33  420_indecision_surplanted_gameplaying_casuallties
# 422     421     33                      421_nugent_idiοts_donnie_2028
# 423     422     33  422_queensbury_inalienable_russioukrainian_red...
# 424     423     33         423_goaders_kravchuk_genociders_yushchenko
# 425     424     33                       424_vix_corrupt_snd_saddened
# 426     425     33   425_recognize_independence_estrangement_fallouts
# 427     426     33                426_map_apartment_tchakarova_velina
# 428     427     33     427_totalenergies_complicity_english_dismissed
# 429     428     33                      428_founders_miners_13rd_coal
# 430     429     33            429_fbi_investigate_family_coincidences
# 431     430     33                    430_catie_muhogo_rhyme_leftwing
# 432     431     33  431_capabilitiesbased_negotiations_lisbon_simo...
# 433     432     33          432_ashes_zaragoza_18081813_servicemember
# 434     433     33             433_convoys_modified_switchblade_drops
# 435     434     33                  434_automatic_hs2_rail_civillians
# 436     435     33     435_prosthetics_enforcer_clinicians_prosthetic
# 437     436     32                         436_cost_yearend_160_euros
# 438     437     32                         437_update_daily_nyt_cohen
# 439     438     32                       438_explosion_atg_fiery_30th
# 440     439     32                      439_trench_near_close_footage
# 441     440     32          440_gutted_cancerstricken_parade_honoring
# 442     441     32       441_reasserting_intersectional_tubby_barkley
# 443     442     32        442_continuation_tendentious_rússia_erasion
# 444     443     32       443_provinces_strengthen_breakaway_zwimbabwe
# 445     444     32                 444_scandal_lanes_vicious_downplay
# 446     445     32                    445_grp_samme_nazirus_auschwitz
# 447     446     32       446_trumpkin_colonialist_madness_russophobia
# 448     447     32                 447_trenches_carries_trench_rocket
# 449     448     32                      448_toll_60000_ohchr_veronika
# 450     449     32             449_poles_internationallywith_fein_lou
# 451     450     32       450_capitulate_provocative_catalyzing_mykhed
# 452     451     32                          451_2211_plotting_utc_sat
# 453     452     31              452_headcam_horrible_surrounds_wagner
# 454     453     31            453_prorssian_rssian_accountable_biafra
# 455     454     31         454_resolved_devasted_diazcanel_petrostate
# 456     455     31                 455_why_angry_unfathomly_spiderman
# 457     456     31                       456_tulsi_blacklisted_azz_lt
# 458     457     31            457_washingtons_genocide_fishing_asleep
# 459     458     31                     458_footage_video_drone_brutal
# 460     459     31          459_drip_weaponry_aheadthereforewe_sheman
# 461     460     31                    460_68_193839_presuppose_couses
# 462     461     31                461_chicken_mattress_scenario_crawl
# 463     462     31              462_auschwitz_injustice_worship_n4zis
# 464     463     31            463_aflaflw_intl_voters_inadvertantlyin
# 465     464     31             464_iranians_precious_iranian_barbaric
# 466     465     31                             465_hell_1919_eff_road
# 467     466     31           466_documents_classified_disclose_career
# 468     467     30                     467_newsom_schiff_polling_adam
# 469     468     30       468_yanukovych_2014_stanch_traitornwhonwoukd
# 470     469     30                           469_devils_evil_pure_mrs
# 471     470     30            470_soledar_dozens_miroslav_slavyangrad
# 472     471     30                   471_som_debunk_articles_platform
# 473     472     30         472_nemstov_celebrating_greedfest_talibani
# 474     473     30          473_package_longrange_longerrange_provide
# 475     474     30            474_bandera_poles_injustice_ukraineeven
# 476     475     30        475_ratio_loyalistsinformers_maims_casualty
# 477     476     30      476_intensifies_announce_selfrighteous_thrall
# 478     477     30                 477_tortured_raped_female_recorded
# 479     478     30              478_toysdont_msdnc_presidentu_donnell
# 480     479     30             479_tourniquet_heksinki_mfking_compile
# 481     480     30  480_underwrite_abbatoir_intresting_anthropocen...
# 482     481     30            481_fascist_rallying_colonies_massscale
# 483     482     30      482_ceasefire_selfdeclared_launches_unserious
# 484     483     30              483_eunato_indecision_folloe_putinbut
# 485     484     30          484_strasbourg_oppressed_iranians_request
# 486     485     30                 485_50t_china_happenunder_diplomas
# 487     486     30               486_pensions_meds_unaccounted_social
# 488     487     30                        487_trapped_fierce_92nd_860
# 489     488     29             488_bratstvo_settled_armenia_sugarcoat
# 490     489     29              489_flynn_zelenskyy_engulfed_zelensky
# 491     490     29                      490_pedo_epstein_bisexual_ebt
# 492     491     29       491_azores_artilce_counterparty_hahaahhahaha
# 493     492     29           492_boundaries_bureacracy_olde_constrain
# 494     493     29                493_royalties_patriots_detest_stunt
# 495     494     29         494_chechenia_belief_neighborhoods_singing
# 496     495     29                       495_posts_vindman_kinako_4xs
# 497     496     29      496_libertariansmaga_kofman_prowestern_erased
# 498     497     29           497_housetohouse_banksy_leaked_cleansing
# 499     498     29       498_fking_corrupt_politian_americansremember
# 500     499     29           499_forcefully_landgrabs_premodern_repfl
# 501     500     29             500_supremacists_sayers_freddie_salute
# 502     501     29           501_ops_antiimperialist_envyvitriol_wawu
# 503     502     29               502_significant_drags_markets_impact
# 504     503     29              503_chechnya_nazilover_deirdre_bufoon
# 505     504     29             504_quagmires_impression_crux_limmited
# 506     505     29             505_rickards_tilt_taxed_representation
# 507     506     29                  506_drops_brutally_blows_grenades
# 508     507     29               507_stabilising_orla_guerin_doggedly
# 509     508     29                 508_manners_tends_instance_involve
# 510     509     29                     509_flip_killiary_mueller_hook
# 511     510     29                   510_turkey_erdogan_azeri_turkiye
# 512     511     29                     511_ww_parallel_furedi_tuerkei
# 513     512     29                 512_yellow_blue_colors_discourages
# 514     513     29                  513_ambassador_enter_polish_fails
# 515     514     29                            514_tide_turn_alone_won
# 516     515     29                515_chunk_unprovked_responsecan_myi
# 517     516     29           516_delicate_berlusconi_dyslexia_wtrench
# 518     517     28                    517_comedian_century_clown_fool
# 519     518     28              518_laughter_lavrov_provokes_diplomat
# 520     519     28                519_mick_bcuz_preybeasts_barracking
# 521     520     28             520_alvin_bragg_intimidating_manhattan
# 522     521     28       521_bacl_culling_aboutthis_sovreigntyclearly
# 523     522     28       522_telegram_executing_authenticated_channel
# 524     523     28   523_exinfrastructure_plans_zero_unconstitutional
# 525     524     28                  524_kraken_gopro_footage_destroys
# 526     525     28             525_family_crime_mudryks_meanwhilehere
# 527     526     28                       526_crypto_nft_twitch_tiktok
# 528     527     28                527_oliver_stone_documentary_stones
# 529     528     28                       528_drill_naval_africa_south
# 530     529     28            529_secrets_cohen_territorywar_stiffest
# 531     530     28            530_lobby_totake_borken_lethalnonlethal
# 532     531     28  531_specially_communism_nearsightedness_compar...
# 533     532     28                  532_navalny_defiant_safety_alexey
# 534     533     28      533_exhaust_prolonged_plans_russianpropaganda
# 535     534     28          534_dems_republicans_housesmarkets_ribbon
# 536     535     28                    535_atomic_heart_school_schools
# 537     536     28    536_validated_reflecting_assumptions_challenged
# 538     537     27                   537_grinder_meat_demographic_kia
# 539     538     27                       538_debt_printed_200b_capita
# 540     539     27              539_dissuade_deterrence_writes_showed
# 541     540     27                    540_pew_surveys_equivalence_pov
# 542     541     27                   541_delving_troopers_creeps_spot
# 543     542     27                   542_coward_cowards_standin_hider
# 544     543     27                   543_britishrun_grayzone_tech_spy
# 545     544     27                  544_bloody_battles_denies_soledar
# 546     545     27               545_cooperating_roger_waters_invited
# 547     546     27                        546_bradley_m2_bmp2_leopard
# 548     547     27            547_avantgarde_heist_paintings_scythian
# 549     548     27                548_mismanaged_tax_irsfair_taxaudit
# 550     549     27                    549_holt_blaine_cries_illigical
# 551     550     27                     550_anew_threatens_ammo_planes
# 552     551     27  551_opposing_canute_magacultists_bushcheneywol...
# 553     552     27                 552_defund_lemons_cartel_sanctuary
# 554     553     27                   553_urban_leopard_headcam_wagner
# 555     554     27                 554_msi_scandal_resignations_levin
# 556     555     27                555_harvesting_organ_biolabs_organs
# 557     556     27                  556_swap_funeral_bodies_recovered
# 558     557     27      557_federationgovernment_1953_spared_proright
# 559     558     26                      558_flexes_muscles_usyk_tyson
# 560     559     26        559_declined_exsplen_interventionnow_mcfail
# 561     560     26                 560_losers_φρόνησις_repop_prudence
# 562     561     26              561_deadlier_thwarts_permissives_blum
# 563     562     26               562_regiment_meta_controversial_azov
# 564     563     26           563_meatballs_cavalierly_kyivmohyla_1430
# 565     564     26   564_traders_ukrainens_commonalityall_saddamlibya
# 566     565     26            565_ตออกมาพ_georiga_goergia_belligerant
# 567     566     26                     566_deadlock_g20_fret_studying
# 568     567     26               567_cbrne_armour_ammunition_shipping
# 569     568     26                568_angelo_gage_guessing_terrorized
# 570     569     26                  569_block_minister_poland_germany
# 571     570     26    570_tiny_actuate_landofjackasses_streetrussians
# 572     571     26  571_cabal_bribery_humandrugweaponbioresearch_r...
# 573     572     26          572_strasbourg_oppressed_iranians_request
# 574     573     26                      573_mysterious_tools_39_panes
# 575     574     26                574_tender_rape_ukrainelong_sookien
# 576     575     26                 575_white_zinchenkos_fancies_myrie
# 577     576     26                    576_exhuming_ruzz_grisly_eighth
# 578     577     26                   577_bombs_drops_frontline_drones
# 579     578     26                      578_valor_bicker_vacant_carly
# 580     579     26            579_toilets_sanctions_zhirinovsky_vitol
# 581     580     26      580_wealthier_russification_meddler_brigading
# 582     581     25        581_ukrainepoland_endangers_posture_reaches
# 583     582     25                            582_awol_seal_navy_2019
# 584     583     25    583_stateanybody_easilydebunked_elonq_congruent
# 585     584     25            584_ohhh_claimtrump_blackmailed_hillary
# 586     585     25               585_zelensky_zeze_supppoed_zelinskky
# 587     586     25              586_ammunition_ammo_production_rounds
# 588     587     25  587_irreplaceable_chechnya_happeningaccept_pol...
# 589     588     25        588_attitudes_icymi_mysterious_construction
# 590     589     25                   589_awol_birmingham_menonite_96½
# 591     590     25            590_language_farright_prolgbtq_righters
# 592     591     25   591_bounties_barclays_wiseman_fightingsupporting
# 593     592     25           592_waysno_indicter_retrieves_globalhomo
# 594     593     25                    593_fcked_bunnies_warthis_moxie
# 595     594     25                 594_89_phones_cellphone_cellphones
# 596     595     25                595_trust_bismarkian_newroads_maven
# 597     596     25          596_2347_cancerstricken_bosses_irrational
# 598     597     25       597_prosecute_whitehouse_delegation_tribunal
# 599     598     25                         598_bla_barista_clair_secs
# 600     599     25                          599_seal_navy_exus_former
# 601     600     25                           600_grim_fresh_faces_mvd
# 602     601     25                    601_mutated_mega_child_pregnant
# 603     602     25                  602_usmnt_wc_insightful_centuries
# 604     603     25               603_3171_borscht_fundraising_seconds
# 605     604     25     604_prosecutor_fired_investigating_withholding
# 606     605     25                 605_orban_viktor_hungarys_krishnas
# 607     606     25              606_ambush_mercenary_hundreds_clashes
# 608     607     25                       607_proxy_canon_facto_usbase
# 609     608     25                          608_119_bub_blieden_exrnc
# 610     609     25  609_homeless_ownpeoplesadthe_streetsdo_homeles...
# 611     610     24                      610_news18_update_vs_20230104
# 612     611     24          611_massacred_facist_pillaging_resolution
# 613     612     24  612_agitprop_speeches_unforgivablethe_academia...
# 614     613     24                         613_nbc_reporter_list_puts
# 615     614     24                     614_mccain_graham_lindsey_john
# 616     615     24             615_sinocommunism_newell_it2_impeached
# 617     616     24            616_norway_requests_asylum_rusiaukraine
# 618     617     24     617_urself_cheney_begginings_themprigozhinfrom
# 619     618     24                    618_antony_wolff_secretary_prof
# 620     619     24      619_nationalism_transient_beinarush_ephemeral
# 621     620     24                   620_refute_coward_theirtask_orke
# 622     621     24                    621_sweden_finland_join_applied
# 623     622     24                          622_brit_کارگر_atk_kargar
# 624     623     24                   623_gopro_pavlivka_footage_close
# 625     624     24  624_signaling_classicmadman_ukrainemccarthy_bi...
# 626     625     24                   625_flaw_creation_lawyers_shield
# 627     626     24    626_isrussia_innoapropriate_neem_statementgreat
# 628     627     24              627_kickoff_insisting_moments_bizarre
# 629     628     24           628_ranks_azerbaijan_supportive_horribly
# 630     629     24                   629_pathetic_corleone_pab_hehehe
# 631     630     24                      630_droves_viewed_trenches_1m
# 632     631     24       631_wagenknecht_oles_languageetc_perfunctory
# 633     632     24            632_language_prejudices_tatar_forbidden
# 634     633     24            633_destabilizing_foisted_anyonewhat_df
# 635     634     24                 634_diddle_donbas_hungary_predates
# 636     635     24                  635_mozart_cancer_milburn_execute
# 637     636     24  636_antiaircraftantimissile_prioritize_sponsor...
# 638     637     24       637_calgarian_reflects_myopicwatch_resurface
# 639     638     24                  638_tainted_julian_johnson_dielet
# 640     639     24            639_ceasefire_ukraineyour_save_ambition
# 641     640     23                640_ovi_rushin_mentalities_postwwii
# 642     641     23                641_smert_memes_forreal_disembodied
# 643     642     23                     642_maltese_lilek_innifsek_mur
# 644     643     23               643_girkin_satisfied_intend_isbeyond
# 645     644     23                644_solved_parallels_goodputin_komi
# 646     645     23  645_currency_sovereignwealth_instrumentfeb_rec...
# 647     646     23                               646_pole_na_dey_wolf
# 648     647     23   647_capitulates_pronazi_tripledown_psychoneocons
# 649     648     23     648_antisemitism_podcast_presidential_concerns
# 650     649     23               649_antrim_wifi_invokes_complexities
# 651     650     23       650_closerange_squads_armament_escapeukraine
# 652     651     23                       651_threw_betrayed_dogs_2312
# 653     652     23              652_lovely_notis_immaterial_filthiest
# 654     653     23             653_bluffs_eyetoeye_undisputed_ratchet
# 655     654     23  654_eva_believes_leak_trumprussiaukrainepeetap...
# 656     655     23                  655_number_casualty_60000_wounded
# 657     656     23                      656_bombs_footage_near_drones
# 658     657     23  657_testdriving_euwanting_whitehot_likesubmitting
# 659     658     23           658_babys_cheetoman_lemmings_experiments
# 660     659     23                   659_malone_damar_hamlin_analyzes
# 661     660     23                      660_miller_msm_credibility_rs
# 662     661     23                 661_ceasefire_israeli_expm_blocked
# 663     662     23          662_thatbwe_savings_spendingstaing_drugdo
# 664     663     23             663_taiwan_strait_chollet_crowdsourced
# 665     664     23              664_myths_grasp_dyinghe_thatsocialism
# 666     665     23                           665_dore_jimmy_rant_epic
# 667     666     23                      666_allthis_usnt_grenfell_gob
# 668     667     23             667_inflation_raise_printed_meaningful
# 669     668     23            668_resigns_criticism_germanys_minister
# 670     669     23             669_delaware_censor_tiesnot_wombbabies
# 671     670     23                             670_16585_rsaf_div_owl
# 672     671     23  671_march2023_prognostications_propagandist_de...
# 673     672     23               672_shiet_hungarians_herorically_caz
# 674     673     23                  673_hearsay_serves_oranges_apples
# 675     674     23                  674_hospital_14_deliberate_claims
# 676     675     23          675_music_terrorizing_fakestinians_altanf
# 677     676     22                 676_galicia_lady_bandera_collected
# 678     677     22  677_suiciding_russianromanianhungarianspoles_l...
# 679     678     22                      678_kulaks_cccp_mil_oppressor
# 680     679     22                 679_squad_insects_drivers_disputes
# 681     680     22              680_obamasoros_mishandled_afraid_quid
# 682     681     22              681_replacements_intensity_tested_kit
# 683     682     22              682_bandera_worshipers_jew_communists
# ...
# 1241   1240     13                   1240_cough_paycheck_lend_backend
# 1242   1241     13         1241_blah_orange_louise_notspeakermccarthy
# 1243   1242     13            1242_chernobyl_1986_reactor_radioactive
# 1244   1243     13          1243_lesser_dominick_officious_annoyingly
# 1245   1244     12                           1244_rf_hec_truncate_ucu
# 1246   1245     12           1245_undergoes_moldovas_shakeup_stressed
# 1247   1246     12        1246_childish_chinawhen_bullys_incarnations
# 1248   1247     12          1247_pause_distraction_indefinite_railing
# 1249   1248     12          1248_twentyfif_shuttering_anwr_marginally
# 1250   1249     12       1249_destroyin_gorbachev_biolab_aggressively
# 1251   1250     12      1250_respected_trenddid_peoplethat_dissappear
# 1252   1251     12             1251_eastsouthern_mishmash_rerun_sully
# 1253   1252     12                          1252_32_river_dams_dnipro
# 1254   1253     12  1253_richpoor_covidbrexit_usa2014_marxismleninism
# 1255   1254     12         1254_yagodas_mankurts_sverdlovs_leonidovna
# 1256   1255     12            1255_2he_europeall_cosmos_shambolically
# 1257   1256     12                   1256_ginni_stinking_hearings_409
# 1258   1257     12                  1257_gerogia_is2stop_2014why_3030
# 1259   1258     12        1258_insurrected_demodeep_fuvking_farmsdont
# 1260   1259     12          1259_semchynska_uhl_semchynsky_kostyantyn
# 1261   1260     12               1260_ns_straighten_describes_hawkish
# 1262   1261     12             1261_sword_murika_tatiana_suggestively
# 1263   1262     12                      1262_blacked_psyop_chas_91001
# 1264   1263     12        1263_paranoid_obviouswake_vacationing_crows
# 1265   1264     12             1264_zsymbol_displayor_exorcism_raized
# 1266   1265     12                 1265_dropping_bombs_drones_footage
# 1267   1266     12           1266_koresh_nuzhim_morallybankrupt_screw
# 1268   1267     12           1267_frp_voterbleeding_paroled_invasioni
# 1269   1268     12                1268_15700_inattacks_2692_misreport
# 1270   1269     12                    1269_ballsy_fusing_sook_outrage
# 1271   1270     12                 1270_taller_hierarchy_rolled_nanci
# 1272   1271     12                       1271_imbibe_yano_qin_tacitly
# 1273   1272     12                     1272_troop_500_wagner_horrible
# 1274   1273     12                          1273_cyber_npr_role_story
# 1275   1274     12                        1274_jan_anti_hundreds_tank
# 1276   1275     12                     1275_littoral_phase_red_secnav
# 1277   1276     12              1276_forgive_𝐋𝐥𝐨𝐲𝐝_𝐁𝐥𝐢𝐧𝐤𝐞𝐧_crimethese
# 1278   1277     12           1277_proputin_endangers_asiataiwan_proxi
# 1279   1278     12                  1278_holds_rage_battles_commander
# 1280   1279     12          1279_outburst_visions_businessmen_dudayev
# 1281   1280     12           1280_record_ect_streets84_energycrushing
# 1282   1281     12       1281_pensions_resurfaces_stoking_shitinstead
# 1283   1282     12                1282_hedges_chris_censorship_report
# 1284   1283     12               1283_tracker_interactive_maps_charts
# 1285   1284     12       1284_residents_ingeneering_newcomer_emettors
# 1286   1285     12        1285_goals_attained_maximalist_negotiations
# 1287   1286     12                   1286_reserves_falkls_baptize_nob
# 1288   1287     12            1287_2633_happeningor_sumption_bilahari
# 1289   1288     12                1288_yrsukraine_malefree_karkov_pdm
# 1290   1289     12                      1289_xix_mustered_deleted_rte
# 1291   1290     12                1290_1an_2russia_emigrate_dissolves
# 1292   1291     12  1291_explosions_indication_scalate_funnysadpat...
# 1293   1292     12                1292_exclusive_mercenary_camo_birds
# 1294   1293     12                    1293_twww_bff_undeclared_hawley
# 1295   1294     12                1294_flees_drew_komsomolets_unlearn
# 1296   1295     12                         1295_exseal_dies_6th_known
# 1297   1296     12                   1296_loom_discuss_battles_allies
# 1298   1297     12                     1297_amx10rcs_lias_beting_eu28
# 1299   1298     12                   1298_blow_grenades_drop_position
# 1300   1299     12             1299_developments_hidden_grenades_drop
# 1301   1300     12             1300_callup_defuse_thailand_jaishankar
# 1302   1301     12                   1301_watercolor_hopeful_ebay_sun
# 1303   1302     12               1302_attrit_3xxxx_bakhmur_nikolaevka
# 1304   1303     12  1303_clucker_noweither_mealymouthed_straightta...
# 1305   1304     12                 1304_we2_broadway_coughs_escaltion
# 1306   1305     12         1305_particulararly_hondurus_givin_pursuit
# 1307   1306     12              1306_khashoggi_peeps_itneither_veatch
# 1308   1307     12                 1307_positions_smash_drone_running
# 1309   1308     12             1308_mangushev_renaud_brent_voronenkov
# 1310   1309     12             1309_individualo_fester_ncaa_admission
# 1311   1310     12  1310_terminally_health_russianarmed_westernali...
# 1312   1311     12              1311_spade_frommom_30nof_beforeduring
# 1313   1312     12             1312_torys_freespeach_mislite_fashiest
# 1314   1313     12             1313_sachs_jeffrey_perspective_context
# 1315   1314     12                    1314_puke_pukearamas_fffk_wthis
# 1316   1315     12              1315_airbag_includ_ukrainemultiple_a3
# 1317   1316     12    1316_turkishrussian_expressly_ciabacked_lobbied
# 1318   1317     12             1317_660_760_counterattack_mercenaries
# 1319   1318     12  1318_disarming_economiestrade_shouldwill_euroa...
# 1320   1319     12   1319_35m_ukrainepretty_resourcesjust_internation
# 1321   1320     11              1320_whined_libertarians_fake_propgnd
# 1322   1321     11              1321_tricked_zoomed_trims_antitrudeau
# 1323   1322     11  1322_fountain_blindhypocritical_investigatesol...
# 1324   1323     11               1323_prevented_membership_finland_pm
# 1325   1324     11                       1324_modified_drop_bomb_line
# 1326   1325     11                    1325_drop_bombs_horrible_drones
# 1327   1326     11             1326_anywho_socratic_evades_legitimise
# 1328   1327     11                       1327_cornyn_dia_confirms_sky
# 1329   1328     11  1328_obligations_pensioned_mediascape_psychosu...
# 1330   1329     11  1329_authoritarians_zerbians_byzantina_indians...
# 1331   1330     11  1330_putinofils_ballspathetic_tactful_obliterates
# 1332   1331     11             1331_fissures_cracking_usukraine_unity
# 1333   1332     11                          1332_fod_f4_intake_visual
# 1334   1333     11            1333_ideally_insurrection_yesbut_etcnow
# 1335   1334     11           1334_assembly_immediate_eleventh_resumes
# 1336   1335     11         1335_countryside_convoy_crossing_04ukraine
# 1337   1336     11   1336_myanmar_enlistment_offices_voluntarilymaybe
# 1338   1337     11    1337_19510_remainedrussia_termite_secondrussian
# 1339   1338     11               1338_farming_buffett_planting_litter
# 1340   1339     11            1339_glaziev_fraternité_egalité_liberté
# 1341   1340     11                        1340_swift_daniel_navy_seal
# 1342   1341     11                 1341_guos_faucisus_bellend_slowest
# 1343   1342     11              1342_insects_elite_mercenaries_ambush
# 1344   1343     11              1343_15yearold_armour_drone_leleka100
# 1345   1344     11                         1344_puto_vimeo_cou_scotus
# 1346   1345     11                   1345_2034_12jan_proff_depressive
# 1347   1346     11            1346_todaybakhmut_kherson_drone_counter
# 1348   1347     11          1347_moskovite_havethe_persevered_serfdom
# 1349   1348     11               1348_quicker_overyet_knuckle_bigtime
# 1350   1349     11                1349_gopro_destroys_brutally_dozens
# 1351   1350     11          1350_australians_png_warprofiteer_lookout
# 1352   1351     11          1351_choreographed_ambistions_whixh_dover
# 1353   1352     11                 1352_restricted_vacuums_jelani_tnc
# 1354   1353     11       1353_antilibertarian_glazyevs_ramanis_ramani
# 1355   1354     11     1354_zimbawee_milllions_ineffectively_dreading
# 1356   1355     11                    1355_spin_attrition_fuel_bloody
# 1357   1356     11                          1356_gym_howth_lift_churn
# 1358   1357     11  1357_wíll_oligarchshunter_democracyprotective_...
# 1359   1358     11       1358_imperialism_bsing_proamerican_whirlwind
# 1360   1359     11                1359_galinichev_maksym_boxing_champ
# 1361   1360     11    1360_friendhandlerblackmailer_presto_clay_terms
# 1362   1361     11   1361_countrytoo_chemicalbiological_whoicc_leeway
# 1363   1362     11        1362_reznikov_oleksii_amassed_uncomfortably
# 1364   1363     11  1363_grandchildren_jeleous_democratsand_desguised
# 1365   1364     11       1364_chechnya_lavrovputin_goebbelshitler_tii
# 1366   1365     11              1365_grenades_trenches_frontline_drop
# 1367   1366     11            1366_pedophile_fondled_pediphile_paners
# 1368   1367     11                 1367_hiding_drone_horrible_footage
# 1369   1368     11      1368_australiabrazil_vaccinations_aukus_cheat
# 1370   1369     11          1369_attackers_194045_warranted_normality
# 1371   1370     11       1370_constitution_deir_vaccinate_governorate
# 1372   1371     11           1371_daycare_cwp_traumatized_accelerated
# 1373   1372     11           1372_escaping_ancient_evacuate_sicknicks
# 1374   1373     11                1373_cultural_soveits_cccr_devushka
# 1375   1374     11            1374_abuser_arrestedand_splainin_berger
# 1376   1375     11                  1375_1not_genarsl_positives_pales
# 1377   1376     11  1376_politiciansoligarchs_zelenskyyputinhitler...
# 1378   1377     11                1377_surge_deepens_adviser_confirms
# 1379   1378     11  1378_christian_satans_unsc_afghanistaniraqukraine
# 1380   1379     11               1379_energ_fcredit_publicist_daniele
# 1381   1380     11        1380_impeachment_djt_lawyerunfriggin_4steps
# 1382   1381     11         1381_bln_ing_ukraineohyou_backstopbailouts
# 1383   1382     11              1382_tplf_factso_actordictator_virile
# 1384   1383     11          1383_reconstruction_9minute_ful_measuring
# 1385   1384     11             1384_ermolenko_antonina_piano_playlist
# 1386   1385     11          1385_slobbering_presumptuous_drinks_malta
# 1387   1386     11  1386_envelope_unsupported_dumblensky_thatchemical
# 1388   1387     11                      1387_brace_decisive_ahead_set
# 1389   1388     11      1388_dissapointing_equivalizing_gwn_imagining
# 1390   1389     11             1389_demilita_seventh_ringing_punishes
# 1391   1390     11  1390_futurebut_upcoming_recruitments_insecurities
# 1392   1391     10         1391_surging_massed_ukrainesense_samething
# 1393   1392     10                 1392_logistic_bound_outclassed_004
# 1394   1393     10          1393_awill_headwind_majorly_overestimated
# 1395   1394     10              1394_resist_instructive_usnato_ivaded
# 1396   1395     10                 1395_itemized_gregg_scored_padding
# 1397   1396     10              1396_capita_cadivi_shapovalov_agothat
# 1398   1397     10                   1397_wavering_devolving_avg_shld
# 1399   1398     10               1398_currencies_yuan_dominance_trade
# 1400   1399     10                  1399_ticket_fly_buy_londoncowboys
# 1401   1400     10  1400_backwater_overcomitting_reactionretaliati...
# 1402   1401     10              1401_antonovsky_crosses_trucks_bridge
# 1403   1402     10               1402_ruffalo_amnesty_yalls_marauders
# 1404   1403     10                   1403_updates_insists_reels_hosts
# 1405   1404     10             1404_rnc_profiteer_preaching_politcian
# 1406   1405     10                1405_snipers_arsewipes_115k_sparing
# 1407   1406     10      1406_pakistan_pakistans_egosgreed_delusionsky
# 1408   1407     10  1407_readybut_natostillthey_freindsif_ceasefir...
# 1409   1408     10                  1408_hunter_closets_duhhhhh_sleet
# 1410   1409     10         1409_encouraged_rousing_recommends_cynthia
# 1411   1410     10     1410_synopsis_doggo_pretender_autotranslations
# 1412   1411     10         1411_russiaclaimed_seditionists_madmen_opt
# 1413   1412     10            1412_fbicia_frame_rented_trumpomobsters
# 1414   1413     10            1413_rah_objectively_deconstruct_whiney
# 1415   1414     10  1414_amoxicillin_antibiotic_demandnothing_amox...
# 1416   1415     10                  1415_tonia_vadim_karasev_landmass
# 1417   1416     10         1416_lustration_bannons_practising_cracked
# 1418   1417     10  1417_holomodorbandera_1959_warcrimesbut_nation...
# 1419   1418     10                1418_backburner_cede_navigating_atb
# 1420   1419     10                1419_waits_armenians_graves_flowers
# 1421   1420     10  1420_russoukrainian_securityborder_notwhy_popu...
# 1422   1421     10            1421_updates_trade_russiaukraine_latest
# 1423   1422     10               1422_vn_happeni_peoplethe_cultivated
# 1424   1423     10           1423_isis_afghiraq_staggered_repressions
# 1425   1424     10            1424_forgert_glutinous_wasremains_cauae
# 1426   1425     10   1425_ceasefires_referendums_refused_similarities
# 1427   1426     10                      1426_as_upsc_clique_zelenskyy
# 1428   1427     10               1427_outand_jellyfish_baier_moneyjoe
# 1429   1428     10           1428_itselfpresbiden_nouveau_swathe_3040
# 1430   1429     10        1429_palestine_ukraine0_3billion_113billion
# 1431   1430     10       1430_fuckedup_attendance_racistnot_secrettop
# 1432   1431     10                       1431_cases_nyt_court_reuters
# 1433   1432     10  1432_russianspeaking_paycheck_2014pre_hungryde...
# 1434   1433     10         1433_ziggas_wiggers_germanics_antidemocrat
# 1435   1434     10              1434_quack_extorted_clintondnc_4false
# 1436   1435     10                   1435_weaking_dck_cadre_absorbing
# 1437   1436     10           1436_vk_diary_germanfrenchspanish_copped
# 1438   1437     10         1437_halloween_donessk_gorlivka_scoundrels
# 1439   1438     10                       1438_blah_lies_unveils_goode
# 1440   1439     10                  1439_schiff_sperry_adam_satirized
# 1441   1440     10             1440_jud_feminism_makita_protectionist
# 1442   1441     10                     1441_icc_warrant_arrest_judges
# 1443   1442     10                       1442_strap_sofrep_140m_knots
# 1444   1443     10        1443_2whats_navasardian_hitlerthey_nazinazi
# 1445   1444     10  1444_clausewitzs_devines_eighteenthcentury_anders
# 1446   1445     10  1445_jampacked_disorganized_dissatisfaction_hi...
# 1447   1446     10           1446_anguish_enlisted_colossal_demograph
# 1448   1447     10             1447_streched_liquified_buget_violated
# 1449   1448     10        1448_megadonor_statewhat_therenot_obsession
# 1450   1449     10               1449_septic_australian_australia_aus
# 1451   1450     10      1450_antiassault_undivided_inspects_homelands
# 1452   1451     10                    1451_palestine_ohio_aide_denied
# 1453   1452     10             1452_bros_kramatorsk_22yo_fudgerussian
# 1454   1453     10                        1453_cspans_petey_aor_assco
# 1455   1454     10                   1454_stirrer_myria_ellie_digital
# 1456   1455     10        1455_forcebly_repetitia_slovakian_creatives
# 1457   1456     10                    1456_islamic_republic_irgc_role
# 1458   1457     10        1457_22723_leadingyou_alldo_occupyterritory
# 1459   1458     10              1458_iranis_disadvantages_recoup_fore
# 1460   1459     10              1459_pu_chernomyrdin_primakov_luzhkov
# 1461   1460     10                   1460_38k_numbers_curators_300400
# 1462   1461     10                    1461_denounces_fivepage_fm_crud
# 1463   1462     10            1462_contributing_widespread_sale_irans
# 1464   1463     10  1463_dinnergo_debtsfund_personalitiesalternati...
# 1465   1464     10  1464_kassam_posobiec_deterrence_moralpsycholog...
# 1466   1465     10           1465_shovels_reservists_ministry_defence
# 1467   1466     10                 1466_russianswe_truewe_pga_shotwhy
# 1468   1467     10           1467_completed_pipeline_nord_revalations

# %%
bert_topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="30dfc3c1-a235-4940-b424-0f71d436e012" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30dfc3c1-a235-4940-b424-0f71d436e012")) {                    Plotly.newPlot(                        "30dfc3c1-a235-4940-b424-0f71d436e012",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.00415297333309791,0.0042583612407943155,0.004602642555638361,0.004641912764613628,0.005253473701767134],"y":["funding  ","billion  ","dollars  ","tax  ","money  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.0028563091941661784,0.0031934310983225637,0.003196957798485924,0.003282271559676878,0.010288480890132656],"y":["expansion  ","member  ","join  ","natos  ","nato  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.007883907520234714,0.007940543935945137,0.008935284910749967,0.013729742207635324,0.02022819102569754],"y":["leopards  ","abrams  ","germany  ","leopard  ","tanks  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.0034121380068173734,0.00471594391892972,0.006801489012431814,0.007851022414839553,0.014977013719363478],"y":["beijing  ","xi  ","chinas  ","chinese  ","china  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.007076299038157749,0.011288381807762343,0.013653786069577276,0.023227626130178005,0.048242241233311015],"y":["waving  ","bio  ","profile  ","flags  ","flag  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.004209362993875582,0.004976773225043734,0.011312058569265544,0.01735766115452477,0.017546548112746713],"y":["use  ","tactical  ","nuke  ","nukes  ","nuclear  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.006122197442872272,0.009013184963633325,0.011248156088438889,0.014672654417031607,0.016828615490454783],"y":["documentary  ","photos  ","footage  ","videos  ","video  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.008623164002850738,0.009592077466176345,0.010251057528128464,0.011295669085191857,0.028408635686217536],"y":["scam  ","fraud  ","audit  ","scheme  ","laundering  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0 ...

# %%
#Positive
umap_model = UMAP(random_state=3231)
bert_topic_model= BERTopic(embedding_model = "all-MiniLM-L6-v2", umap_model=umap_model)

bert_positive = X_ukraine[X_ukraine['label']==1] #change this to 1 if positive. keep 0 if negative.
bert_positive = bert_positive.Tweet.tolist()
topics, probs = bert_topic_model.fit_transform(bert_positive)

pd.set_option('display.max_rows', None)
topic_list=bert_topic_model.get_topic_info()
topic_list

bert_topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1d3e3379-f238-468a-b343-cea3d602360d" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d3e3379-f238-468a-b343-cea3d602360d")) {                    Plotly.newPlot(                        "1d3e3379-f238-468a-b343-cea3d602360d",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.004572244676455145,0.005043594557308488,0.005767233530557991,0.010226600120880048,0.020575071934100148],"y":["member  ","alliance  ","membership  ","join  ","nato  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.007684077102688645,0.008341508539865254,0.00965320109992525,0.009872586631483915,0.017293215092873127],"y":["bidens  ","documents  ","joe  ","hunter  ","biden  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.007306725176079089,0.00834674279190683,0.009983139424342658,0.016601843823718942,0.02807217786405934],"y":["fascists  ","neo  ","nazism  ","nazi  ","nazis  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.006411695980794645,0.006464069837947162,0.007101311732157723,0.012359460147150999,0.12743242176095493],"y":["ukraine  ","dawn  ","standing  ","inspiration  ","glory  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.0065003262619765,0.006666556046099888,0.0079299467653674,0.01908664761334254,0.02874511392025215],"y":["zelenskys  ","president  ","volodymyr  ","zelenskyy  ","zelensky  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.007019995576261406,0.009747807948215056,0.014626613887319785,0.028408443428384195,0.05055697929082917],"y":["fly  ","virtue  ","profile  ","flags  ","flag  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.0065493974296324045,0.0073160511085294255,0.009896308281352423,0.02108846743737035,0.024867213558609876],"y":["pay  ","money  ","dollars  ","taxes  ","tax  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.005079728440575523,0.005764923780132143,0.005834832544549506,0.006013305651440028,0.014127530229412655],"y":["sending  ","giving  ","cash  ","send  ","money  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444 ...
